# %% [markdown]
# # PyEO Processing: How to build a change detection pipeline using your classification model..

# %% [markdown]
# - Here we will cover how to query and download images in order to build a cloud-free composite baseline
# - We can then use this a reference against which to compare later 'change' images and so be able to identify forest changes
# - Identified forest changes can then be processed and filtered based on the pattern over time
# - Manual assessment can then be judge which alert ares to flag for further investigation

# %% [markdown]
# # Composite Baseline Building

# %% [markdown]
# - This section will take us stepwise through the imagery query, download and composite creation aspects of the `run_acd_national.py` script, which runs the full PyEO pipeline from the command line in a terminal.
# - Jupyter notebooks provide a useful and engaging interface to understand the components of this script, so we will follow an extracted version throughout this notebook.
#
# This section comprises several stages:
# 1. Directory and V=variable setup.
# 1. Querying for Sentinel-2 imagery that meets our search criteria.
# 1. Downloading the Sentinel-2 imagery identified from the Query.
# 1. If necessary, preprocess any L1C to L2A by applying atmospheric corrections.
# 1. Cloud-masking the L2A imagery.
# 1. Creation of a composite baseline reference from the time series that has been downloaded and processed.
# 1. Query and Download of a set of Change Detection Images
# 1. Classification of Baseline and Change Detection Images
# 1. Creation of Forest Alerts

# %% [markdown]
# # Setup: Requirements to use this Notebook

# %% [markdown]
# ## A note on Sen2Cor
# - Sen2Cor is ESA's atmospheric correction software for Sentinel-2 images at processing level L1C. The output from it is an L2A product.
# - Sen2Cor must be installed on Sepal for the atmospheric correction to work. If the specific path in the ini file is not working, the atmospheric correction step is skipped and only downloaded L2A images are processed.
# - Sen2Cor requires a processing parameter file called L2A_GIPP.xml. This file may reside outside of the installation directory. A path to this file must be specific explicitly in the ini file. If it is not found or it stems from a previous version of Sen2Cor, the atmospheric correction step is skipped and only downloaded L2A images are processed.
# - If you encounter difficulties with the central installation of Sen2Cor on Sepal you can install it locally in your sepal user directory and specify the paths in the ini file. This way of using Sen2Cor has been tested and found to work error-free with this version of Pyeo.

# %%
# example how Sen2Cor can be installed within your Sepal user directory
# remove the 3 quotation marks to uncomment and run these commands
'''
# !cd ~
# !wget https://step.esa.int/thirdparties/sen2cor/2.10.0/Sen2Cor-02.10.01-Linux64.run
# !bash /home/sepal-user/Sen2Cor-02.10.01-Linux64.run
'''

# %% [markdown]
# ## Select the virtual environment
# - Use the drop-down list at the top right of the Jupyter notebook window
# - Select (venv) Python for Earth Observation (PyEO)

# %% [markdown]
# ## Check the working directory is set to `pyeo_1` within your PyEO installation

# %%
pwd
# Out:
# '/home/sepal-user/pyeo_dir/pyeo_1/notebooks'

# %%
cd /home/sepal-user/pyeo_dir/pyeo_1
# Out:
# /home/sepal-user/pyeo_dir/pyeo_1

# %%
pwd
# Out:
# '/home/sepal-user/pyeo_dir/pyeo_1'

# %% [markdown]
# ## <a id='toc3_1_'></a>[Directory and Variable Setup](#toc0_)

# %% [markdown]
# ### <a id='toc3_1_1_'></a>[Import Libraries](#toc0_)

# %%
import shutil
import sys

from pyeo_1 import (classification, filesystem_utilities,
                    queries_and_downloads, raster_manipulation)

from pyeo_1.acd_national import (acd_initialisation,
                                 acd_config_to_log,
                                 acd_roi_tile_intersection)
import configparser
import argparse
import json
import numpy as np
import os
from osgeo import gdal
import geopandas as gpd
import pandas as pd
from datetime import datetime
import warnings
import zipfile

gdal.UseExceptions()

print("Libraries successfully imported")
# Out:
# Libraries successfully imported

# %% [markdown]
# ### <a id='toc3_1_3_'></a>[Declare Processing Parameters with In-Notebook Variables](#toc0_)

# %% [markdown]
# - When running the `pyeo` pipeline we use an initialisation file (.ini) to provide the required parameters.
# - For SEPAL, we will use `pyeo_sepal.ini`
# - Below the parameters are explained, but we will read these in via the config parser.

# %% [raw]
# ### Acquisition dates for Images in the Change Period, in the form yyyymmdd
# start_date=20230101
# end_date=20230611
#
# # Acquisition dates for Images for the Baseline Composite, in the form yyyymmdd
# composite_start=20220101
# composite_end=20221231
#
# # EPSG code for Kenya - north of equator and east of 36°E is EPSG:21097
# # See https://epsg.io/21097 and https://spatialreference.org/ref/epsg/21097/
# epsg=21097
#
# # Cloud cover threshold for imagery to download
# cloud_cover=25
#
# # Certainty value above which a pixel is considered a cloud from sen2cor
# cloud_certainty_threshold=0
#
# # path to the trained machine learning model for land cover in Kenya
# model= "./models/model_36MYE_Unoptimised_20230505_no_haze.pkl"
#
# # pyeo_dir needs to be an absolute path
# pyeo_dir = "/home/sepal-user/module-venv/pyeo_1"
# # tile_dir needs to be an absolute path
# tile_dir = "/home/sepal-user/pyeo_downloads"
#
# # Relative paths are relative to pyeo_dir\
# integrated_dir = "./integrated"
# roi_dir = "./roi"
# roi_filename = "kfs_roi_subset_c.shp"
# geometry_dir = "./geometry"
# s2_tiles_filename = "kenya_s2_tiles.shp"
# log_dir = "./log"
# log_filename = "test_sepal_venv_20230614.log"
# credentials_path = "/home/sepal-user/module-venv/credentials/credentials.ini"
#
# environment_manager = "venv"
#
# #set up Sen2Cor installation path and path to the GIPP file on Sepal
# sen2cor_path = "/usr/local/lib/Sen2Cor-02.10.01-Linux64/bin/L2A_Process"
# gipp_path = "/etc/sen2cor/2.10/cfg/L2A_GIPP.xml"
# # Note: set sen2_path = "none" to disable use of Sen2Cor and download of L1C data
#
# # ***** STEP 1 ROI-TILE INTERSECTION  *****
# do_tile_intersection = True
# # **************************************************************************************************************************
#
# # ***** STEP 2 SETUP GENERAL RASTER PROCESSING OPTIONS *****
# do_raster = True
# chunks = 10
# do_skip_existing = True
# do_quicklooks = False
# # **************************************************************************************************************************
#
# # ***** STEP 3 SETUP GENERAL RASTER PROCESSING PARAMETERS *****
# download_source = "scihub"
# # granules below this size in MB will not be downloaded
# faulty_granule_threshold = 350
# # list of strings with the band name elements of the image file names in "" string notation
# # the wavebands specified here must match those used to build the random forest model specified in the Classify section below
# band_names = ["B02", "B03", "B04", "B08"]
# # file name pattern to search for when identifying band file locations in "" string notation
# resolution_string = "10m"
# # spatial resolution of the output raster files in metres. Can be any resolution, not just 10, 20 or 60 as in the default band resolutions of Sentinel-2
# output_resolution = 10
# # **************************************************************************************************************************
#
#
# # ***** STEP 4 DOWNLOAD REFERENCE IMAGES AND BUILD A MEDIAN COMPOSITE *****
# do_build_composite = True
# # set buffer in number of pixels for dilating the SCL cloud mask (recommend 10 pixels of 10 m) for the composite building
# buffer_size_cloud_masking_composite = 10
# # maximum number of images to be downloaded for compositing, in order of least cloud cover
# download_limit = 5
# # **************************************************************************************************************************
#
#
# # ***** STEP 5: DOWNLOAD CHANGE DETECTION IMAGES FOR THE REQUIRED DATE RANGE *****
# do_download = True
# # set buffer in number of pixels for dilating the SCL cloud mask (recommend 30 pixels of 10 m) for the change detection
# buffer_size_cloud_masking = 20
# # **************************************************************************************************************************
#
#
# # ***** STEP 6: CLASSIFIY THE COMPOSITE AND CHANGE DETECTION IMAGES *****
# # ***** NOTE: MOVE MODEL SPECIFICATION TO THIS SECTION*****
# do_build_prob_image = False
# # do_build_prob_image, consider removing
# do_classify = True
# # list of strings with class labels starting from class 1. Must match the trained model that was used.
# class_labels = ["primary forest", "plantation forest", "bare soil", "crops", "grassland", "open water", "burn scar", "cloud", "cloud shadow", "haze", "sparse woodland", "dense woodland", "artificial"]
# # if sieve is 0, no sieve is applied. If >0, the classification images will be sieved using gdal and all contiguous groups of pixels smaller than this number will be eliminated
# sieve = 0
# # **************************************************************************************************************************
#
#
# # ***** STEP 7: DETECT CHANGES AND BUILD RASTER REPORTS *****
# # ***** NOTE: ADD REPORT BINARISATION PARAMETERS TO THIS SECTION MIN_DETECTION; CONSISTENCY ETC.*****
# do_change = True
# # find subsequent changes from any of these classes. Must match the trained model that was used.
# change_from_classes = [1, 2]
# # to any of these classes. Must match the trained model that was used.
# change_to_classes = [3]
# # **************************************************************************************************************************
#
#
# # ***** STEP 8: VECTOR ANALYSIS OF TILE RASTER REPORTS *****
# [vector_processing_parameters]
# level_1_filename = "gadm41_KEN_1.json"
# # vectorisation currently hardcoded to use level_1_filename
# level_2_filename = "gadm41_KEN_2.json"
# level_3_filename = "gadm41_KEN_3.json"
#
# do_delete_existing_vector = True
# do_vectorise = True
#
#
# # ***** STEP 9: INTEGRATE VECTOR ANALYSES TO NATIONAL SCOPE *****
# do_integrate = True
# # **************************************************************************************************************************
#
# # ***** STEP 10: FILTER NATIONAL SCOPE VECTORISED FOREST ALERTS *****
# do_filter = False
# # If there are any strings within counties_of_interest list, filtering by county will be attempted
# counties_of_interest = []
# # Counties_of_interest = ["Kwale", "TransNzoia"]
# minimum_area_to_report_m2 = 120

# %% [markdown]
# - Now, let's read in the `.ini` file

# %% [markdown]
# ### Declare the path to the initialisation file
# - You can leave this path alone if you are using the `pyeo_sepal.ini` file that comes packaged with PyEO

# %%
pwd
# Out:
# '/home/sepal-user/pyeo_dir/pyeo_1'

# %%
config_path = "/home/sepal-user/pyeo_dir/pyeo_1/pyeo_sepal.ini"

# %% [markdown]
# # Edit the `pyeo_sepal.ini` file
# You can either:
# - Check that `pyeo_dir` and `tile_dir` in `pyeo_sepal.ini` match those below. These paths should be the same as below if you have followed the instructions in `PyEO_1_sepal_orientation` notebook"
#     - ```pyeo_dir = /home/sepal-user/20230626_pyeo_installation/pyeo_1```
#     - ```tile_dir = /home/sepal-user/20230626_pyeo_installation```
#
#     <br>
# - Or, amend the `pyeo_sepal.ini` file to match your file paths if you cloned `pyeo_1` into a different directory:
#     - Right-Click and 'Open' pyeo_sepal.ini in the file browser on the left to be able to edit it
#     - Change pyeo_dir to point to the pyeo code in your installation directory
#     ```pyeo_dir = /home/sepal-user/20230626_pyeo_installation/pyeo_1```
#     - Change tile_dir to point to your installation directory, this is where data files will be stored
#     ```tile_dir = /home/sepal-user/20230626_pyeo_installation```
#     - Save the edited initialisation file - by pressing ```Ctrl+S```

# %% [markdown]
# # Edit the `credentials_dummy.ini` file:
# - Ensure the credentials path in the `pyeo_sepal.ini` corresponds to your credentials file.
# - The default path is to `credentials/credentials.ini`
# - To use this default option open the file `credentials_dummy.ini` in the editor (Right-Click then 'Open')
# - Edit the file to add your personal credentials for the dataspace API - following the convention of this file.
# - Save the file as `credentials.ini` into the credentials folder (using File -> Save File As)

# %%
config_dict, acd_log = acd_initialisation(config_path)
# Out:
# 2023-07-09 20:35:00,629: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:00,630: INFO:                     ****PROCESSING START****
# 2023-07-09 20:35:00,631: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:00,632: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:00,633: INFO: ---                  INTEGRATED PROCESSING START            ---
# 2023-07-09 20:35:00,633: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:00,634: INFO: Reading in parameters defined in: /home/sepal-user/pyeo_dir/pyeo_1/pyeo_sepal.ini
# 2023-07-09 20:35:00,635: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### Read the `.ini` file into Python
# - Here we create a variable called `config_dict`, which is a Python dictionary containing the configuration parameters we explored in one of the cells above.

# %%
pwd
# Out:
# '/home/sepal-user/pyeo_dir/pyeo_1'

# %% [markdown]
# ### Print the configuration parameters
# - We print the configuration parameter to create a record of what pyeo has been configured to do.

# %%
acd_config_to_log(config_dict, acd_log)
# Out:
# 2023-07-09 20:35:00,741: INFO: Options:
# 2023-07-09 20:35:00,742: INFO: The Environment Manager configured to use is : venv
# 2023-07-09 20:35:00,743: INFO:   --dev Running in development mode, choosing development versions of functions where available
# 2023-07-09 20:35:00,744: INFO:   -do_tile_intersection
# 2023-07-09 20:35:00,745: INFO:       Sentinel-2 tile intersection with ROI enabled
# 2023-07-09 20:35:00,745: INFO:   --do_raster
# 2023-07-09 20:35:00,746: INFO:       raster pipeline enabled
# 2023-07-09 20:35:00,747: INFO:   --build_composite for baseline composite
# 2023-07-09 20:35:00,748: INFO:   --download_source = dataspace
# 2023-07-09 20:35:00,748: INFO:          composite start date  : 20230101
# 2023-07-09 20:35:00,749: INFO:          composite end date  : 20230210
# 2023-07-09 20:35:00,750: INFO:   --download for change detection images
# 2023-07-09 20:35:00,751: INFO:   --download_source = dataspace
# 2023-07-09 20:35:00,752: INFO:   Faulty Granule Threshold  : 350
# 2023-07-09 20:35:00,753: INFO:   --classify to apply the random forest model and create classification layers
# 2023-07-09 20:35:00,753: INFO:   --change to produce change detection layers and report images
# 2023-07-09 20:35:00,754: INFO:          change start date  : 20220101
# 2023-07-09 20:35:00,755: INFO:          change end date  : 20221231
# 2023-07-09 20:35:00,756: INFO:   --quicklooks to create image quicklooks
# 2023-07-09 20:35:00,757: INFO:   --do_delete_existing_vector , when vectorising the change report rasters,
# 2023-07-09 20:35:00,757: INFO:             existing vectors files will be deleted and new vector files created.
# 2023-07-09 20:35:00,758: INFO:   --do_vectorise
# 2023-07-09 20:35:00,759: INFO:       raster change reports will be vectorised
# 2023-07-09 20:35:00,760: INFO:   --do_integrate
# 2023-07-09 20:35:00,761: INFO:       vectorised reports will be merged together
# 2023-07-09 20:35:00,761: INFO: EPSG used is: 21097
# 2023-07-09 20:35:00,762: INFO: List of image bands: ['B02', 'B03', 'B04', 'B08']
# 2023-07-09 20:35:00,763: INFO: Model used: ./models/model_36MYE_Unoptimised_20230505_no_haze.pkl
# 2023-07-09 20:35:00,764: INFO:
# 2023-07-09 20:35:00,765: INFO: List of class labels:
# 2023-07-09 20:35:00,765: INFO:   1 : primary forest
# 2023-07-09 20:35:00,766: INFO:   2 : plantation forest
# 2023-07-09 20:35:00,767: INFO:   3 : bare soil
# 2023-07-09 20:35:00,768: INFO:   4 : crops
# 2023-07-09 20:35:00,768: INFO:   5 : grassland
# 2023-07-09 20:35:00,769: INFO:   6 : open water
# 2023-07-09 20:35:00,770: INFO:   7 : burn scar
# 2023-07-09 20:35:00,771: INFO:   8 : cloud
# 2023-07-09 20:35:00,772: INFO:   9 : cloud shadow
# 2023-07-09 20:35:00,772: INFO:   10 : haze
# 2023-07-09 20:35:00,773: INFO:   11 : sparse woodland
# 2023-07-09 20:35:00,774: INFO:   12 : dense woodland
# 2023-07-09 20:35:00,775: INFO:   13 : artificial
# 2023-07-09 20:35:00,776: INFO: Detecting changes from any of the classes: [1, 2]
# 2023-07-09 20:35:00,777: INFO:                     to any of the classes: [3]
# 2023-07-09 20:35:00,777: INFO: ------------------------------------------------------------
# 2023-07-09 20:35:00,778: INFO: Reporting Directories and Filepaths
# 2023-07-09 20:35:00,785: INFO: Tile Directory is   : /home/sepal-user/pyeo_dir
# 2023-07-09 20:35:00,786: INFO: Working Directory is   : /home/sepal-user/pyeo_dir/pyeo_1
# 2023-07-09 20:35:00,786: INFO: The following directories are relative to the working directory, i.e. stored underneath:
# 2023-07-09 20:35:00,787: INFO: Integrated Directory is   : ./integrated
# 2023-07-09 20:35:00,788: INFO: ROI Directory is   : ./roi
# 2023-07-09 20:35:00,788: INFO: Geometry Directory is   : ./geometry
# 2023-07-09 20:35:00,789: INFO: Path to the Administrative Boundaries used in the Change Report Vectorisation   : ./geometry/gadm41_KEN_1.json
# 2023-07-09 20:35:00,789: INFO: Path to Sen2Cor is   : /home/sepal-user/Sen2Cor-02.10.01-Linux64/bin/L2A_Process
# 2023-07-09 20:35:00,792: INFO: -------------------------------------------
# 2023-07-09 20:35:00,795: INFO: -------------------------------------------

# %% [markdown]
# ## Identify the required Sentinel-2 tiles

# %% [markdown]
# - PyEO operates by looking at a shapefile to determine the Region of Interest (ROI)
# - This directory path and filename of this shapefile needs to be specified in these two lines in `pyeo_sepal.ini`:
#     - `roi_dir = ./roi`
#     - `roi_filename = kfs_roi_subset_c.shp`
# - Then in the cell below, PyEO identifies what Sentinel-2 tiles intersect with the Region Of Interest (ROI).

# %%
os.chdir(config_dict["pyeo_dir"]) # ensures pyeo is looking in the correct directory
tilelist_filepath = acd_roi_tile_intersection(config_dict, acd_log)

if len(tilelist_filepath) > 1:
    acd_log.info("More than one tile covers the region of interest.")
    acd_log.info("This notebook is intended for training purposes and only processes the first tile.")
# Out:
# 2023-07-09 20:35:01,039: INFO: The provided ROI intersects with 2 Sentinel-2 tiles
# 2023-07-09 20:35:01,040: INFO: These tiles are  :
# 2023-07-09 20:35:01,041: INFO:   1 : 36NXG
# 2023-07-09 20:35:01,041: INFO:   2 : 36NYG
# 2023-07-09 20:35:01,042: INFO: Writing Sentinel-2 tiles that intersect with the provided ROI to  : ./roi/tilelist.csv
# 2023-07-09 20:35:01,058: INFO: Finished ROI tile intersection
# 2023-07-09 20:35:01,059: INFO: More than one tile covers the region of interest.
# 2023-07-09 20:35:01,060: INFO: This notebook is intended for training purposes and only processes the first tile.

# %%
print(tilelist_filepath)
# Out:
# ./roi/tilelist.csv

# %% [markdown]
# - **Right-Click on tile_list.csv in the JupyterLab explorer to the left and select 'open' to view it in a tab within JupyterLab.**

# %% [markdown]
# ## Running PyEO Per-Tile

# %% [markdown]
# - PyEO is designed to run per-tile.
# - It takes `tilelist.csv` created in the above cell and runs the pipeline for each tile in this `.csv` file.
# - This tutorial will run through the pipeline for the first tile in `tilelist.csv` : `36NXG`.

# %% [markdown]
# ## <a id='toc3_1_4_'></a>[Create the Folder Structure PyEO Expects](#toc0_)

# %%
os.chdir(config_dict["pyeo_dir"]) # ensures pyeo is looking in the correct directory

tile_to_process = pd.read_csv(tilelist_filepath)["tile"][0]
individual_tile_directory_path = os.path.join(config_dict["tile_dir"], tile_to_process)
filesystem_utilities.create_folder_structure_for_tiles(individual_tile_directory_path)
print("Folder structure build successfully finished")
# Out:
# Folder structure build successfully finished

# %% [markdown]
# - You can now use the JupyterLab file explorer to view the new folder structure which should be in your installation directory and called `36NXG`
# - These folders provide the skeleton for the pipeline to store and process the tile's imagery

# %%
individual_tile_directory_path
# Out:
# '/home/sepal-user/pyeo_dir/36NXG'

# %% [markdown]
# ## <a id='toc3_1_5_'></a>[Create the Log File](#toc0_)

# %% [markdown]
# - `PyEO` uses a Log file as a convenient location to monitor pipeline progress
# - Additionally, the log file acts as a record of which parameters were used.

# %%
tile_log = filesystem_utilities.init_log_acd(
    log_path=os.path.join(individual_tile_directory_path, "log", tile_to_process + ".log"),
    logger_name=f"pyeo_1_{tile_to_process}"
)
# Out:
# 2023-07-09 20:35:01,266: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:01,267: INFO:                     ****PROCESSING START****
# 2023-07-09 20:35:01,268: INFO: ---------------------------------------------------------------

# %% [markdown]
# - You can now use the JupyterLab file explorer to find the log file which will be in a log folder beneath the main tile directory
#     - For example, the path to the Log file for `36NXG`, is : `20230626_pyeo_installation/36NXG/log/36NXG.log`

# %% [markdown]
# ## Create the Required Directory Variables

# %% [markdown]
# - This cell ensures the paths for the directory strucutre are available to pipeline commands.

# %%
tile_log.info("Creating the directory paths")

change_image_dir = os.path.join(individual_tile_directory_path, r"images")
l1_image_dir = os.path.join(individual_tile_directory_path, r"images/L1C")
l2_image_dir = os.path.join(individual_tile_directory_path, r"images/L2A")
l2_masked_image_dir = os.path.join(individual_tile_directory_path, r"images/cloud_masked")
categorised_image_dir = os.path.join(individual_tile_directory_path, r"output/classified")
probability_image_dir = os.path.join(individual_tile_directory_path, r"output/probabilities")
sieved_image_dir = os.path.join(individual_tile_directory_path, r"output/sieved")
composite_dir = os.path.join(individual_tile_directory_path, r"composite")
composite_l1_image_dir = os.path.join(individual_tile_directory_path, r"composite/L1C")
composite_l2_image_dir = os.path.join(individual_tile_directory_path, r"composite/L2A")
composite_l2_masked_image_dir = os.path.join(individual_tile_directory_path, r"composite/cloud_masked")
quicklook_dir = os.path.join(individual_tile_directory_path, r"output/quicklooks")

tile_log.info("Successfully created the directory paths")
# Out:
# 2023-07-09 20:35:01,329: INFO: Creating the directory paths
# 2023-07-09 20:35:01,330: INFO: Successfully created the directory paths

# %% [markdown]
# - So now, we can type any of the above variables into a Python cell and when we execute it - we will see the file path for that directory.

# %%
l1_image_dir
# Out:
# '/home/sepal-user/pyeo_dir/36NXG/images/L1C'

# %% [markdown]
# ## Create the Processing Argument Variables

# %% [markdown]
# - `PyEO` uses these parameters to make decisions throughout the pipeline.

# %%
os.chdir(config_dict["pyeo_dir"]) # ensures pyeo is looking in the correct directory
# !pwd
# Out:
# /home/sepal-user/pyeo_dir/pyeo_1

# %%
start_date = config_dict["start_date"]
end_date = config_dict["end_date"]
composite_start_date = config_dict["composite_start"]
composite_end_date = config_dict["composite_end"]
cloud_cover = config_dict["cloud_cover"]
cloud_certainty_threshold = config_dict["cloud_certainty_threshold"]
model_path = config_dict["model_path"]
sen2cor_path = config_dict["sen2cor_path"]
gipp_path = config_dict["gipp_path"]
epsg = config_dict["epsg"]
bands = config_dict["bands"]
resolution = config_dict["resolution_string"]
out_resolution = config_dict["output_resolution"]
buffer_size = config_dict["buffer_size_cloud_masking"]
buffer_size_composite = config_dict["buffer_size_cloud_masking_composite"]
max_image_number = config_dict["download_limit"]
faulty_granule_threshold = config_dict["faulty_granule_threshold"]
download_limit = config_dict["download_limit"]

skip_existing = config_dict["do_skip_existing"]
sieve = config_dict["sieve"]
from_classes = config_dict["from_classes"]
to_classes = config_dict["to_classes"]

download_source = config_dict["download_source"]
if download_source == "scihub":
    tile_log.info("scihub API is the download source")
if download_source == "dataspace":
    tile_log.info("dataspace API is the download source")

if sen2cor_path == "none":
    tile_log.info("Sen2Cor is disabled. Only processing L2A products. Skipping all L1C products.")
else:
    tile_log.info("Sen2Cor should be installed in the directory: " + sen2cor_path)
    tile_log.info("The file L2A_GIPP.xml should be in the directory: " + gipp_path)
    tile_log.info("If Sen2Cor causes an error, check the installation directory and whether the GIPP file exists.")

tile_log.info(f"Faulty Granule Threshold is set to   : {config_dict['faulty_granule_threshold']}")
tile_log.info("    Files below this threshold will not be downloaded")

credentials_path = config_dict["credentials_path"]
if not os.path.exists(credentials_path):
    tile_log.error(f"The credentials path does not exist  :{credentials_path}")
    tile_log.error(f"Current working directory :{os.getcwd()}")
    tile_log.error("Exiting raster pipeline")
    sys.exit(1)

conf = configparser.ConfigParser(allow_no_value=True, interpolation=None)
conf.read(credentials_path)
credentials_dict = {}

# Adjust for various ways of writing none or n/a to disable use of Sen2Cor.
if sen2cor_path == "None" or sen2cor_path == "NONE" or sen2cor_path == "N/A" \
        or sen2cor_path == "n/a" or sen2cor_path == "":
    sen2cor_path = "none"
    
tile_log.info("Successfully read the processing arguments and credentials")
# Out:
# 2023-07-09 20:35:01,831: INFO: dataspace API is the download source
# 2023-07-09 20:35:01,832: INFO: Sen2Cor should be installed in the directory: /home/sepal-user/Sen2Cor-02.10.01-Linux64/bin/L2A_Process
# 2023-07-09 20:35:01,833: INFO: The file L2A_GIPP.xml should be in the directory: /home/sepal-user/sen2cor/2.10/cfg/L2A_GIPP.xml
# 2023-07-09 20:35:01,833: INFO: If Sen2Cor causes an error, check the installation directory and whether the GIPP file exists.
# 2023-07-09 20:35:01,834: INFO: Faulty Granule Threshold is set to   : 350
# 2023-07-09 20:35:01,835: INFO:     Files below this threshold will not be downloaded
# 2023-07-09 20:35:01,844: INFO: Successfully read the processing arguments and credentials

# %% [markdown]
# ## Read the Specified Credentials

# %%
if download_source == "dataspace":

    tile_log.info(f'Running download handler for {download_source}')

    credentials_dict["sent_2"] = {}
    credentials_dict["sent_2"]["user"] = conf["dataspace"]["user"]
    credentials_dict["sent_2"]["pass"] = conf["dataspace"]["pass"]
    sen_user = credentials_dict["sent_2"]["user"]
    sen_pass = credentials_dict["sent_2"]["pass"]

if download_source == "scihub":

    tile_log.info(f'Running download handler for {download_source}')

    credentials_dict["sent_2"] = {}
    credentials_dict["sent_2"]["user"] = conf["sent_2"]["user"]
    credentials_dict["sent_2"]["pass"] = conf["sent_2"]["pass"]
    sen_user = credentials_dict["sent_2"]["user"]
    sen_pass = credentials_dict["sent_2"]["pass"]
    
tile_log.info(f"Successfully configured the credentials for {download_source}")
# Out:
# 2023-07-09 20:35:01,900: INFO: Running download handler for dataspace
# 2023-07-09 20:35:01,901: INFO: Successfully configured the credentials for dataspace

# %% [markdown]
# ## <a id='toc3_2_'></a>[Query Sentinel-2 Composite Imagery](#toc0_)

# %% [markdown]
# First, a brief primer on the two Sentinel-2 data products we are concerned with:
# - L1C
# - L2A
#
# **L1C** corresponds to the 1st processing level for the imagery. <br>
#
# **L2A** corresponds to the 2nd processing level and this is the imagery we want to work with as these have been **atmospherically corrected**.
#
# -------------------------------
#
# Now that we have the query, file handling and log parameters set up, we can start querying the Copernicus Hub for the Sentinel-2 imagery that we want.
#
# The cell below starts the `build_composite` process. First, we query for the `L1C` products that match our criteria (date range, tile of interest, cloud cover).
#
# Since we have declared a download limit of 12 images, the software caps the number of images in our query. This is a useful tool if we have limited disk space.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Creating an initial cloud-free median composite from Sentinel-2 as a baseline map"
    )
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Searching for images for initial composite.")

    if download_source == "dataspace":

        try:
            tiles_geom_path = os.path.join(config_dict["pyeo_dir"], os.path.join(config_dict["geometry_dir"], config_dict["s2_tiles_filename"]))
            tile_log.info(f"Path to the S2 tile geometry information absolute path: {os.path.abspath(tiles_geom_path)}")
            tiles_geom = gpd.read_file(os.path.abspath(tiles_geom_path))
        except FileNotFoundError:
            tile_log.error(f"Path to the S2 tile geometry does not exist, absolute path given: {os.path.abspath(tiles_geom_path)}")

        tile_geom = tiles_geom[tiles_geom["Name"] == tile_to_process]
        tile_geom = tile_geom.to_crs(epsg=4326)
        geometry = tile_geom["geometry"].iloc[0]
        geometry = geometry.representative_point()

        # convert date string to YYYY-MM-DD
        date_object = datetime.strptime(composite_start_date, "%Y%m%d")
        dataspace_composite_start = date_object.strftime("%Y-%m-%d")
        date_object = datetime.strptime(composite_end_date, "%Y%m%d")
        dataspace_composite_end = date_object.strftime("%Y-%m-%d")

        try:
            dataspace_composite_products_all = queries_and_downloads.query_dataspace_by_polygon(
                max_cloud_cover=cloud_cover,
                start_date=dataspace_composite_start,
                end_date=dataspace_composite_end,
                area_of_interest=geometry,
                max_records=100,
                log=tile_log
            )
        except Exception as error:
            tile_log.error(f"query_dataspace_by_polygon received this error: {error}")

        titles = dataspace_composite_products_all["title"].tolist()
        sizes = list()
        uuids = list()
        for elem in dataspace_composite_products_all.itertuples(index=False):
            sizes.append(elem[-2]["download"]["size"])
            uuids.append(elem[-2]["download"]["url"].split("/")[-1])

        relative_orbit_numbers = dataspace_composite_products_all["relativeOrbitNumber"].tolist()
        processing_levels = dataspace_composite_products_all["processingLevel"].tolist()
        transformed_levels = ['Level-1C' if level == 'S2MSI1C' else 'Level-2A' for level in processing_levels]
        cloud_covers = dataspace_composite_products_all["cloudCover"].tolist()
        begin_positions = dataspace_composite_products_all["startDate"].tolist()
        statuses = dataspace_composite_products_all["status"].tolist()

        scihub_compatible_df = pd.DataFrame({"title": titles,
                                            "size": sizes,
                                            "beginposition": begin_positions,
                                            "relativeorbitnumber": relative_orbit_numbers,
                                            "cloudcoverpercentage": cloud_covers,
                                            "processinglevel": transformed_levels,
                                            "uuid": uuids,
                                            "status": statuses})

        # check granule sizes on the server
        scihub_compatible_df["size"] = scihub_compatible_df["size"].apply(lambda x: round(float(x) * 1e-6, 2))
        # reassign to match the scihub variable
        df_all = scihub_compatible_df


    if download_source == "scihub":

        try:
            composite_products_all = queries_and_downloads.check_for_s2_data_by_date(
                config_dict["tile_dir"],
                composite_start_date,
                composite_end_date,
                conf=credentials_dict,
                cloud_cover=cloud_cover,
                tile_id=tile_to_process,
                producttype=None,
            )

        except Exception as error:
            tile_log.error(
                f"check_for_s2_data_by_date failed, got this error :  {error}"
            )

        tile_log.info(
            "--> Found {} L1C and L2A products for the composite:".format(
                len(composite_products_all)
            )
        )

        df_all = pd.DataFrame.from_dict(composite_products_all, orient="index")

        # check granule sizes on the server
        df_all["size"] = (
            df_all["size"]
            .str.split(" ")
            .apply(lambda x: float(x[0]) * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]])
        )

    if download_source == "scihub":
        min_granule_size = faulty_granule_threshold
    else:
        min_granule_size = 0  # Required for dataspace API which doesn't report size correctly (often reported as zero)

    df = df_all.query("size >= " + str(min_granule_size))

    tile_log.info(
        "Removed {} faulty scenes <{}MB in size from the list".format(
            len(df_all) - len(df), min_granule_size
        )
    )
    # find < threshold sizes, report to log
    df_faulty = df_all.query("size < " + str(min_granule_size))
    for r in range(len(df_faulty)):
        tile_log.info(
            "   {} MB: {}".format(
                df_faulty.iloc[r, :]["size"], df_faulty.iloc[r, :]["title"]
            )
        )

    l1c_products = df[df.processinglevel == "Level-1C"]
    l2a_products = df[df.processinglevel == "Level-2A"]
    tile_log.info("    {} L1C products".format(l1c_products.shape[0]))
    tile_log.info("    {} L2A products".format(l2a_products.shape[0]))


    rel_orbits = np.unique(l1c_products["relativeorbitnumber"])
    if len(rel_orbits) > 0:
        if l1c_products.shape[0] > max_image_number / len(rel_orbits):
            tile_log.info(
                "Capping the number of L1C products to {}".format(max_image_number)
            )
            tile_log.info(
                "Relative orbits found covering tile: {}".format(rel_orbits)
            )
            tile_log.info("dataspace branch reaches here")
            uuids = []
            for orb in rel_orbits:
                uuids = uuids + list(
                    l1c_products.loc[
                        l1c_products["relativeorbitnumber"] == orb
                    ].sort_values(by=["cloudcoverpercentage"], ascending=True)[
                        "uuid"
                    ][
                        : int(max_image_number / len(rel_orbits))
                    ]
                )
            # keeps least cloudy n (max image number)
            l1c_products = l1c_products[l1c_products["uuid"].isin(uuids)]
            tile_log.info(
                "    {} L1C products remain:".format(l1c_products.shape[0])
            )
            for product in l1c_products["title"]:
                tile_log.info("       {}".format(product))
            tile_log.info(f"len of L1C products for dataspace is {len(l1c_products['title'])}")

    rel_orbits = np.unique(l2a_products["relativeorbitnumber"])
    if len(rel_orbits) > 0:
        if l2a_products.shape[0] > max_image_number / len(rel_orbits):
            tile_log.info(
                "Capping the number of L2A products to {}".format(max_image_number)
            )
            tile_log.info(
                "Relative orbits found covering tile: {}".format(rel_orbits)
            )
            uuids = []
            for orb in rel_orbits:
                uuids = uuids + list(
                    l2a_products.loc[
                        l2a_products["relativeorbitnumber"] == orb
                    ].sort_values(by=["cloudcoverpercentage"], ascending=True)[
                        "uuid"
                    ][
                        : int(max_image_number / len(rel_orbits))
                    ]
                )
            l2a_products = l2a_products[l2a_products["uuid"].isin(uuids)]
            tile_log.info(
                "    {} L2A products remain:".format(l2a_products.shape[0])
            )
            for product in l2a_products["title"]:
                tile_log.info("       {}".format(product))
            tile_log.info(f"len of L2A products for dataspace is {len(l2a_products['title'])}")

    if l1c_products.shape[0] > 0 and l2a_products.shape[0] > 0:
        tile_log.info(
            "Filtering out L1C products that have the same 'beginposition' time stamp as an existing L2A product."
        )
        if download_source == "scihub":
            (l1c_products,l2a_products,) = queries_and_downloads.filter_unique_l1c_and_l2a_data(df,log=tile_log)

        if download_source == "dataspace":
            l1c_products = queries_and_downloads.filter_unique_dataspace_products(l1c_products=l1c_products, l2a_products=l2a_products, log=tile_log)

    df = None
    tile_log.info(f" {len(l1c_products['title'])} L1C products for the Composite")
    tile_log.info(f" {len(l2a_products['title'])} L2A products for the Composite")
    
    tile_log.info("Successfully queried the L1C and L2A products for the Composite")
# Out:
# 2023-07-09 20:35:01,983: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:01,984: INFO: Creating an initial cloud-free median composite from Sentinel-2 as a baseline map
# 2023-07-09 20:35:01,984: INFO: ---------------------------------------------------------------
# 2023-07-09 20:35:01,985: INFO: Searching for images for initial composite.
# 2023-07-09 20:35:01,986: INFO: Path to the S2 tile geometry information absolute path: /home/sepal-user/pyeo_dir/pyeo_1/geometry/kenya_s2_tiles.shp
# 2023-07-09 20:35:30,063: INFO: Removed 0 faulty scenes <0MB in size from the list
# 2023-07-09 20:35:30,067: INFO:     36 L1C products
# 2023-07-09 20:35:30,068: INFO:     32 L2A products
# 2023-07-09 20:35:30,069: INFO: Capping the number of L1C products to 5
# 2023-07-09 20:35:30,070: INFO: Relative orbits found covering tile: [135]
# 2023-07-09 20:35:30,070: INFO: dataspace branch reaches here
# 2023-07-09 20:35:30,073: INFO:     5 L1C products remain:
# 2023-07-09 20:35:30,074: INFO:        S2B_MSIL1C_20220511T074609_N0400_R135_T36NXG_20220511T094754.SAFE
# 2023-07-09 20:35:30,075: INFO:        S2A_MSIL1C_20220307T074801_N0400_R135_T36NXG_20220307T091249.SAFE
# 2023-07-09 20:35:30,075: INFO:        S2A_MSIL1C_20220126T075211_N0400_R135_T36NXG_20220126T090631.SAFE
# 2023-07-09 20:35:30,076: INFO:        S2B_MSIL1C_20220312T074719_N0400_R135_T36NXG_20220312T094827.SAFE
# 2023-07-09 20:35:30,077: INFO:        S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:30,077: INFO: len of L1C products for dataspace is 5
# 2023-07-09 20:35:30,078: INFO: Capping the number of L2A products to 5
# 2023-07-09 20:35:30,079: INFO: Relative orbits found covering tile: [135]
# 2023-07-09 20:35:30,084: INFO:     5 L2A products remain:
# 2023-07-09 20:35:30,085: INFO:        S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE
# 2023-07-09 20:35:30,086: INFO:        S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE
# 2023-07-09 20:35:30,087: INFO:        S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE
# 2023-07-09 20:35:30,087: INFO:        S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE
# 2023-07-09 20:35:30,088: INFO:        S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE
# 2023-07-09 20:35:30,090: INFO: len of L2A products for dataspace is 5
# 2023-07-09 20:35:30,090: INFO: Filtering out L1C products that have the same 'beginposition' time stamp as an existing L2A product.
# 2023-07-09 20:35:30,091: INFO: Before filtering, 5 L1C and 5 L2A
# 2023-07-09 20:35:30,093: INFO: L1C : S2B_MSIL1C_20220511T074609_N0400_R135_T36NXG_20220511T094754.SAFE
# 2023-07-09 20:35:30,094: INFO: L1C : S2A_MSIL1C_20220307T074801_N0400_R135_T36NXG_20220307T091249.SAFE
# 2023-07-09 20:35:30,095: INFO: L1C : S2A_MSIL1C_20220126T075211_N0400_R135_T36NXG_20220126T090631.SAFE
# 2023-07-09 20:35:30,096: INFO: L1C : S2B_MSIL1C_20220312T074719_N0400_R135_T36NXG_20220312T094827.SAFE
# 2023-07-09 20:35:30,096: INFO: L1C : S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:30,098: INFO: L2A : S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE
# 2023-07-09 20:35:30,099: INFO: L2A : S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE
# 2023-07-09 20:35:30,100: INFO: L2A : S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE
# 2023-07-09 20:35:30,101: INFO: L2A : S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE
# 2023-07-09 20:35:30,102: INFO: L2A : S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE
# 2023-07-09 20:35:30,115: INFO: After filtering, 1 L1C and 5 L2A
# 2023-07-09 20:35:30,117: INFO: Unique L1C : S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:30,118: INFO: Unique L2A : S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE
# 2023-07-09 20:35:30,119: INFO: Unique L2A : S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE
# 2023-07-09 20:35:30,120: INFO: Unique L2A : S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE
# 2023-07-09 20:35:30,120: INFO: Unique L2A : S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE
# 2023-07-09 20:35:30,121: INFO: Unique L2A : S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE
# 2023-07-09 20:35:30,122: INFO:  1 L1C products for the Composite
# 2023-07-09 20:35:30,123: INFO:  5 L2A products for the Composite
# 2023-07-09 20:35:30,123: INFO: Successfully queried the L1C and L2A products for the Composite

# %% [markdown]
# ### <a id='toc3_2_1_'></a>[Search for L2A Images Corresponding to L1C](#toc0_)

# %% [markdown]
# - The cell below searches our download directory for any existing imagery. If we have downloaded any imagery already, `pyeo_1` will remove the matching image from our search query.
#
# - Secondly, if we have opted to use `scihub` as our `download_source`, then `pyeo_1` searches the Copernicus archive for any corresponding `L2A` products. If it finds a matching L2A product, then it removes the `L1C` counterpart from the query. The `dataspace` option handles this on the server.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    # Search the local directories, composite/L2A and L1C, checking if scenes have already been downloaded and/or processed whilst checking their dir sizes
    if download_source == "scihub":
        if sen2cor_path == "none":
            tile_log.info("Sen2Cor path is not specified. Skipping L1C download and processing.")
            l1c_products = pd.dataframe() # reset the dataframe of L1C products to an empty dataframe to skip download
        else:
            if l1c_products.shape[0] > 0:
                tile_log.info(
                    "Checking for already downloaded and zipped L1C or L2A products and"
                )
                tile_log.info("  availability of matching L2A products for download.")
                n = len(l1c_products)
                drop = []
                add = []
                for r in range(n):
                    id = l1c_products.iloc[r, :]["title"]
                    search_term = (
                        id.split("_")[2]
                        + "_"
                        + id.split("_")[3]
                        + "_"
                        + id.split("_")[4]
                        + "_"
                        + id.split("_")[5]
                    )
                    tile_log.info(
                        "Searching locally for file names containing: {}.".format(
                            search_term
                        )
                    )
                    file_list = (
                        [
                            os.path.join(composite_l1_image_dir, f)
                            for f in os.listdir(composite_l1_image_dir)
                        ]
                        + [
                            os.path.join(composite_l2_image_dir, f)
                            for f in os.listdir(composite_l2_image_dir)
                        ]
                        + [
                            os.path.join(composite_l2_masked_image_dir, f)
                            for f in os.listdir(composite_l2_masked_image_dir)
                        ]
                    )
                    for f in file_list:
                        if search_term in f:
                            tile_log.info("  Product already downloaded: {}".format(f))
                            drop.append(l1c_products.index[r])
                    search_term = (
                        "*"
                        + id.split("_")[2]
                        + "_"
                        + id.split("_")[3]
                        + "_"
                        + id.split("_")[4]
                        + "_"
                        + id.split("_")[5]
                        + "*"
                    )


                    tile_log.info(
                        "Searching on the data hub for files containing: {}.".format(
                            search_term
                        )
                    )
                    matching_l2a_products = queries_and_downloads._file_api_query(
                        user=sen_user,
                        passwd=sen_pass,
                        start_date=composite_start_date,
                        end_date=composite_end_date,
                        filename=search_term,
                        cloud=cloud_cover,
                        producttype="S2MSI2A",
                    )

                    matching_l2a_products_df = pd.DataFrame.from_dict(
                        matching_l2a_products, orient="index"
                    )
                    # 07/03/2023: Matt - Applied Ali's fix for converting product size to MB to compare against faulty_grandule_threshold
                    if (
                        len(matching_l2a_products_df) == 1
                        and [
                            float(x[0]) * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]]
                            for x in [matching_l2a_products_df["size"][0].split(" ")]
                        ][0]
                        > faulty_granule_threshold
                    ):
                        tile_log.info("Replacing L1C {} with L2A product:".format(id))
                        tile_log.info(
                            "              {}".format(
                                matching_l2a_products_df.iloc[0, :]["title"]
                            )
                        )

                        drop.append(l1c_products.index[r])
                        add.append(matching_l2a_products_df.iloc[0, :])
                    if len(matching_l2a_products_df) == 0:
                        pass
                    if len(matching_l2a_products_df) > 1:
                        # check granule sizes on the server
                        matching_l2a_products_df["size"] = (
                            matching_l2a_products_df["size"]
                            .str.split(" ")
                            .apply(
                                lambda x: float(x[0])
                                * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]]
                            )
                        )
                        matching_l2a_products_df = matching_l2a_products_df.query(
                            "size >= " + str(faulty_granule_threshold)
                        )
                        if (
                            matching_l2a_products_df.iloc[0, :]["size"]
                            .str.split(" ")
                            .apply(
                                lambda x: float(x[0])
                                * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]]
                            )
                            > faulty_granule_threshold
                        ):
                            tile_log.info("Replacing L1C {} with L2A product:".format(id))
                            tile_log.info(
                                "              {}".format(
                                    matching_l2a_products_df.iloc[0, :]["title"]
                                )
                            )
                            drop.append(l1c_products.index[r])
                            add.append(matching_l2a_products_df.iloc[0, :])
                if len(drop) > 0:
                    l1c_products = l1c_products.drop(index=drop)
                if len(add) > 0:
                    # l2a_products = l2a_products.append(add)
                    add = pd.DataFrame(add)
                    l2a_products = pd.concat([l2a_products, add])

                tile_log.info("\n Successfully searched for the L2A counterparts for the L1C products for the Composite")
        
    # here, dataspace and scihub derived l1c_products and l2a_products lists are the "same"
    l2a_products = l2a_products.drop_duplicates(subset="title")
    tile_log.info(
        "    {} L1C products remaining for download".format(
            l1c_products.shape[0]
        )
    )
    tile_log.info(
        "    {} L2A products remaining for download".format(
            l2a_products.shape[0]
        )
    )

    tile_log.info("Cell successfully finished")
# Out:
# 2023-07-09 20:35:30,150: INFO:     1 L1C products remaining for download
# 2023-07-09 20:35:30,151: INFO:     5 L2A products remaining for download
# 2023-07-09 20:35:30,152: INFO: Cell successfully finished

# %% [markdown]
# ## <a id='toc3_3_'></a>[Download Sentinel-2 Composite Imagery](#toc0_)

# %% [markdown]
# ### <a id='toc3_3_1_'></a>[Download and Process L1Cs](#toc0_)

# %% [markdown]
# - From the `log` output above in the previous section, we can see that `pyeo_1` has found a matching `L2A` image for each of the `L1Cs` in our search query. So now we have only L2As in our search query.
#
# - If we did have `L1Cs` in our search query, then the cell below would download these L1Cs and apply `atmospheric_correction` using `Sen2Cor`.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if l1c_products.shape[0] > 0:
        tile_log.info(f"Downloading Sentinel-2 L1C products from {download_source}:")

        if download_source == "scihub":

            queries_and_downloads.download_s2_data_from_df(
                l1c_products,
                composite_l1_image_dir,
                composite_l2_image_dir,
                source="scihub",
                user=sen_user,
                passwd=sen_pass,
                try_scihub_on_fail=True,
            )

        if download_source == "dataspace":

            queries_and_downloads.download_s2_data_from_dataspace(
                product_df=l1c_products,
                l1c_directory=composite_l1_image_dir,
                l2a_directory=composite_l2_image_dir,
                dataspace_username=sen_user,
                dataspace_password=sen_pass,
                log=tile_log
            )
            
        # if we have downloaded L1C products, we need to run Sen2Cor to convert them to L2A
        tile_log.info("Atmospheric correction with sen2cor.")
        raster_manipulation.atmospheric_correction(
            composite_l1_image_dir,
            composite_l2_image_dir,
            sen2cor_path,
            gipp_path,
            delete_unprocessed_image=False,
            log=tile_log,
        )

        tile_log.info("Successfully downloaded the Sentinel-2 L1C products")
# Out:
# 2023-07-09 20:35:30,217: INFO: Downloading Sentinel-2 L1C products from dataspace:
# 2023-07-09 20:35:30,219: INFO:     Checking 1 of 1 : S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:30,229: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L1C/S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE imagery already exists, skipping download
# 2023-07-09 20:35:30,230: INFO: Atmospheric correction with sen2cor.
# 2023-07-09 20:35:30,231: INFO:    image path = /home/sepal-user/pyeo_dir/36NXG/composite/L1C/S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:30,232: INFO:    out_directory = /home/sepal-user/pyeo_dir/36NXG/composite/L2A
# 2023-07-09 20:35:48,742: INFO:    out name = /home/sepal-user/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:48,744: INFO:    out path = /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:48,745: INFO:    out glob = /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG*
# 2023-07-09 20:35:48,746: INFO: Atmospheric correction of S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:51,103: INFO: Calling sen2cor:
# 2023-07-09 20:35:51,105: INFO: /home/sepal-user/Sen2Cor-02.10.01-Linux64/bin/L2A_Process --GIP_L2A /home/sepal-user/sen2cor/2.10/cfg/L2A_GIPP.xml /home/sepal-user/pyeo_dir/36NXG/composite/L1C/S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE --output_dir /home/sepal-user/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 20:35:55,259: INFO: Sen2Cor. Version: 02.10.01, created: 2021.12.13, supporting Level-1C product version 14.2 - 14.9 started ...
#
# 2023-07-09 20:35:55,261: INFO: Product version: 14.9
#
# 2023-07-09 20:35:55,262: INFO: Operation mode: TOOLBOX
#
# 2023-07-09 20:35:55,266: INFO: Processing baseline: 99.99
#
# 2023-07-09 20:35:55,296: INFO: Progress[%]:  0.00 : Generating datastrip metadata
#
# 2023-07-09 20:35:58,310: INFO: L2A datastrip successfully generated
#
# 2023-07-09 20:35:58,639: INFO: No resolution specified, will process 20 and 10 m resolution
#
# 2023-07-09 20:35:58,640: INFO: 20 m resolution will be downsampled to 60 m
#
# 2023-07-09 20:36:01,049: INFO: Progress[%]: 0.09 : PID-13264, L2A_ProcessTile: processing with resolution 20 m, elapsed time[s]: 2.413, total: 0:00:07.819841
#
# 2023-07-09 20:36:01,061: INFO: Progress[%]: 0.10 : PID-13264, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.012, total: 0:00:07.831902
#
# 2023-07-09 20:36:01,158: INFO: Progress[%]: 0.10 : PID-13264, L2A_Tables: start import, elapsed time[s]: 0.097, total: 0:00:07.928888
#
# 2023-07-09 20:36:02,410: INFO: Progress[%]: 0.15 : PID-13264, L2A_Tables: band B01 imported, elapsed time[s]: 1.251, total: 0:00:09.180029
#
# 2023-07-09 20:36:08,118: INFO: Progress[%]: 0.37 : PID-13264, L2A_Tables: band B02 imported, elapsed time[s]: 5.709, total: 0:00:14.888796
#
# 2023-07-09 20:36:15,297: INFO: Progress[%]: 0.65 : PID-13264, L2A_Tables: band B03 imported, elapsed time[s]: 7.179, total: 0:00:22.068192
#
# 2023-07-09 20:36:23,242: INFO: Progress[%]: 0.96 : PID-13264, L2A_Tables: band B04 imported, elapsed time[s]: 7.943, total: 0:00:30.010811
#
# 2023-07-09 20:36:27,774: INFO: Progress[%]: 1.14 : PID-13264, L2A_Tables: band B05 imported, elapsed time[s]: 4.533, total: 0:00:34.544213
#
# 2023-07-09 20:36:31,363: INFO: Progress[%]: 1.28 : PID-13264, L2A_Tables: band B06 imported, elapsed time[s]: 3.589, total: 0:00:38.133436
#
# 2023-07-09 20:36:34,902: INFO: Progress[%]: 1.42 : PID-13264, L2A_Tables: band B07 imported, elapsed time[s]: 3.539, total: 0:00:41.672392
#
# 2023-07-09 20:36:38,470: INFO: Progress[%]: 1.56 : PID-13264, L2A_Tables: band B8A imported, elapsed time[s]: 3.568, total: 0:00:45.240445
#
# 2023-07-09 20:36:39,580: INFO: Progress[%]: 1.61 : PID-13264, L2A_Tables: band B09 imported, elapsed time[s]: 1.110, total: 0:00:46.350534
#
# 2023-07-09 20:36:41,520: INFO: Progress[%]: 1.68 : PID-13264, L2A_Tables: band B10 imported, elapsed time[s]: 1.940, total: 0:00:48.290244
#
# 2023-07-09 20:36:44,997: INFO: Progress[%]: 1.82 : PID-13264, L2A_Tables: band B11 imported, elapsed time[s]: 3.477, total: 0:00:51.767582
#
# 2023-07-09 20:36:48,647: INFO: Progress[%]: 1.96 : PID-13264, L2A_Tables: band B12 imported, elapsed time[s]: 3.650, total: 0:00:55.417518
#
# 2023-07-09 20:36:48,865: INFO: Progress[%]: 1.97 : PID-13264, L2A_Tables: AUX_CAMS* file found., elapsed time[s]: 0.218, total: 0:00:55.635817
#
# 2023-07-09 20:37:02,067: INFO: Progress[%]: 2.49 : PID-13264, L2A_Tables: Visibility map from file AUX_CAMSFO prepared, elapsed time[s]: 13.201, total: 0:01:08.837260
#
# 2023-07-09 20:37:02,092: INFO: Progress[%]: 2.49 : PID-13264, L2A_ProcessTile: start of Scene Classification, elapsed time[s]: 0.025, total: 0:01:08.862683
#
# 2023-07-09 20:37:04,214: INFO: Progress[%]: 2.57 : PID-13264, L2A_Tables: band B02 must be resampled, elapsed time[s]: 2.122, total: 0:01:10.984320
#
# 2023-07-09 20:37:06,428: INFO: Progress[%]: 2.66 : PID-13264, Pre process   , elapsed time[s]: 2.214, total: 0:01:13.198728
#
# 2023-07-09 20:37:06,491: INFO: Progress[%]: 2.66 : PID-13264, L2A_Tables: band B01 must be resampled, elapsed time[s]: 0.063, total: 0:01:13.261450
#
# 2023-07-09 20:37:12,137: INFO: Progress[%]: 2.88 : PID-13264, L2A_Tables: band B03 must be resampled, elapsed time[s]: 5.646, total: 0:01:18.907948
#
# 2023-07-09 20:37:14,994: INFO: Progress[%]: 2.99 : PID-13264, L2A_Tables: band B04 must be resampled, elapsed time[s]: 2.856, total: 0:01:21.764085
#
# 2023-07-09 20:37:18,273: INFO: Progress[%]: 3.12 : PID-13264, L2A_Tables: band B09 must be resampled, elapsed time[s]: 3.280, total: 0:01:25.044271
#
# 2023-07-09 20:37:20,585: INFO: Progress[%]: 3.21 : PID-13264, L2A_Tables: band B10 must be resampled, elapsed time[s]: 2.312, total: 0:01:27.356223
#
# 2023-07-09 20:37:23,419: INFO: Progress[%]: 3.32 : PID-13264, L2A_SC init   , elapsed time[s]: 2.832, total: 0:01:30.188100
#
# 2023-07-09 20:37:24,546: INFO: Progress[%]: 3.37 : PID-13264, L2A_CSND_1_1  , elapsed time[s]: 1.128, total: 0:01:31.316246
#
# 2023-07-09 20:37:25,773: INFO: Progress[%]: 3.42 : PID-13264, L2A_CSND_1_2  , elapsed time[s]: 1.227, total: 0:01:32.543155
#
# 2023-07-09 20:37:26,487: INFO: Progress[%]: 3.45 : PID-13264, L2A_CSND_2_0  , elapsed time[s]: 0.715, total: 0:01:33.257844
#
# 2023-07-09 20:37:27,457: INFO: Progress[%]: 3.48 : PID-13264, L2A_CSND_2_1  , elapsed time[s]: 0.970, total: 0:01:34.228059
#
# 2023-07-09 20:37:27,970: INFO: Progress[%]: 3.50 : PID-13264, L2A_CSND_2_1_2, elapsed time[s]: 0.512, total: 0:01:34.739876
#
# 2023-07-09 20:37:28,378: INFO: Progress[%]: 3.52 : PID-13264, L2A_CSND_2_2  , elapsed time[s]: 0.408, total: 0:01:35.148213
#
# 2023-07-09 20:37:29,119: INFO: Progress[%]: 3.55 : PID-13264, L2A_CSND_2_3  , elapsed time[s]: 0.741, total: 0:01:35.889585
#
# 2023-07-09 20:37:30,061: INFO: Progress[%]: 3.59 : PID-13264, L2A_CSND_2_4  , elapsed time[s]: 0.941, total: 0:01:36.831027
#
# 2023-07-09 20:37:32,131: INFO: Progress[%]: 3.67 : PID-13264, L2A_CSND_2_5  , elapsed time[s]: 2.070, total: 0:01:38.901097
#
# 2023-07-09 20:37:32,145: INFO: Progress[%]: 3.67 : PID-13264, L2A_SnowPostProcessingCCI  , elapsed time[s]: 0.015, total: 0:01:38.916041
#
# 2023-07-09 20:37:33,902: INFO: Progress[%]: 3.74 : PID-13264, L2A_CSND_3    , elapsed time[s]: 1.757, total: 0:01:40.672629
#
# 2023-07-09 20:37:35,309: INFO: Progress[%]: 3.79 : PID-13264, L2A_CSND_5_1  , elapsed time[s]: 1.407, total: 0:01:42.079894
#
# 2023-07-09 20:37:37,264: INFO: Progress[%]: 3.87 : PID-13264, L2A_CSND_5_2  , elapsed time[s]: 1.955, total: 0:01:44.034588
#
# 2023-07-09 20:37:38,788: INFO: Progress[%]: 3.93 : PID-13264, L2A_CSND_6    , elapsed time[s]: 1.524, total: 0:01:45.558958
#
# 2023-07-09 20:37:39,768: INFO: Progress[%]: 3.97 : PID-13264, L2A_CSND_6_2  , elapsed time[s]: 0.979, total: 0:01:46.538411
#
# 2023-07-09 20:37:41,160: INFO: Progress[%]: 4.02 : PID-13264, L2A_CSND_7    , elapsed time[s]: 1.393, total: 0:01:47.931061
#
# 2023-07-09 20:37:42,430: INFO: Progress[%]: 4.07 : PID-13264, DV recovery   , elapsed time[s]: 1.270, total: 0:01:49.200945
#
# 2023-07-09 20:37:43,790: INFO: Progress[%]: 4.12 : PID-13264, WP recovery   , elapsed time[s]: 1.360, total: 0:01:50.560849
#
# 2023-07-09 20:37:43,804: INFO: Progress[%]: 4.12 : PID-13264, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.014, total: 0:01:50.575057
#
# 2023-07-09 20:37:46,004: INFO: Progress[%]: 4.21 : PID-13264, Snow recovery , elapsed time[s]: 2.200, total: 0:01:52.774929
#
# 2023-07-09 20:37:52,776: INFO: Progress[%]: 4.48 : PID-13264, SnowSoilBorders, elapsed time[s]: 6.772, total: 0:01:59.546849
#
# 2023-07-09 20:37:53,512: INFO: Progress[%]: 4.50 : PID-13264, Soil recovery , elapsed time[s]: 0.735, total: 0:02:00.282190
#
# 2023-07-09 20:37:53,525: INFO: Progress[%]: 4.51 : PID-13264, Cirrus recovery with B10 , elapsed time[s]: 0.014, total: 0:02:00.296288
#
# 2023-07-09 20:37:53,539: INFO: Progress[%]: 4.51 : PID-13264, Urban and Bare pixel recovery with CCI Land Cover Map at 300 m , elapsed time[s]: 0.014, total: 0:02:00.310037
#
# 2023-07-09 20:38:09,297: INFO: Progress[%]: 5.12 : PID-13264, Bright pixels Hollstein Fmask, elapsed time[s]: 15.757, total: 0:02:16.066840
#
# 2023-07-09 20:39:53,749: INFO: Cloud heights processed in 0:00:28.090349 seconds
#
# 2023-07-09 20:39:53,751: INFO: Progress[%]: 9.22 : PID-13264, L2A_SHD       , elapsed time[s]: 104.451, total: 0:04:00.517434
#
# 2023-07-09 20:39:53,763: INFO: Progress[%]: 9.22 : PID-13264, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.016, total: 0:04:00.533804
#
# 2023-07-09 20:39:56,140: INFO: Progress[%]: 9.31 : PID-13264, Topographic casted shadow Pixels post processing, elapsed time[s]: 2.377, total: 0:04:02.910812
#
# 2023-07-09 20:39:57,083: INFO: Progress[%]: 9.35 : PID-13264, Post process  , elapsed time[s]: 0.943, total: 0:04:03.853559
#
# 2023-07-09 20:39:57,269: INFO: Progress[%]: 9.36 : PID-13264, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 0.187, total: 0:04:04.040098
#
# 2023-07-09 20:39:58,655: INFO: Progress[%]: 9.41 : PID-13264, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 1.385, total: 0:04:05.425505
#
# 2023-07-09 20:39:58,666: INFO: Progress[%]: 9.41 : PID-13264, L2A_AtmCorr: start of AOT retrieval at 550nm, elapsed time[s]: 0.012, total: 0:04:05.437039
#
# 2023-07-09 20:40:04,827: INFO: Progress[%]: 9.65 : PID-13264, L2A_AtmCorr: end of internal classification, elapsed time[s]: 6.161, total: 0:04:11.597563
#
# 2023-07-09 20:40:05,711: INFO: Progress[%]: 9.69 : PID-13264, L2A_AtmCorr: end of interpolation LUTs, elapsed time[s]: 0.884, total: 0:04:12.481468
#
# 2023-07-09 20:40:28,202: INFO: Progress[%]: 10.57 : PID-13264, L2A_AtmCorr: end retrieving reference pixels for dark areas, elapsed time[s]: 22.492, total: 0:04:34.973177
#
# 2023-07-09 20:42:17,471: INFO: Progress[%]: 14.86 : PID-13264, L2A_AtmCorr: end of check for negative reflectance pixels, elapsed time[s]: 109.267, total: 0:06:24.240081
#
# 2023-07-09 20:42:20,706: INFO: Progress[%]: 14.98 : PID-13264, L2A_AtmCorr: the rescaling of path radiance in blue band has been disabled by configuration, elapsed time[s]: 3.236, total: 0:06:27.476435
#
# 2023-07-09 20:43:19,696: INFO: Progress[%]: 17.30 : PID-13264, L2A_AtmCorr: end of visibility index calculation, elapsed time[s]: 58.988, total: 0:07:26.464363
#
# 2023-07-09 20:43:19,708: INFO: Progress[%]: 17.30 : PID-13264, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 0.015, total: 0:07:26.478983
#
# 2023-07-09 20:43:19,718: INFO: Progress[%]: 17.30 : PID-13264, L2A_AtmCorr: start of water vapour retrieval, elapsed time[s]: 0.010, total: 0:07:26.488982
#
# 2023-07-09 20:43:21,062: INFO: Progress[%]: 17.35 : PID-13264, L2A_AtmCorr: end of water vapour retrieval preparation, elapsed time[s]: 1.344, total: 0:07:27.833023
#
# 2023-07-09 20:46:37,118: INFO: Progress[%]: 25.04 : PID-13264, L2A_AtmCorr: end of water vapour retrieval, elapsed time[s]: 196.054, total: 0:10:43.886775
#
# 2023-07-09 20:46:37,135: INFO: Progress[%]: 25.04 : PID-13264, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.015, total: 0:10:43.901559
#
# 2023-07-09 20:46:44,171: INFO: Progress[%]: 25.32 : PID-13264, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 7.040, total: 0:10:50.941450
#
# 2023-07-09 20:46:44,183: INFO: Progress[%]: 25.32 : PID-13264, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.013, total: 0:10:50.954002
#
# 2023-07-09 20:49:13,435: INFO: Progress[%]: 31.17 : PID-13264, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 149.249, total: 0:13:20.203409
#
# 2023-07-09 20:49:13,452: INFO: Progress[%]: 31.17 : PID-13264, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.020, total: 0:13:20.223259
#
# 2023-07-09 20:50:17,294: INFO: Progress[%]: 33.67 : PID-13264, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 63.840, total: 0:14:24.063135
#
# 2023-07-09 20:50:17,339: INFO: Progress[%]: 33.67 : PID-13264, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.047, total: 0:14:24.109682
#
# 2023-07-09 20:50:18,883: INFO: Progress[%]: 33.74 : PID-13264, L2A_Tables: start export for 20 m resolution, elapsed time[s]: 1.544, total: 0:14:25.653401
#
# 2023-07-09 20:50:25,059: INFO: Progress[%]: 33.98 : PID-13264, L2A_Tables: band B01 exported, elapsed time[s]: 6.176, total: 0:14:31.829690
#
# 2023-07-09 20:50:35,406: INFO: Progress[%]: 34.38 : PID-13264, L2A_Tables: band B02 exported, elapsed time[s]: 10.347, total: 0:14:42.176967
#
# 2023-07-09 20:50:46,212: INFO: Progress[%]: 34.81 : PID-13264, L2A_Tables: band B03 exported, elapsed time[s]: 10.806, total: 0:14:52.982675
#
# 2023-07-09 20:50:57,077: INFO: Progress[%]: 35.23 : PID-13264, L2A_Tables: band B04 exported, elapsed time[s]: 10.865, total: 0:15:03.847652
#
# 2023-07-09 20:51:08,003: INFO: Progress[%]: 35.66 : PID-13264, L2A_Tables: band B05 exported, elapsed time[s]: 10.926, total: 0:15:14.773649
#
# 2023-07-09 20:51:19,564: INFO: Progress[%]: 36.11 : PID-13264, L2A_Tables: band B06 exported, elapsed time[s]: 11.559, total: 0:15:26.332924
#
# 2023-07-09 20:51:31,320: INFO: Progress[%]: 36.58 : PID-13264, L2A_Tables: band B07 exported, elapsed time[s]: 11.758, total: 0:15:38.090946
#
# 2023-07-09 20:51:42,904: INFO: Progress[%]: 37.03 : PID-13264, L2A_Tables: band B8A exported, elapsed time[s]: 11.584, total: 0:15:49.675002
#
# 2023-07-09 20:51:53,601: INFO: Progress[%]: 37.45 : PID-13264, L2A_Tables: band B11 exported, elapsed time[s]: 10.696, total: 0:16:00.371476
#
# 2023-07-09 20:52:04,268: INFO: Progress[%]: 37.87 : PID-13264, L2A_Tables: band B12 exported, elapsed time[s]: 10.667, total: 0:16:11.038943
#
# 2023-07-09 20:52:05,580: INFO: Progress[%]: 37.92 : PID-13264, L2A_Tables: band SCL exported, elapsed time[s]: 1.312, total: 0:16:12.350972
#
# 2023-07-09 20:52:06,246: INFO: Progress[%]: 37.95 : PID-13264, L2A_Tables: band SNW exported, elapsed time[s]: 0.666, total: 0:16:13.017295
#
# 2023-07-09 20:52:07,341: INFO: Progress[%]: 37.99 : PID-13264, L2A_Tables: band CLD exported, elapsed time[s]: 1.095, total: 0:16:14.112266
#
# 2023-07-09 20:52:08,765: INFO: Progress[%]: 38.04 : PID-13264, L2A_Tables: band AOT exported, elapsed time[s]: 1.424, total: 0:16:15.536310
#
# 2023-07-09 20:52:18,781: INFO: Progress[%]: 38.44 : PID-13264, L2A_Tables: band WVP exported, elapsed time[s]: 10.016, total: 0:16:25.552009
#
# 2023-07-09 20:52:19,669: INFO: Progress[%]: 38.47 : PID-13264, L2A_Tables: band VIS exported, elapsed time[s]: 0.886, total: 0:16:26.437632
#
# 2023-07-09 20:52:21,458: INFO: Progress[%]: 38.54 : PID-13264, L2A_Tables: band PVI exported, elapsed time[s]: 1.791, total: 0:16:28.228974
#
# 2023-07-09 20:52:41,308: INFO: Progress[%]: 39.32 : PID-13264, L2A_Tables: band TCI exported, elapsed time[s]: 19.850, total: 0:16:48.078795
#
# 2023-07-09 20:52:41,328: INFO: Progress[%]: 39.32 : PID-13264, L2A_Tables: stop export, elapsed time[s]: 0.020, total: 0:16:48.099213
#
# 2023-07-09 20:52:41,343: INFO: Progress[%]: 39.32 : PID-13264, L2A_Tables: preparing downsampled export for 60 m resolution, elapsed time[s]: 0.015, total: 0:16:48.114033
#
# 2023-07-09 20:52:41,358: INFO: Progress[%]: 39.32 : PID-13264, L2A_Tables: start export for 60 m resolution, elapsed time[s]: 0.015, total: 0:16:48.129438
#
# 2023-07-09 20:52:43,224: INFO: Progress[%]: 39.40 : PID-13264, L2A_Tables: band B01 exported, elapsed time[s]: 1.866, total: 0:16:49.994988
#
# 2023-07-09 20:52:44,953: INFO: Progress[%]: 39.46 : PID-13264, L2A_Tables: band B02 exported, elapsed time[s]: 1.729, total: 0:16:51.724102
#
# 2023-07-09 20:52:47,198: INFO: Progress[%]: 39.55 : PID-13264, L2A_Tables: band B03 exported, elapsed time[s]: 2.244, total: 0:16:53.968459
#
# 2023-07-09 20:52:49,435: INFO: Progress[%]: 39.64 : PID-13264, L2A_Tables: band B04 exported, elapsed time[s]: 2.237, total: 0:16:56.205459
#
# 2023-07-09 20:52:51,694: INFO: Progress[%]: 39.73 : PID-13264, L2A_Tables: band B05 exported, elapsed time[s]: 2.259, total: 0:16:58.464937
#
# 2023-07-09 20:52:53,904: INFO: Progress[%]: 39.81 : PID-13264, L2A_Tables: band B06 exported, elapsed time[s]: 2.210, total: 0:17:00.674717
#
# 2023-07-09 20:52:56,203: INFO: Progress[%]: 39.90 : PID-13264, L2A_Tables: band B07 exported, elapsed time[s]: 2.299, total: 0:17:02.973978
#
# 2023-07-09 20:52:58,467: INFO: Progress[%]: 39.99 : PID-13264, L2A_Tables: band B8A exported, elapsed time[s]: 2.264, total: 0:17:05.237962
#
# 2023-07-09 20:53:00,747: INFO: Progress[%]: 40.08 : PID-13264, L2A_Tables: band B09 exported, elapsed time[s]: 2.280, total: 0:17:07.517991
#
# 2023-07-09 20:53:02,947: INFO: Progress[%]: 40.17 : PID-13264, L2A_Tables: band B11 exported, elapsed time[s]: 2.200, total: 0:17:09.718074
#
# 2023-07-09 20:53:05,113: INFO: Progress[%]: 40.25 : PID-13264, L2A_Tables: band B12 exported, elapsed time[s]: 2.166, total: 0:17:11.884289
#
# 2023-07-09 20:53:07,800: INFO: Progress[%]: 40.36 : PID-13264, L2A_Tables: band SCL exported, elapsed time[s]: 2.686, total: 0:17:14.570589
#
# 2023-07-09 20:53:08,305: INFO: Progress[%]: 40.38 : PID-13264, L2A_Tables: band SNW exported, elapsed time[s]: 0.505, total: 0:17:15.075982
#
# 2023-07-09 20:53:08,890: INFO: Progress[%]: 40.40 : PID-13264, L2A_Tables: band CLD exported, elapsed time[s]: 0.585, total: 0:17:15.660534
#
# 2023-07-09 20:53:09,676: INFO: Progress[%]: 40.43 : PID-13264, L2A_Tables: band AOT exported, elapsed time[s]: 0.786, total: 0:17:16.446983
#
# 2023-07-09 20:53:11,655: INFO: Progress[%]: 40.51 : PID-13264, L2A_Tables: band WVP exported, elapsed time[s]: 1.979, total: 0:17:18.426173
#
# 2023-07-09 20:53:11,670: INFO: Progress[%]: 40.51 : PID-13264, L2A_Tables: band TCI must be resampled, elapsed time[s]: 0.015, total: 0:17:18.441067
#
# 2023-07-09 20:53:14,913: INFO: Progress[%]: 40.64 : PID-13264, L2A_Tables: band TCI exported, elapsed time[s]: 3.243, total: 0:17:21.683863
#
# 2023-07-09 20:53:19,011: INFO: Progress[%]: 40.80 : PID-13264, L2A_ProcessTile: processing with resolution 10 m, elapsed time[s]: 4.098, total: 0:17:25.781591
#
# 2023-07-09 20:53:19,022: INFO: Progress[%]: 40.80 : PID-13264, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.012, total: 0:17:25.793276
#
# 2023-07-09 20:53:19,111: INFO: Progress[%]: 40.80 : PID-13264, L2A_Tables: remove unused bands for 10m resolution, elapsed time[s]: 0.089, total: 0:17:25.882073
#
# 2023-07-09 20:53:19,873: INFO: Progress[%]: 40.83 : PID-13264, L2A_Tables: start import, elapsed time[s]: 0.760, total: 0:17:26.642483
#
# 2023-07-09 20:53:26,024: INFO: Progress[%]: 41.07 : PID-13264, L2A_Tables: band B08 imported, elapsed time[s]: 6.152, total: 0:17:32.794748
#
# 2023-07-09 20:53:27,264: INFO: Progress[%]: 41.12 : PID-13264, L2A_Tables: band SCL needs to be resampled, elapsed time[s]: 1.240, total: 0:17:34.034706
#
# 2023-07-09 20:53:30,369: INFO: Progress[%]: 41.24 : PID-13264, L2A_Tables: band SCL imported, elapsed time[s]: 3.105, total: 0:17:37.139627
#
# 2023-07-09 20:53:31,551: INFO: Progress[%]: 41.29 : PID-13264, L2A_Tables: band AOT needs to be resampled, elapsed time[s]: 1.182, total: 0:17:38.321448
#
# 2023-07-09 20:53:34,702: INFO: Progress[%]: 41.41 : PID-13264, L2A_Tables: band AOT imported, elapsed time[s]: 3.151, total: 0:17:41.472243
#
# 2023-07-09 20:53:35,857: INFO: Progress[%]: 41.46 : PID-13264, L2A_Tables: band WVP needs to be resampled, elapsed time[s]: 1.155, total: 0:17:42.627482
#
# 2023-07-09 20:53:39,029: INFO: Progress[%]: 41.58 : PID-13264, L2A_Tables: band WVP imported, elapsed time[s]: 3.172, total: 0:17:45.799253
#
# 2023-07-09 20:53:40,212: INFO: Progress[%]: 41.63 : PID-13264, L2A_Tables: band VIS needs to be resampled, elapsed time[s]: 1.183, total: 0:17:46.982621
#
# 2023-07-09 20:53:43,383: INFO: Progress[%]: 41.75 : PID-13264, L2A_Tables: band VIS imported, elapsed time[s]: 3.171, total: 0:17:50.153926
#
# 2023-07-09 20:53:45,455: INFO: Progress[%]: 41.84 : PID-13264, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 2.071, total: 0:17:52.225127
#
# 2023-07-09 20:53:50,977: INFO: Progress[%]: 42.05 : PID-13264, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 5.522, total: 0:17:57.747162
#
# 2023-07-09 20:53:50,989: INFO: Progress[%]: 42.05 : PID-13264, L2A_AtmCorr: start of resampling visibility for 10 m resolution, elapsed time[s]: 0.013, total: 0:17:57.759754
#
# 2023-07-09 20:53:52,395: INFO: Progress[%]: 42.11 : PID-13264, L2A_AtmCorr: end of resampling visibility for 10 m resolution, elapsed time[s]: 1.406, total: 0:17:59.165565
#
# 2023-07-09 20:53:54,264: INFO: Progress[%]: 42.18 : PID-13264, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 1.869, total: 0:18:01.034099
#
# 2023-07-09 20:53:54,275: INFO: Progress[%]: 42.18 : PID-13264, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.011, total: 0:18:01.045549
#
# 2023-07-09 20:53:58,385: INFO: Progress[%]: 42.34 : PID-13264, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 4.110, total: 0:18:05.155304
#
# 2023-07-09 20:53:58,396: INFO: Progress[%]: 42.34 : PID-13264, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.012, total: 0:18:05.167435
#
# 2023-07-09 20:57:45,570: INFO: Progress[%]: 51.25 : PID-13264, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 227.171, total: 0:21:52.338637
#
# 2023-07-09 20:57:45,596: INFO: Progress[%]: 51.25 : PID-13264, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.028, total: 0:21:52.366838
#
# 2023-07-09 21:01:03,464: INFO: Progress[%]: 59.01 : PID-13264, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 197.866, total: 0:25:10.232473
#
# 2023-07-09 21:01:03,517: INFO: Progress[%]: 59.01 : PID-13264, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.055, total: 0:25:10.287952
#
# 2023-07-09 21:01:03,530: INFO: Progress[%]: 59.02 : PID-13264, L2A_Tables: start export for 10 m resolution, elapsed time[s]: 0.013, total: 0:25:10.301058
#
# 2023-07-09 21:01:38,754: INFO: Progress[%]: 60.40 : PID-13264, L2A_Tables: band B02 exported, elapsed time[s]: 35.223, total: 0:25:45.524463
#
# 2023-07-09 21:02:14,788: INFO: Progress[%]: 61.81 : PID-13264, L2A_Tables: band B03 exported, elapsed time[s]: 36.033, total: 0:26:21.557162
#
# 2023-07-09 21:02:51,994: INFO: Progress[%]: 63.27 : PID-13264, L2A_Tables: band B04 exported, elapsed time[s]: 37.208, total: 0:26:58.764972
#
# 2023-07-09 21:03:31,528: INFO: Progress[%]: 64.82 : PID-13264, L2A_Tables: band B08 exported, elapsed time[s]: 39.532, total: 0:27:38.296652
#
# 2023-07-09 21:03:38,122: INFO: Progress[%]: 65.08 : PID-13264, L2A_Tables: band AOT exported, elapsed time[s]: 6.597, total: 0:27:44.893205
#
# 2023-07-09 21:04:10,519: INFO: Progress[%]: 66.35 : PID-13264, L2A_Tables: band WVP exported, elapsed time[s]: 32.397, total: 0:28:17.290289
#
# 2023-07-09 21:05:24,695: INFO: Progress[%]: 69.26 : PID-13264, L2A_Tables: band TCI exported, elapsed time[s]: 74.173, total: 0:29:31.463607
#
# 2023-07-09 21:05:24,921: INFO: Progress[%]: 69.27 : PID-13264, L2A_Tables: stop export, elapsed time[s]: 0.227, total: 0:29:31.690962
#
# 2023-07-09 21:05:30,783: INFO: Progress[%]: 100.00 : Application terminated successfully.
#
# 2023-07-09 21:05:30,785: INFO:
#
# 2023-07-09 21:05:30,962: INFO: sen2cor processing finished for /home/sepal-user/pyeo_dir/36NXG/composite/L1C/S2B_MSIL1C_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 21:05:30,963: INFO: Checking for presence of band raster files in /home/sepal-user/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 21:05:31,001: INFO: Changing L2A path: /home/sepal-user/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 21:05:31,001: INFO:   to new L2A path: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE
# 2023-07-09 21:05:31,012: INFO: Successfully downloaded the Sentinel-2 L1C products

# %% [markdown]
# ### <a id='toc3_3_2_'></a>[Download L2As](#toc0_)

# %% [markdown]
# In this subsection, we will download the L2As from our search query.
#
# But first, let's take a look at what our search query result, `l2a_products` looks like by printing the first 3 rows with `.head(3)`:

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    l2a_products.head(3)

# %% [markdown]
# Let's highlight a few columns of interest:
#
# In the cell output above, we can see the product `uuid` as the dataframe index (*the first column, it has no column name*). These are the unique identifiers used to distinguish the scenes from each other.
#
# From the `title` column, we can see the titles of each product, the titles themselves show us important information, for example: the Satellite (*S2A or S2B*), the Sensor (*MSI*), the product type (*L2A*), the date the image was captured (*YYYYMMDD*) or the corresponding tile for the image (*TXXXXX*).
#
# We can also see if the product is online or in the Long-Term Archive (`LTA`), by looking at the column `ondemand`, where `false` indicates the product is in the LTA or `true` indicates the product is online and ready for download.

# %% [markdown]
# ---------

# %% [markdown]
# Now, let's download the `L2As` in our search query `l2a_products`, by asking `pyeo_1` to download these images from the Copernicus archive. If any incomplete downloads are present from a previous run (*remember, pyeo_1 is an iterative download, classification and change detection process*), then `pyeo_1` will flag these files to the user through the log file.
#
# If the images are in the Long Term Archive (`LTA`), then `pyeo_1` will linearly activate and wait for the LTA image to become available, before downloading and moving onto the next L2A in the search query.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if l2a_products.shape[0] > 0:
        tile_log.info("Downloading Sentinel-2 L2A products.")

        if download_source == "scihub":

            queries_and_downloads.download_s2_data(
                l2a_products.to_dict("index"),
                composite_l1_image_dir,
                composite_l2_image_dir,
                source="scihub",
                user=sen_user,
                passwd=sen_pass,
                try_scihub_on_fail=True,
            )
        if download_source == "dataspace":

            queries_and_downloads.download_s2_data_from_dataspace(
                product_df=l2a_products,
                l1c_directory=composite_l1_image_dir,
                l2a_directory=composite_l2_image_dir,
                dataspace_username=sen_user,
                dataspace_password=sen_pass,
                log=tile_log
            )

    # check for incomplete L2A downloads
    incomplete_downloads, sizes = raster_manipulation.find_small_safe_dirs(
        composite_l2_image_dir, threshold=faulty_granule_threshold * 1024 * 1024
    )
    if len(incomplete_downloads) > 0:
        for index, safe_dir in enumerate(incomplete_downloads):
            if sizes[
                index
            ] / 1024 / 1024 < faulty_granule_threshold and os.path.exists(safe_dir):
                tile_log.warning("Found likely incomplete download of size {} MB: {}".format(
                        str(round(sizes[index] / 1024 / 1024)), safe_dir))

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Image download and atmospheric correction for composite is complete.")
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 21:05:31,121: INFO: Downloading Sentinel-2 L2A products.
# 2023-07-09 21:05:31,130: INFO:     Checking 1 of 5 : S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE
# 2023-07-09 21:05:31,171: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE imagery already exists, skipping download
# 2023-07-09 21:05:31,172: INFO:     Checking 2 of 5 : S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE
# 2023-07-09 21:05:31,214: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE imagery already exists, skipping download
# 2023-07-09 21:05:31,214: INFO:     Checking 3 of 5 : S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE
# 2023-07-09 21:05:31,252: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE imagery already exists, skipping download
# 2023-07-09 21:05:31,252: INFO:     Checking 4 of 5 : S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE
# 2023-07-09 21:05:31,289: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE imagery already exists, skipping download
# 2023-07-09 21:05:31,290: INFO:     Checking 5 of 5 : S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE
# 2023-07-09 21:05:31,325: INFO:         /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE imagery already exists, skipping download
# 2023-07-09 21:05:31,701: INFO: ---------------------------------------------------------------
# 2023-07-09 21:05:31,702: INFO: Image download and atmospheric correction for composite is complete.
# 2023-07-09 21:05:31,702: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### <a id='toc3_3_3_'></a>[Housekeeping](#toc0_)

# %% [markdown]
# The cell below performs some housekeeping if we have told `pyeo_1` to delete or zip imagery. This functionality is useful for ensuring disk space is kept to a minimum.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if config_dict["do_delete"]:
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Deleting downloaded L1C images for composite, keeping only derived L2A products")
        tile_log.info(
            "---------------------------------------------------------------"
        )
        directory = composite_l1_image_dir
        tile_log.info("Deleting {}".format(directory))
        shutil.rmtree(directory)
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Deletion of L1C images complete. Keeping only L2A images.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
    else:
        if config_dict["do_zip"]:
            tile_log.info("---------------------------------------------------------------")
            tile_log.info("Zipping downloaded L1C images for composite after atmospheric correction")
            tile_log.info("---------------------------------------------------------------")
            filesystem_utilities.zip_contents(composite_l1_image_dir)
            tile_log.info("---------------------------------------------------------------")
            tile_log.info("Zipping complete")
            tile_log.info("---------------------------------------------------------------")

    tile_log.info("Cell successfully finished")
# Out:
# 2023-07-09 21:05:31,711: INFO: Cell successfully finished

# %% [markdown]
# ## <a id='toc3_4_'></a>[Process the Downloaded Imagery](#toc0_)

# %% [markdown]
# Now that we have downloaded the L2A Imagery, we will process the imagery. Processing refers to:
#
# 1. Applying the `SCL Cloud Mask` to remove cloud, haze or cloud shadow pixels from the imagery.
# 2. Applying a `Processing Baseline Correction Offset` to the imagery, if applicable.
# 3. Create `Quicklooks` (*.png*) of the processed imagery.

# %% [markdown]
# ### Check for pre-downloaded Imagery

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Applying simple cloud, cloud shadow and haze mask based on SCL files and stacking the masked band raster files.")
    tile_log.info("---------------------------------------------------------------")

    directory = composite_l2_masked_image_dir
    masked_file_paths = [
        f
        for f in os.listdir(directory)
        if f.endswith(".tif") and os.path.isfile(os.path.join(directory, f))
    ]

    directory = composite_l2_image_dir
    l2a_zip_file_paths = [f for f in os.listdir(directory) if f.endswith(".zip")]

    if len(l2a_zip_file_paths) > 0:
        for f in l2a_zip_file_paths:
            # check whether the zipped file has already been cloud masked
            zip_timestamp = filesystem_utilities.get_image_acquisition_time(
                os.path.basename(f)
            ).strftime("%Y%m%dT%H%M%S")
            if any(zip_timestamp in f for f in masked_file_paths):
                continue
            else:
                # extract it if not
                filesystem_utilities.unzip_contents(
                    os.path.join(composite_l2_image_dir, f),
                    ifstartswith="S2",
                    ending=".SAFE",
                )

    directory = composite_l2_image_dir
    l2a_safe_file_paths = [
        f
        for f in os.listdir(directory)
        if f.endswith(".SAFE") and os.path.isdir(os.path.join(directory, f))
    ]

    files_for_cloud_masking = []
    if len(l2a_safe_file_paths) > 0:
        for f in l2a_safe_file_paths:
            # check whether the L2A SAFE file has already been cloud masked
            safe_timestamp = filesystem_utilities.get_image_acquisition_time(
                os.path.basename(f)
            ).strftime("%Y%m%dT%H%M%S")
            if any(safe_timestamp in f for f in masked_file_paths):
                continue
            else:
                # add it to the list of files to do if it has not been cloud masked yet
                files_for_cloud_masking = files_for_cloud_masking + [f]

    tile_log.info("Cell successfully finished")
# Out:
# 2023-07-09 21:05:31,773: INFO: ---------------------------------------------------------------
# 2023-07-09 21:05:31,774: INFO: Applying simple cloud, cloud shadow and haze mask based on SCL files and stacking the masked band raster files.
# 2023-07-09 21:05:31,774: INFO: ---------------------------------------------------------------
# 2023-07-09 21:05:31,786: INFO: Cell successfully finished

# %% [markdown]
# ### <a id='toc3_4_2_'></a>[Apply SCL Cloud Mask](#toc0_)

# %% [markdown]
# Optical data is affected by the presence of clouds over the land cover of interest. So, we use `apply_scl_cloud_mask` to remove cloudy pixels from the imagery, as we are not interested in clouds.
#
# The cell below peforms two things:
#
# - Checks whether any L2A SAFE files have been cloud masked from a previous run.
#
# - If any L2A SAFE files have not been cloud masked, then `apply_scl_cloud_mask` is applied.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if len(files_for_cloud_masking) == 0:
        tile_log.info("No L2A images found for cloud masking. They may already have been done.")
    else:
        raster_manipulation.apply_scl_cloud_mask(
            composite_l2_image_dir,
            composite_l2_masked_image_dir,
            scl_classes=[0, 1, 2, 3, 8, 9, 10, 11],
            buffer_size=buffer_size_composite,
            bands=bands,
            out_resolution=out_resolution,
            haze=None,
            epsg=epsg,
            skip_existing=skip_existing,)

    tile_log.info("Successfully applied the Cloud Mask")
# Out:
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE/GRANULE/L2A_T36NXG_A027045_20220511T080451/IMG_DATA/R10m/T36NXG_20220511T074609_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE/GRANULE/L2A_T36NXG_A027045_20220511T080451/IMG_DATA/R10m/T36NXG_20220511T074609_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE/GRANULE/L2A_T36NXG_A027045_20220511T080451/IMG_DATA/R10m/T36NXG_20220511T074609_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220511T074609_N0400_R135_T36NXG_20220511T103313.SAFE/GRANULE/L2A_T36NXG_A027045_20220511T080451/IMG_DATA/R10m/T36NXG_20220511T074609_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE/GRANULE/L2A_T36NXG_A035024_20220307T075216/IMG_DATA/R10m/T36NXG_20220307T074801_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE/GRANULE/L2A_T36NXG_A035024_20220307T075216/IMG_DATA/R10m/T36NXG_20220307T074801_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE/GRANULE/L2A_T36NXG_A035024_20220307T075216/IMG_DATA/R10m/T36NXG_20220307T074801_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220307T074801_N0400_R135_T36NXG_20220307T113320.SAFE/GRANULE/L2A_T36NXG_A035024_20220307T075216/IMG_DATA/R10m/T36NXG_20220307T074801_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE/GRANULE/L2A_T36NXG_A026187_20220312T080452/IMG_DATA/R10m/T36NXG_20220312T074719_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE/GRANULE/L2A_T36NXG_A026187_20220312T080452/IMG_DATA/R10m/T36NXG_20220312T074719_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE/GRANULE/L2A_T36NXG_A026187_20220312T080452/IMG_DATA/R10m/T36NXG_20220312T074719_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220312T074719_N0400_R135_T36NXG_20220312T103427.SAFE/GRANULE/L2A_T36NXG_A026187_20220312T080452/IMG_DATA/R10m/T36NXG_20220312T074719_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N9999_R135_T36NXG_20221128T124418.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2A_MSIL2A_20220126T075211_N0400_R135_T36NXG_20220126T111035.SAFE/GRANULE/L2A_T36NXG_A034452_20220126T075213/IMG_DATA/R10m/T36NXG_20220126T075211_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE/S2B_MSIL2A_20220918T074619_N9999_R135_T36NXG_20230709T203554.SAFE/GRANULE/L2A_T36NXG_A028904_20220918T080455/IMG_DATA/R10m/T36NXG_20220918T074619_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE/S2B_MSIL2A_20220918T074619_N9999_R135_T36NXG_20230709T203554.SAFE/GRANULE/L2A_T36NXG_A028904_20220918T080455/IMG_DATA/R10m/T36NXG_20220918T074619_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE/S2B_MSIL2A_20220918T074619_N9999_R135_T36NXG_20230709T203554.SAFE/GRANULE/L2A_T36NXG_A028904_20220918T080455/IMG_DATA/R10m/T36NXG_20220918T074619_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/composite/L2A/S2B_MSIL2A_20220918T074619_N0400_R135_T36NXG_20220918T094433.SAFE/S2B_MSIL2A_20220918T074619_N9999_R135_T36NXG_20230709T203554.SAFE/GRANULE/L2A_T36NXG_A028904_20220918T080455/IMG_DATA/R10m/T36NXG_20220918T074619_B08_10m.jp2
# 2023-07-09 21:33:03,206: INFO: Successfully applied the Cloud Mask

# %% [markdown]
# ### <a id='toc3_4_3_'></a>[Apply Processing Baseline Offset](#toc0_)

# %% [markdown]
# Before Sentinel-2 imagery is provided to the user as L1C or L2A formats, the raw imagery (L0) are processed by the ESA Copernicus Ground Segment ([see here](https://sentinel.esa.int/web/sentinel/user-guides/sentinel-2-msi/processing-levels)). The algorithms used in the processing baseline, are indicated by the field `N0XXX` in the product title and the changes introduced by each processing baseline iteration are listed [here](https://sentinel.esa.int/web/sentinel/technical-guides/sentinel-2-msi/processing-baseline).
#
# The advent of processing baseline `N0400` introduced an offset of `-1000` in the spectral reflectance values, the reasoning and suggested reading can be viewed [here](https://forum.step.esa.int/t/info-introduction-of-additional-radiometric-offset-in-pb04-00-products/35431). Therefore, to ensure that the spectral reflectance of imagery before and after `N0400` can be compared, we apply the offset correction of `+1000`.
#
# The cell below, applies such an offset correction.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Offsetting cloud masked L2A images for composite.")
    tile_log.info("---------------------------------------------------------------")

    raster_manipulation.apply_processing_baseline_offset_correction_to_tiff_file_directory(
        composite_l2_masked_image_dir, composite_l2_masked_image_dir)

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Offsetting of cloud masked L2A images for composite complete.")
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 21:33:03,223: INFO: ---------------------------------------------------------------
# 2023-07-09 21:33:03,225: INFO: Offsetting cloud masked L2A images for composite.
# 2023-07-09 21:33:03,225: INFO: ---------------------------------------------------------------
# apply_processing_baseline_offset_correction_to_tiff_file_directory() running on: /home/sepal-user/pyeo_dir/36NXG/composite/cloud_masked
# 2023-07-09 21:36:07,201: INFO: ---------------------------------------------------------------
# 2023-07-09 21:36:07,205: INFO: Offsetting of cloud masked L2A images for composite complete.
# 2023-07-09 21:36:07,209: INFO: ---------------------------------------------------------------
# Offsetting Finished

# %% [markdown]
# ### <a id='toc3_4_4_'></a>[Create Quicklooks of Cloud-Masked Images](#toc0_)

# %% [markdown]
# - We can also create quicklooks of the Cloud-Masked images. These are especially useful for viewing the images quickly using a standard photo viewer, and for use in presentations.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if config_dict["do_quicklooks"] or config_dict["do_all"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Producing quicklooks.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
        dirs_for_quicklooks = [composite_l2_masked_image_dir]
        for main_dir in dirs_for_quicklooks:
            files = [
                f.path
                for f in os.scandir(main_dir)
                if f.is_file() and os.path.basename(f).endswith(".tif")
            ]
            # files = [ f.path for f in os.scandir(main_dir) if f.is_file() and os.path.basename(f).endswith(".tif") and "class" in os.path.basename(f) ] # do classification images only
            if len(files) == 0:
                tile_log.warning("No images found in {}.".format(main_dir))
            else:
                for f in files:
                    quicklook_path = os.path.join(
                        quicklook_dir,
                        os.path.basename(f).split(".")[0] + ".png",
                    )
                    tile_log.info("Creating quicklook: {}".format(quicklook_path))
                    raster_manipulation.create_quicklook(
                        f,
                        quicklook_path,
                        width=512,
                        height=512,
                        format="PNG",
                        bands=[3, 2, 1],
                        scale_factors=[[0, 2000, 0, 255]],
                    )
        tile_log.info("Quicklooks complete.")
    else:
        tile_log.info("Quicklook option disabled in ini file.")


    if config_dict["do_zip"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info(
            "Zipping downloaded L2A images for composite after cloud masking and band stacking"
        )
        tile_log.info(
            "---------------------------------------------------------------"
        )
        filesystem_utilities.zip_contents(composite_l2_image_dir)
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Zipping complete")
        tile_log.info(
            "---------------------------------------------------------------"
        )
# Out:
# 2023-07-09 21:36:07,224: INFO: ---------------------------------------------------------------
# 2023-07-09 21:36:07,225: INFO: Producing quicklooks.
# 2023-07-09 21:36:07,226: INFO: ---------------------------------------------------------------
# 2023-07-09 21:36:07,234: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20220918T074619_NA400_R135_T36NXG_20220918T094433.png
# 2023-07-09 21:36:20,746: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20220126T075211_NA400_R135_T36NXG_20220126T111035.png
# 2023-07-09 21:36:34,365: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20220511T074609_NA400_R135_T36NXG_20220511T103313.png
# 2023-07-09 21:36:53,120: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20220126T075211_NA999_R135_T36NXG_20221128T124418.png
# 2023-07-09 21:37:06,757: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20220307T074801_NA400_R135_T36NXG_20220307T113320.png
# 2023-07-09 21:37:20,324: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20220312T074719_NA400_R135_T36NXG_20220312T103427.png
# 2023-07-09 21:37:33,849: INFO: Quicklooks complete.

# %% [markdown]
# ## <a id='toc3_5_'></a>[Create Composite from the Baseline Imagery](#toc0_)

# %% [markdown]
# Now we come to the last section of Tutorial Section 2. Previously, we have queried the Copernicus archive for Sentinel-2 images that matched our search criteria, we evaluated which L2A products were present in the archive to avoid unecessary processing from pyeo_1 for conversion from L1C to L2A. We then downloaded the resulting imagery, applied a cloud mask and a baseline offset correction, if necessary.

# %%
import warnings
if config_dict["build_composite"] or config_dict["do_all"]:
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)

        tile_log.info("---------------------------------------------------------------")
        tile_log.info(
            "Building initial cloud-free median composite from directory {}".format(
                composite_l2_masked_image_dir
            )
        )
        tile_log.info("---------------------------------------------------------------")
        directory = composite_l2_masked_image_dir
        masked_file_paths = [
            f
            for f in os.listdir(directory)
            if f.endswith(".tif") and os.path.isfile(os.path.join(directory, f))
        ]

        if len(masked_file_paths) > 0:
            raster_manipulation.clever_composite_directory(
                composite_l2_masked_image_dir,
                composite_dir,
                chunks=config_dict["chunks"],
                generate_date_images=True,
                missing_data_value=0,
            )
            tile_log.info("---------------------------------------------------------------")
            tile_log.info("Baseline composite complete.")
            tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 21:37:33,859: INFO: ---------------------------------------------------------------
# 2023-07-09 21:37:33,860: INFO: Building initial cloud-free median composite from directory /home/sepal-user/pyeo_dir/36NXG/composite/cloud_masked
# 2023-07-09 21:37:33,861: INFO: ---------------------------------------------------------------
# 2023-07-09 21:45:12,682: INFO: ---------------------------------------------------------------
# 2023-07-09 21:45:12,684: INFO: Baseline composite complete.
# 2023-07-09 21:45:12,685: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### <a id='toc3_5_1_'></a>[Create Quicklook of the Composite](#toc0_)

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if config_dict["do_quicklooks"] or config_dict["do_all"]:
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Producing quicklooks.")
        tile_log.info("---------------------------------------------------------------")
        dirs_for_quicklooks = [composite_dir]
        for main_dir in dirs_for_quicklooks:
            files = [
                f.path
                for f in os.scandir(main_dir)
                if f.is_file() and os.path.basename(f).endswith(".tif")
            ]
            if len(files) == 0:
                tile_log.warning("No images found in {}.".format(main_dir))
            else:
                for f in files:
                    quicklook_path = os.path.join(
                        quicklook_dir,
                        os.path.basename(f).split(".")[0] + ".png",
                    )
                    tile_log.info(
                        "Creating quicklook: {}".format(quicklook_path)
                    )
                    raster_manipulation.create_quicklook(
                        f,
                        quicklook_path,
                        width=512,
                        height=512,
                        format="PNG",
                        bands=[3, 2, 1],
                        scale_factors=[[0, 2000, 0, 255]],
                    )
        tile_log.info("Quicklooks complete.")
# Out:
# 2023-07-09 21:45:12,703: INFO: ---------------------------------------------------------------
# 2023-07-09 21:45:12,704: INFO: Producing quicklooks.
# 2023-07-09 21:45:12,705: INFO: ---------------------------------------------------------------
# 2023-07-09 21:45:12,713: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/composite_T36NXG_20220918T074619.png
# 2023-07-09 21:45:26,408: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/composite_T36NXG_20220511T074609.png
# 2023-07-09 21:45:50,968: INFO: Quicklooks complete.

# %% [markdown]
# ### <a id='toc3_5_2_'></a>[Final Housekeeping](#toc0_)

# %% [markdown]
# Now that we have created our composite and produced any quicklooks, we tell `pyeo_1` to delete or compress the cloud-masked L2A images that the composite was derived from.

# %%
if config_dict["build_composite"] or config_dict["do_all"]:
    if config_dict["do_quicklooks"] or config_dict["do_all"]:
        if config_dict["do_delete"]:
            tile_log.info(
                "---------------------------------------------------------------"
            )
            tile_log.info(
                "Deleting intermediate cloud-masked L2A images used for the baseline composite"
            )
            tile_log.info(
                "---------------------------------------------------------------"
            )
            f = composite_l2_masked_image_dir
            tile_log.info("Deleting {}".format(f))
            shutil.rmtree(f)
            tile_log.info(
                "---------------------------------------------------------------"
            )
            tile_log.info("Intermediate file products have been deleted.")
            tile_log.info("They can be reprocessed from the downloaded L2A images.")
            tile_log.info(
                "---------------------------------------------------------------"
            )
        else:
            if config_dict["do_zip"]:
                tile_log.info(
                    "---------------------------------------------------------------"
                )
                tile_log.info(
                    "Zipping cloud-masked L2A images used for the baseline composite"
                )
                tile_log.info(
                    "---------------------------------------------------------------"
                )
                filesystem_utilities.zip_contents(composite_l2_masked_image_dir)
                tile_log.info(
                    "---------------------------------------------------------------"
                )
                tile_log.info("Zipping complete")
                tile_log.info(
                    "---------------------------------------------------------------"
                )

        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info(
            "Compressing tiff files in directory {} and all subdirectories".format(
                composite_dir
            )
        )
        tile_log.info(
            "---------------------------------------------------------------"
        )
        for root, dirs, files in os.walk(composite_dir):
            all_tiffs = [
                image_name for image_name in files if image_name.endswith(".tif")
            ]
            for this_tiff in all_tiffs:
                raster_manipulation.compress_tiff(
                    os.path.join(root, this_tiff), os.path.join(root, this_tiff)
                )

        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info(
            "Baseline image composite, file compression, zipping and deletion of"
        )
        tile_log.info("intermediate file products (if selected) are complete.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
# Out:
# 2023-07-09 21:45:50,982: INFO: ---------------------------------------------------------------
# 2023-07-09 21:45:50,983: INFO: Compressing tiff files in directory /home/sepal-user/pyeo_dir/36NXG/composite and all subdirectories
# 2023-07-09 21:45:50,984: INFO: ---------------------------------------------------------------
# 2023-07-09 21:50:52,798: INFO: ---------------------------------------------------------------
# 2023-07-09 21:50:52,821: INFO: Baseline image composite, file compression, zipping and deletion of
# 2023-07-09 21:50:52,826: INFO: intermediate file products (if selected) are complete.
# 2023-07-09 21:50:52,827: INFO: ---------------------------------------------------------------

# %% [markdown]
# # <a id='toc4_'></a>[Session 3: Change Detection](#toc0_)

# %% [markdown]
# - If we are returning to this notebook after a break, we need to re-run the cells in the subsection - [Directory and Variable Setup.](#toc3_1_)

# %% [markdown]
# ## <a id='toc4_3_'></a>[Query Sentinel-2 Change Imagery](#toc0_)

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Downloading change detection images between {} and {} with cloud cover <= {}".format(
            start_date, end_date, cloud_cover
        )
    )
    tile_log.info("---------------------------------------------------------------")
    if download_source == "dataspace":

        try:
            tiles_geom_path = os.path.join(config_dict["pyeo_dir"], os.path.join(config_dict["geometry_dir"], config_dict["s2_tiles_filename"]))
            tiles_geom = gpd.read_file(os.path.abspath(tiles_geom_path))

        except FileNotFoundError:
            tile_log.error(f"tiles_geom does not exist, the path is :{tiles_geom_path}")

        tile_geom = tiles_geom[tiles_geom["Name"] == tile_to_process]
        tile_geom = tile_geom.to_crs(epsg=4326)
        geometry = tile_geom["geometry"].iloc[0]
        geometry = geometry.representative_point()

        # convert date string to YYYY-MM-DD
        date_object = datetime.strptime(start_date, "%Y%m%d")
        dataspace_change_start = date_object.strftime("%Y-%m-%d")
        date_object = datetime.strptime(end_date, "%Y%m%d")
        dataspace_change_end = date_object.strftime("%Y-%m-%d")

        try:
            dataspace_change_products_all = queries_and_downloads.query_dataspace_by_polygon(
                max_cloud_cover=cloud_cover,
                start_date=dataspace_change_start,
                end_date=dataspace_change_end,
                area_of_interest=geometry,
                max_records=100,
                log=tile_log
            )
        except Exception as error:
            tile_log.error(f"query_by_polygon received this error: {error}")

        titles = dataspace_change_products_all["title"].tolist()
        sizes = list()
        uuids = list()
        for elem in dataspace_change_products_all.itertuples(index=False):
            sizes.append(elem[-2]["download"]["size"])
            uuids.append(elem[-2]["download"]["url"].split("/")[-1])


        relative_orbit_numbers = dataspace_change_products_all["relativeOrbitNumber"].tolist()
        processing_levels = dataspace_change_products_all["processingLevel"].tolist()
        transformed_levels = ['Level-1C' if level == 'S2MSI1C' else 'Level-2A' for level in processing_levels]
        cloud_covers = dataspace_change_products_all["cloudCover"].tolist()
        begin_positions = dataspace_change_products_all["startDate"].tolist()
        statuses = dataspace_change_products_all["status"].tolist()

        scihub_compatible_df = pd.DataFrame({"title": titles,
                                            "size": sizes,
                                            "beginposition": begin_positions,
                                            "relativeorbitnumber": relative_orbit_numbers,
                                            "cloudcoverpercentage": cloud_covers,
                                            "processinglevel": transformed_levels,
                                            "uuid": uuids,
                                            "status": statuses})

        # check granule sizes on the server
        scihub_compatible_df["size"] = scihub_compatible_df["size"].apply(lambda x: round(float(x) * 1e-6, 2))
        # reassign to match the scihub variable
        df_all = scihub_compatible_df

    if download_source == "scihub":
        products_all = queries_and_downloads.check_for_s2_data_by_date(
            config_dict["tile_dir"],
            start_date,
            end_date,
            credentials_dict,
            cloud_cover=cloud_cover,
            tile_id=tile_to_process,
            producttype=None,  # "S2MSI2A" or "S2MSI1C"
        )
        tile_log.info(
            "--> Found {} L1C and L2A products for change detection:".format(
                len(products_all)
            )
        )
        df_all = pd.DataFrame.from_dict(products_all, orient="index")

        # check granule sizes on the server
        df_all["size"] = (
            df_all["size"]
            .str.split(" ")
            .apply(lambda x: float(x[0]) * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]])
        )

    # here the main call (from if download_source == "scihub" branch) is resumed
    df = df_all.query("size >= " + str(faulty_granule_threshold))
    tile_log.info(
        "Removed {} faulty scenes <{}MB in size from the list:".format(
            len(df_all) - len(df), faulty_granule_threshold
        )
    )
    df_faulty = df_all.query("size < " + str(faulty_granule_threshold))
    for r in range(len(df_faulty)):
        tile_log.info(
            "   {} MB: {}".format(
                df_faulty.iloc[r, :]["size"], df_faulty.iloc[r, :]["title"]
            )
        )

    l1c_products = df[df.processinglevel == "Level-1C"]
    l2a_products = df[df.processinglevel == "Level-2A"]
    tile_log.info("    {} L1C products".format(l1c_products.shape[0]))
    tile_log.info("    {} L2A products".format(l2a_products.shape[0]))

    if l1c_products.shape[0] > 0 and l2a_products.shape[0] > 0:
        tile_log.info(
            "Filtering out L1C products that have the same 'beginposition' time stamp as an existing L2A product."
        )
        if download_source == "scihub":
            (l1c_products,l2a_products,) = queries_and_downloads.filter_unique_l1c_and_l2a_data(df,log=tile_log)

        if download_source == "dataspace":
            l1c_products = queries_and_downloads.filter_unique_dataspace_products(l1c_products=l1c_products, l2a_products=l2a_products, log=tile_log)

        tile_log.info(
            "--> {} L1C and L2A products with unique 'beginposition' time stamp for the composite:".format(
                l1c_products.shape[0] + l2a_products.shape[0]
            )
        )

    df = None
    tile_log.info(f" {len(l1c_products['title'])} L1C Change Images")
    tile_log.info(f" {len(l2a_products['title'])} L2A Change Images")
    
    tile_log.info("Cell successfully finished")
# Out:
# 2023-07-09 21:50:52,854: INFO: ---------------------------------------------------------------
# 2023-07-09 21:50:52,855: INFO: Downloading change detection images between 20230101 and 20230210 with cloud cover <= 25
# 2023-07-09 21:50:52,855: INFO: ---------------------------------------------------------------
# 2023-07-09 21:50:56,683: INFO: Removed 0 faulty scenes <350MB in size from the list:
# 2023-07-09 21:50:56,688: INFO:     8 L1C products
# 2023-07-09 21:50:56,688: INFO:     6 L2A products
# 2023-07-09 21:50:56,689: INFO: Filtering out L1C products that have the same 'beginposition' time stamp as an existing L2A product.
# 2023-07-09 21:50:56,690: INFO: Before filtering, 8 L1C and 6 L2A
# 2023-07-09 21:50:56,692: INFO: L1C : S2B_MSIL1C_20230205T075019_N0509_R135_T36NXG_20230205T093336.SAFE
# 2023-07-09 21:50:56,693: INFO: L1C : S2A_MSIL1C_20230101T075331_N0509_R135_T36NXG_20230101T093355.SAFE
# 2023-07-09 21:50:56,693: INFO: L1C : S2B_MSIL1C_20230126T075109_N0509_R135_T36NXG_20230126T093309.SAFE
# 2023-07-09 21:50:56,694: INFO: L1C : S2B_MSIL1C_20230106T075219_N0509_R135_T36NXG_20230106T093416.SAFE
# 2023-07-09 21:50:56,695: INFO: L1C : S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 21:50:56,696: INFO: L1C : S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:50:56,696: INFO: L1C : S2A_MSIL1C_20230131T075141_N0509_R135_T36NXG_20230131T093525.SAFE
# 2023-07-09 21:50:56,697: INFO: L1C : S2A_MSIL1C_20230121T075231_N0509_R135_T36NXG_20230121T093443.SAFE
# 2023-07-09 21:50:56,699: INFO: L2A : S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE
# 2023-07-09 21:50:56,700: INFO: L2A : S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE
# 2023-07-09 21:50:56,700: INFO: L2A : S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE
# 2023-07-09 21:50:56,701: INFO: L2A : S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE
# 2023-07-09 21:50:56,702: INFO: L2A : S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE
# 2023-07-09 21:50:56,703: INFO: L2A : S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE
# 2023-07-09 21:50:56,786: INFO: After filtering, 2 L1C and 6 L2A
# 2023-07-09 21:50:56,788: INFO: Unique L1C : S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 21:50:56,789: INFO: Unique L1C : S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:50:56,791: INFO: Unique L2A : S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE
# 2023-07-09 21:50:56,792: INFO: Unique L2A : S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE
# 2023-07-09 21:50:56,792: INFO: Unique L2A : S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE
# 2023-07-09 21:50:56,793: INFO: Unique L2A : S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE
# 2023-07-09 21:50:56,794: INFO: Unique L2A : S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE
# 2023-07-09 21:50:56,794: INFO: Unique L2A : S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE
# 2023-07-09 21:50:56,795: INFO: --> 8 L1C and L2A products with unique 'beginposition' time stamp for the composite:
# 2023-07-09 21:50:56,796: INFO:  2 L1C Change Images
# 2023-07-09 21:50:56,797: INFO:  6 L2A Change Images
# 2023-07-09 21:50:56,797: INFO: Cell successfully finished

# %% [markdown]
# ## Search for L2A Images Corresponding to L1C

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if download_source == "scihub":    
        if l1c_products.shape[0] > 0:
            tile_log.info("Checking for availability of L2A products to minimise download and atmospheric correction of L1C products.")
            n = len(l1c_products)
            drop = []
            add = []
            for r in range(n):
                id = l1c_products.iloc[r, :]["title"]
                search_term = (
                    "*"
                    + id.split("_")[2]
                    + "_"
                    + id.split("_")[3]
                    + "_"
                    + id.split("_")[4]
                    + "_"
                    + id.split("_")[5]
                    + "*"
                )
                tile_log.info("Search term: {}.".format(search_term))
                matching_l2a_products = queries_and_downloads._file_api_query(
                    user=sen_user,
                    passwd=sen_pass,
                    start_date=start_date,
                    end_date=end_date,
                    filename=search_term,
                    cloud=cloud_cover,
                    producttype="S2MSI2A",
                )

                matching_l2a_products_df = pd.DataFrame.from_dict(
                    matching_l2a_products, orient="index"
                )
                if len(matching_l2a_products_df) == 1:
                    tile_log.info(matching_l2a_products_df.iloc[0, :]["size"])
                    matching_l2a_products_df["size"] = (
                        matching_l2a_products_df["size"]
                        .str.split(" ")
                        .apply(
                            lambda x: float(x[0])
                            * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]]
                        )
                    )
                    if (
                        matching_l2a_products_df.iloc[0, :]["size"]
                        > faulty_granule_threshold
                    ):
                        tile_log.info("Replacing L1C {} with L2A product:".format(id))
                        tile_log.info(
                            "              {}".format(
                                matching_l2a_products_df.iloc[0, :]["title"]
                            )
                        )
                        drop.append(l1c_products.index[r])
                        add.append(matching_l2a_products_df.iloc[0, :])
                if len(matching_l2a_products_df) == 0:
                    tile_log.info("Found no match for L1C: {}.".format(id))
                if len(matching_l2a_products_df) > 1:
                    # check granule sizes on the server
                    matching_l2a_products_df["size"] = (
                        matching_l2a_products_df["size"]
                        .str.split(" ")
                        .apply(
                            lambda x: float(x[0])
                            * {"GB": 1e3, "MB": 1, "KB": 1e-3}[x[1]]
                        )
                    )
                    if (
                        matching_l2a_products_df.iloc[0, :]["size"]
                        > faulty_granule_threshold
                    ):
                        tile_log.info("Replacing L1C {} with L2A product:".format(id))
                        tile_log.info(
                            "              {}".format(
                                matching_l2a_products_df.iloc[0, :]["title"]
                            )
                        )
                        drop.append(l1c_products.index[r])
                        add.append(matching_l2a_products_df.iloc[0, :])

            if len(drop) > 0:
                l1c_products = l1c_products.drop(index=drop)
            if len(add) > 0:
                if config_dict["do_dev"]:
                    add = pd.DataFrame(add)
                    l2a_products = pd.concat([l2a_products, add])
                else:
                    add = pd.DataFrame(add)
                    l2a_products = pd.concat([l2a_products, add])

            tile_log.info(
                "    {} L1C products remaining for download".format(
                    l1c_products.shape[0]
                )
            )
    l2a_products = l2a_products.drop_duplicates(subset="title")
    tile_log.info("    {} L2A products remaining for download".format(l2a_products.shape[0]))
# Out:
# 2023-07-09 21:50:56,823: INFO:     6 L2A products remaining for download

# %% [markdown]
# ## <a id='toc4_4_'></a>[Download and Pre-Process L1C Change Imagery](#toc0_)

# %% [markdown]
# - If there any L1C products in the change images search query that are not matched with L2A products, then download these L1Cs and apply `atmospheric_correction`.

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if sen2cor_path == "none":
        tile_log.info("Sen2Cor path is not specified. Skipping L1C download and processing.")
        l1c_products = pd.dataframe() # reset the dataframe of L1C products to an empty dataframe to skip download
        
    if l1c_products.shape[0] > 0:

        tile_log.info(f"Downloading Sentinel-2 L1C products from {download_source}")

        if download_source == "scihub":
            queries_and_downloads.download_s2_data_from_df(
                l1c_products,
                l1_image_dir,
                l2_image_dir,
                download_source,
                user=sen_user,
                passwd=sen_pass,
                try_scihub_on_fail=True,
            )
        elif download_source == "dataspace":
                queries_and_downloads.download_s2_data_from_dataspace(
                product_df=l1c_products,
                l1c_directory=l1_image_dir,
                l2a_directory=l2_image_dir,
                dataspace_username=sen_user,
                dataspace_password=sen_pass,
                log=tile_log
            )
        else:
            tile_log.error(f"download source specified did not match 'scihub' or 'dataspace'")
            tile_log.error(f"download source supplied was  :  {download_source}")
            tile_log.error("exiting pipeline...")
            sys.exit(1)

        tile_log.info("Atmospheric correction with sen2cor.")
        raster_manipulation.atmospheric_correction(
            l1_image_dir,
            l2_image_dir,
            sen2cor_path,
            gipp_path,
            delete_unprocessed_image=False,
            log=tile_log,
        )

        tile_log.info("Successfully downloaded the Sentinel-2 L1C products")
# Out:
# 2023-07-09 21:50:56,878: INFO: Downloading Sentinel-2 L1C products from dataspace
# 2023-07-09 21:50:56,881: INFO:     Checking 1 of 2 : S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 21:50:56,900: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE imagery already exists, skipping download
# 2023-07-09 21:50:56,900: INFO:     Checking 2 of 2 : S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:50:56,912: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE imagery already exists, skipping download
# 2023-07-09 21:50:56,912: INFO: Atmospheric correction with sen2cor.
# 2023-07-09 21:50:56,915: INFO:    image path = /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:50:56,915: INFO:    out_directory = /home/sepal-user/pyeo_dir/36NXG/images/L2A
# 2023-07-09 21:51:00,134: INFO:    out name = /home/sepal-user/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:51:00,136: INFO:    out path = /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:51:00,137: INFO:    out glob = /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG*
# 2023-07-09 21:51:00,139: INFO: Atmospheric correction of S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:51:02,465: INFO: Calling sen2cor:
# 2023-07-09 21:51:02,467: INFO: /home/sepal-user/Sen2Cor-02.10.01-Linux64/bin/L2A_Process --GIP_L2A /home/sepal-user/sen2cor/2.10/cfg/L2A_GIPP.xml /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE --output_dir /home/sepal-user/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 21:51:04,899: INFO: Product versions > 14.9 are not implemented yet.
#
# 2023-07-09 21:51:04,901: INFO: Version 14.9 will be used by default, but warnings during validation might occur.
#
# 2023-07-09 21:51:04,901: INFO:
#
# 2023-07-09 21:51:06,485: INFO: Sen2Cor. Version: 02.10.01, created: 2021.12.13, supporting Level-1C product version 14.2 - 14.9 started ...
#
# 2023-07-09 21:51:06,487: INFO: Product version: 14.9
#
# 2023-07-09 21:51:06,487: INFO: Operation mode: TOOLBOX
#
# 2023-07-09 21:51:06,496: INFO: Processing baseline: 99.99
#
# 2023-07-09 21:51:06,521: INFO: Progress[%]:  0.00 : Generating datastrip metadata
#
# 2023-07-09 21:51:09,582: INFO: L2A datastrip successfully generated
#
# 2023-07-09 21:51:09,911: INFO: No resolution specified, will process 20 and 10 m resolution
#
# 2023-07-09 21:51:09,912: INFO: 20 m resolution will be downsampled to 60 m
#
# 2023-07-09 21:51:12,290: INFO: Progress[%]: 0.09 : PID-18507, L2A_ProcessTile: processing with resolution 20 m, elapsed time[s]: 2.382, total: 0:00:07.654357
#
# 2023-07-09 21:51:12,301: INFO: Progress[%]: 0.09 : PID-18507, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.012, total: 0:00:07.665896
#
# 2023-07-09 21:51:12,403: INFO: Progress[%]: 0.09 : PID-18507, L2A_Tables: start import, elapsed time[s]: 0.102, total: 0:00:07.767685
#
# 2023-07-09 21:51:13,443: INFO: Progress[%]: 0.13 : PID-18507, L2A_Tables: band B01 imported, elapsed time[s]: 1.040, total: 0:00:08.808056
#
# 2023-07-09 21:51:19,383: INFO: Progress[%]: 0.34 : PID-18507, L2A_Tables: band B02 imported, elapsed time[s]: 5.940, total: 0:00:14.747922
#
# 2023-07-09 21:51:27,141: INFO: Progress[%]: 0.63 : PID-18507, L2A_Tables: band B03 imported, elapsed time[s]: 7.758, total: 0:00:22.506000
#
# 2023-07-09 21:51:34,589: INFO: Progress[%]: 0.90 : PID-18507, L2A_Tables: band B04 imported, elapsed time[s]: 7.448, total: 0:00:29.953707
#
# 2023-07-09 21:51:38,627: INFO: Progress[%]: 1.04 : PID-18507, L2A_Tables: band B05 imported, elapsed time[s]: 4.038, total: 0:00:33.991282
#
# 2023-07-09 21:51:41,577: INFO: Progress[%]: 1.15 : PID-18507, L2A_Tables: band B06 imported, elapsed time[s]: 2.950, total: 0:00:36.941517
#
# 2023-07-09 21:51:44,528: INFO: Progress[%]: 1.26 : PID-18507, L2A_Tables: band B07 imported, elapsed time[s]: 2.951, total: 0:00:39.892657
#
# 2023-07-09 21:51:47,597: INFO: Progress[%]: 1.37 : PID-18507, L2A_Tables: band B8A imported, elapsed time[s]: 3.069, total: 0:00:42.962156
#
# 2023-07-09 21:51:48,855: INFO: Progress[%]: 1.41 : PID-18507, L2A_Tables: band B09 imported, elapsed time[s]: 1.257, total: 0:00:44.219479
#
# 2023-07-09 21:51:50,776: INFO: Progress[%]: 1.48 : PID-18507, L2A_Tables: band B10 imported, elapsed time[s]: 1.921, total: 0:00:46.140976
#
# 2023-07-09 21:51:53,810: INFO: Progress[%]: 1.59 : PID-18507, L2A_Tables: band B11 imported, elapsed time[s]: 3.033, total: 0:00:49.174170
#
# 2023-07-09 21:51:56,947: INFO: Progress[%]: 1.71 : PID-18507, L2A_Tables: band B12 imported, elapsed time[s]: 3.138, total: 0:00:52.311806
#
# 2023-07-09 21:51:57,196: INFO: Progress[%]: 1.72 : PID-18507, L2A_Tables: AUX_CAMS* file found., elapsed time[s]: 0.250, total: 0:00:52.561357
#
# 2023-07-09 21:52:10,075: INFO: Progress[%]: 2.18 : PID-18507, L2A_Tables: Visibility map from file AUX_CAMSFO prepared, elapsed time[s]: 12.875, total: 0:01:05.436772
#
# 2023-07-09 21:52:10,128: INFO: Progress[%]: 2.18 : PID-18507, L2A_ProcessTile: start of Scene Classification, elapsed time[s]: 0.056, total: 0:01:05.492749
#
# 2023-07-09 21:52:11,418: INFO: Progress[%]: 2.23 : PID-18507, L2A_Tables: band B02 must be resampled, elapsed time[s]: 1.290, total: 0:01:06.782878
#
# 2023-07-09 21:52:13,513: INFO: Progress[%]: 2.31 : PID-18507, Pre process   , elapsed time[s]: 2.095, total: 0:01:08.877959
#
# 2023-07-09 21:52:13,576: INFO: Progress[%]: 2.31 : PID-18507, L2A_Tables: band B01 must be resampled, elapsed time[s]: 0.063, total: 0:01:08.941027
#
# 2023-07-09 21:52:18,678: INFO: Progress[%]: 2.49 : PID-18507, L2A_Tables: band B03 must be resampled, elapsed time[s]: 5.102, total: 0:01:14.042992
#
# 2023-07-09 21:52:21,334: INFO: Progress[%]: 2.59 : PID-18507, L2A_Tables: band B04 must be resampled, elapsed time[s]: 2.656, total: 0:01:16.698583
#
# 2023-07-09 21:52:24,393: INFO: Progress[%]: 2.70 : PID-18507, L2A_Tables: band B09 must be resampled, elapsed time[s]: 3.059, total: 0:01:19.757796
#
# 2023-07-09 21:52:26,642: INFO: Progress[%]: 2.78 : PID-18507, L2A_Tables: band B10 must be resampled, elapsed time[s]: 2.248, total: 0:01:22.005333
#
# 2023-07-09 21:52:29,387: INFO: Progress[%]: 2.88 : PID-18507, L2A_SC init   , elapsed time[s]: 2.746, total: 0:01:24.751183
#
# 2023-07-09 21:52:30,501: INFO: Progress[%]: 2.92 : PID-18507, L2A_CSND_1_1  , elapsed time[s]: 1.114, total: 0:01:25.865365
#
# 2023-07-09 21:52:31,675: INFO: Progress[%]: 2.97 : PID-18507, L2A_CSND_1_2  , elapsed time[s]: 1.173, total: 0:01:27.038819
#
# 2023-07-09 21:52:32,008: INFO: Progress[%]: 2.98 : PID-18507, L2A_CSND_2_0  , elapsed time[s]: 0.334, total: 0:01:27.372665
#
# 2023-07-09 21:52:32,972: INFO: Progress[%]: 3.01 : PID-18507, L2A_CSND_2_1  , elapsed time[s]: 0.964, total: 0:01:28.336742
#
# 2023-07-09 21:52:33,478: INFO: Progress[%]: 3.03 : PID-18507, L2A_CSND_2_1_2, elapsed time[s]: 0.506, total: 0:01:28.842947
#
# 2023-07-09 21:52:33,884: INFO: Progress[%]: 3.05 : PID-18507, L2A_CSND_2_2  , elapsed time[s]: 0.405, total: 0:01:29.248406
#
# 2023-07-09 21:52:34,589: INFO: Progress[%]: 3.07 : PID-18507, L2A_CSND_2_3  , elapsed time[s]: 0.705, total: 0:01:29.953539
#
# 2023-07-09 21:52:35,541: INFO: Progress[%]: 3.11 : PID-18507, L2A_CSND_2_4  , elapsed time[s]: 0.952, total: 0:01:30.905214
#
# 2023-07-09 21:52:37,601: INFO: Progress[%]: 3.18 : PID-18507, L2A_CSND_2_5  , elapsed time[s]: 2.060, total: 0:01:32.965545
#
# 2023-07-09 21:52:37,615: INFO: Progress[%]: 3.18 : PID-18507, L2A_SnowPostProcessingCCI  , elapsed time[s]: 0.015, total: 0:01:32.980247
#
# 2023-07-09 21:52:39,591: INFO: Progress[%]: 3.25 : PID-18507, L2A_CSND_3    , elapsed time[s]: 1.975, total: 0:01:34.955047
#
# 2023-07-09 21:52:41,080: INFO: Progress[%]: 3.31 : PID-18507, L2A_CSND_5_1  , elapsed time[s]: 1.489, total: 0:01:36.444473
#
# 2023-07-09 21:52:43,018: INFO: Progress[%]: 3.38 : PID-18507, L2A_CSND_5_2  , elapsed time[s]: 1.938, total: 0:01:38.382334
#
# 2023-07-09 21:52:44,583: INFO: Progress[%]: 3.43 : PID-18507, L2A_CSND_6    , elapsed time[s]: 1.566, total: 0:01:39.948073
#
# 2023-07-09 21:52:45,551: INFO: Progress[%]: 3.47 : PID-18507, L2A_CSND_6_2  , elapsed time[s]: 0.968, total: 0:01:40.915648
#
# 2023-07-09 21:52:47,054: INFO: Progress[%]: 3.52 : PID-18507, L2A_CSND_7    , elapsed time[s]: 1.502, total: 0:01:42.418079
#
# 2023-07-09 21:52:48,329: INFO: Progress[%]: 3.57 : PID-18507, DV recovery   , elapsed time[s]: 1.275, total: 0:01:43.693427
#
# 2023-07-09 21:52:49,683: INFO: Progress[%]: 3.62 : PID-18507, WP recovery   , elapsed time[s]: 1.354, total: 0:01:45.047004
#
# 2023-07-09 21:52:49,696: INFO: Progress[%]: 3.62 : PID-18507, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.014, total: 0:01:45.061318
#
# 2023-07-09 21:52:51,896: INFO: Progress[%]: 3.70 : PID-18507, Snow recovery , elapsed time[s]: 2.199, total: 0:01:47.260524
#
# 2023-07-09 21:52:57,987: INFO: Progress[%]: 3.92 : PID-18507, SnowSoilBorders, elapsed time[s]: 6.090, total: 0:01:53.350844
#
# 2023-07-09 21:52:58,714: INFO: Progress[%]: 3.95 : PID-18507, Soil recovery , elapsed time[s]: 0.728, total: 0:01:54.078467
#
# 2023-07-09 21:52:58,729: INFO: Progress[%]: 3.95 : PID-18507, Cirrus recovery with B10 , elapsed time[s]: 0.015, total: 0:01:54.093941
#
# 2023-07-09 21:52:58,743: INFO: Progress[%]: 3.95 : PID-18507, Urban and Bare pixel recovery with CCI Land Cover Map at 300 m , elapsed time[s]: 0.013, total: 0:01:54.107279
#
# 2023-07-09 21:53:12,661: INFO: Progress[%]: 4.45 : PID-18507, Bright pixels Hollstein Fmask, elapsed time[s]: 13.915, total: 0:02:08.022416
#
# 2023-07-09 21:54:42,580: INFO: Cloud heights processed in 0:00:28.329103 seconds
#
# 2023-07-09 21:54:42,581: INFO: Progress[%]: 7.71 : PID-18507, L2A_SHD       , elapsed time[s]: 89.920, total: 0:03:37.942459
#
# 2023-07-09 21:54:42,595: INFO: Progress[%]: 7.71 : PID-18507, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.017, total: 0:03:37.959523
#
# 2023-07-09 21:54:44,904: INFO: Progress[%]: 7.80 : PID-18507, Topographic casted shadow Pixels post processing, elapsed time[s]: 2.310, total: 0:03:40.269056
#
# 2023-07-09 21:54:45,925: INFO: Progress[%]: 7.84 : PID-18507, Post process  , elapsed time[s]: 1.021, total: 0:03:41.289986
#
# 2023-07-09 21:54:46,109: INFO: Progress[%]: 7.84 : PID-18507, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 0.184, total: 0:03:41.473574
#
# 2023-07-09 21:54:47,482: INFO: Progress[%]: 7.89 : PID-18507, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 1.373, total: 0:03:42.846701
#
# 2023-07-09 21:54:47,494: INFO: Progress[%]: 7.89 : PID-18507, L2A_AtmCorr: start of AOT retrieval at 550nm, elapsed time[s]: 0.012, total: 0:03:42.858534
#
# 2023-07-09 21:54:53,861: INFO: Progress[%]: 8.12 : PID-18507, L2A_AtmCorr: end of internal classification, elapsed time[s]: 6.367, total: 0:03:49.225886
#
# 2023-07-09 21:54:54,740: INFO: Progress[%]: 8.15 : PID-18507, L2A_AtmCorr: end of interpolation LUTs, elapsed time[s]: 0.878, total: 0:03:50.104096
#
# 2023-07-09 21:55:14,499: INFO: Progress[%]: 8.87 : PID-18507, L2A_AtmCorr: end retrieving reference pixels for dark areas, elapsed time[s]: 19.759, total: 0:04:09.863187
#
# 2023-07-09 21:57:03,227: INFO: Progress[%]: 12.82 : PID-18507, L2A_AtmCorr: end of check for negative reflectance pixels, elapsed time[s]: 108.725, total: 0:05:58.588682
#
# 2023-07-09 21:57:06,406: INFO: Progress[%]: 12.93 : PID-18507, L2A_AtmCorr: the rescaling of path radiance in blue band has been disabled by configuration, elapsed time[s]: 3.181, total: 0:06:01.770127
#
# 2023-07-09 21:58:05,548: INFO: Progress[%]: 15.08 : PID-18507, L2A_AtmCorr: end of visibility index calculation, elapsed time[s]: 59.141, total: 0:07:00.911284
#
# 2023-07-09 21:58:05,560: INFO: Progress[%]: 15.08 : PID-18507, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 0.014, total: 0:07:00.925281
#
# 2023-07-09 21:58:05,572: INFO: Progress[%]: 15.08 : PID-18507, L2A_AtmCorr: start of water vapour retrieval, elapsed time[s]: 0.011, total: 0:07:00.936658
#
# 2023-07-09 21:58:06,847: INFO: Progress[%]: 15.12 : PID-18507, L2A_AtmCorr: end of water vapour retrieval preparation, elapsed time[s]: 1.275, total: 0:07:02.211302
#
# 2023-07-09 22:01:21,047: INFO: Progress[%]: 22.17 : PID-18507, L2A_AtmCorr: end of water vapour retrieval, elapsed time[s]: 194.199, total: 0:10:16.410109
#
# 2023-07-09 22:01:21,067: INFO: Progress[%]: 22.17 : PID-18507, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.015, total: 0:10:16.425140
#
# 2023-07-09 22:01:28,115: INFO: Progress[%]: 22.42 : PID-18507, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 7.054, total: 0:10:23.479474
#
# 2023-07-09 22:01:28,128: INFO: Progress[%]: 22.42 : PID-18507, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.013, total: 0:10:23.492629
#
# 2023-07-09 22:03:47,131: INFO: Progress[%]: 27.47 : PID-18507, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 139.002, total: 0:12:42.494145
#
# 2023-07-09 22:03:47,147: INFO: Progress[%]: 27.47 : PID-18507, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.018, total: 0:12:42.511813
#
# 2023-07-09 22:04:51,322: INFO: Progress[%]: 29.79 : PID-18507, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 64.173, total: 0:13:46.684706
#
# 2023-07-09 22:04:51,374: INFO: Progress[%]: 29.80 : PID-18507, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.054, total: 0:13:46.738963
#
# 2023-07-09 22:04:53,023: INFO: Progress[%]: 29.86 : PID-18507, L2A_Tables: start export for 20 m resolution, elapsed time[s]: 1.649, total: 0:13:48.387489
#
# 2023-07-09 22:05:00,491: INFO: Progress[%]: 30.13 : PID-18507, L2A_Tables: band B01 exported, elapsed time[s]: 7.469, total: 0:13:55.856081
#
# 2023-07-09 22:05:11,907: INFO: Progress[%]: 30.54 : PID-18507, L2A_Tables: band B02 exported, elapsed time[s]: 11.416, total: 0:14:07.271970
#
# 2023-07-09 22:05:23,298: INFO: Progress[%]: 30.95 : PID-18507, L2A_Tables: band B03 exported, elapsed time[s]: 11.391, total: 0:14:18.663030
#
# 2023-07-09 22:05:34,988: INFO: Progress[%]: 31.38 : PID-18507, L2A_Tables: band B04 exported, elapsed time[s]: 11.690, total: 0:14:30.352829
#
# 2023-07-09 22:05:46,242: INFO: Progress[%]: 31.79 : PID-18507, L2A_Tables: band B05 exported, elapsed time[s]: 11.254, total: 0:14:41.607041
#
# 2023-07-09 22:05:58,012: INFO: Progress[%]: 32.21 : PID-18507, L2A_Tables: band B06 exported, elapsed time[s]: 11.767, total: 0:14:53.374529
#
# 2023-07-09 22:06:09,685: INFO: Progress[%]: 32.64 : PID-18507, L2A_Tables: band B07 exported, elapsed time[s]: 11.675, total: 0:15:05.049428
#
# 2023-07-09 22:06:21,334: INFO: Progress[%]: 33.06 : PID-18507, L2A_Tables: band B8A exported, elapsed time[s]: 11.650, total: 0:15:16.699062
#
# 2023-07-09 22:06:32,448: INFO: Progress[%]: 33.46 : PID-18507, L2A_Tables: band B11 exported, elapsed time[s]: 11.114, total: 0:15:27.812719
#
# 2023-07-09 22:06:43,616: INFO: Progress[%]: 33.87 : PID-18507, L2A_Tables: band B12 exported, elapsed time[s]: 11.168, total: 0:15:38.981024
#
# 2023-07-09 22:06:45,512: INFO: Progress[%]: 33.94 : PID-18507, L2A_Tables: band SCL exported, elapsed time[s]: 1.896, total: 0:15:40.876757
#
# 2023-07-09 22:06:46,465: INFO: Progress[%]: 33.97 : PID-18507, L2A_Tables: band SNW exported, elapsed time[s]: 0.954, total: 0:15:41.830304
#
# 2023-07-09 22:06:49,296: INFO: Progress[%]: 34.07 : PID-18507, L2A_Tables: band CLD exported, elapsed time[s]: 2.831, total: 0:15:44.661228
#
# 2023-07-09 22:06:50,429: INFO: Progress[%]: 34.11 : PID-18507, L2A_Tables: band AOT exported, elapsed time[s]: 1.132, total: 0:15:45.793509
#
# 2023-07-09 22:06:59,287: INFO: Progress[%]: 34.43 : PID-18507, L2A_Tables: band WVP exported, elapsed time[s]: 8.857, total: 0:15:54.650191
#
# 2023-07-09 22:07:00,014: INFO: Progress[%]: 34.46 : PID-18507, L2A_Tables: band VIS exported, elapsed time[s]: 0.728, total: 0:15:55.378617
#
# 2023-07-09 22:07:02,248: INFO: Progress[%]: 34.54 : PID-18507, L2A_Tables: band PVI exported, elapsed time[s]: 2.234, total: 0:15:57.612897
#
# 2023-07-09 22:07:21,756: INFO: Progress[%]: 35.25 : PID-18507, L2A_Tables: band TCI exported, elapsed time[s]: 19.508, total: 0:16:17.120513
#
# 2023-07-09 22:07:21,777: INFO: Progress[%]: 35.25 : PID-18507, L2A_Tables: stop export, elapsed time[s]: 0.021, total: 0:16:17.141535
#
# 2023-07-09 22:07:21,792: INFO: Progress[%]: 35.25 : PID-18507, L2A_Tables: preparing downsampled export for 60 m resolution, elapsed time[s]: 0.015, total: 0:16:17.156776
#
# 2023-07-09 22:07:21,807: INFO: Progress[%]: 35.25 : PID-18507, L2A_Tables: start export for 60 m resolution, elapsed time[s]: 0.015, total: 0:16:17.172058
#
# 2023-07-09 22:07:23,989: INFO: Progress[%]: 35.33 : PID-18507, L2A_Tables: band B01 exported, elapsed time[s]: 2.182, total: 0:16:19.353633
#
# 2023-07-09 22:07:25,924: INFO: Progress[%]: 35.40 : PID-18507, L2A_Tables: band B02 exported, elapsed time[s]: 1.935, total: 0:16:21.288793
#
# 2023-07-09 22:07:28,573: INFO: Progress[%]: 35.50 : PID-18507, L2A_Tables: band B03 exported, elapsed time[s]: 2.649, total: 0:16:23.937455
#
# 2023-07-09 22:07:31,048: INFO: Progress[%]: 35.59 : PID-18507, L2A_Tables: band B04 exported, elapsed time[s]: 2.476, total: 0:16:26.413096
#
# 2023-07-09 22:07:33,613: INFO: Progress[%]: 35.68 : PID-18507, L2A_Tables: band B05 exported, elapsed time[s]: 2.565, total: 0:16:28.977669
#
# 2023-07-09 22:07:35,979: INFO: Progress[%]: 35.77 : PID-18507, L2A_Tables: band B06 exported, elapsed time[s]: 2.366, total: 0:16:31.343650
#
# 2023-07-09 22:07:38,430: INFO: Progress[%]: 35.85 : PID-18507, L2A_Tables: band B07 exported, elapsed time[s]: 2.451, total: 0:16:33.794747
#
# 2023-07-09 22:07:40,911: INFO: Progress[%]: 35.94 : PID-18507, L2A_Tables: band B8A exported, elapsed time[s]: 2.481, total: 0:16:36.275670
#
# 2023-07-09 22:07:43,290: INFO: Progress[%]: 36.03 : PID-18507, L2A_Tables: band B09 exported, elapsed time[s]: 2.379, total: 0:16:38.654622
#
# 2023-07-09 22:07:45,751: INFO: Progress[%]: 36.12 : PID-18507, L2A_Tables: band B11 exported, elapsed time[s]: 2.461, total: 0:16:41.115810
#
# 2023-07-09 22:07:48,163: INFO: Progress[%]: 36.21 : PID-18507, L2A_Tables: band B12 exported, elapsed time[s]: 2.413, total: 0:16:43.528332
#
# 2023-07-09 22:07:51,189: INFO: Progress[%]: 36.32 : PID-18507, L2A_Tables: band SCL exported, elapsed time[s]: 3.026, total: 0:16:46.554184
#
# 2023-07-09 22:07:51,737: INFO: Progress[%]: 36.34 : PID-18507, L2A_Tables: band SNW exported, elapsed time[s]: 0.548, total: 0:16:47.102025
#
# 2023-07-09 22:07:52,770: INFO: Progress[%]: 36.37 : PID-18507, L2A_Tables: band CLD exported, elapsed time[s]: 1.032, total: 0:16:48.134471
#
# 2023-07-09 22:07:53,569: INFO: Progress[%]: 36.40 : PID-18507, L2A_Tables: band AOT exported, elapsed time[s]: 0.799, total: 0:16:48.933710
#
# 2023-07-09 22:07:55,521: INFO: Progress[%]: 36.47 : PID-18507, L2A_Tables: band WVP exported, elapsed time[s]: 1.952, total: 0:16:50.885479
#
# 2023-07-09 22:07:55,535: INFO: Progress[%]: 36.47 : PID-18507, L2A_Tables: band TCI must be resampled, elapsed time[s]: 0.014, total: 0:16:50.899606
#
# 2023-07-09 22:07:59,071: INFO: Progress[%]: 36.60 : PID-18507, L2A_Tables: band TCI exported, elapsed time[s]: 3.536, total: 0:16:54.435984
#
# 2023-07-09 22:08:03,551: INFO: Progress[%]: 36.77 : PID-18507, L2A_ProcessTile: processing with resolution 10 m, elapsed time[s]: 4.479, total: 0:16:58.915472
#
# 2023-07-09 22:08:03,562: INFO: Progress[%]: 36.77 : PID-18507, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.011, total: 0:16:58.926787
#
# 2023-07-09 22:08:03,650: INFO: Progress[%]: 36.77 : PID-18507, L2A_Tables: remove unused bands for 10m resolution, elapsed time[s]: 0.088, total: 0:16:59.014587
#
# 2023-07-09 22:08:04,405: INFO: Progress[%]: 36.80 : PID-18507, L2A_Tables: start import, elapsed time[s]: 0.756, total: 0:16:59.770249
#
# 2023-07-09 22:08:10,482: INFO: Progress[%]: 37.02 : PID-18507, L2A_Tables: band B08 imported, elapsed time[s]: 6.077, total: 0:17:05.846928
#
# 2023-07-09 22:08:11,779: INFO: Progress[%]: 37.06 : PID-18507, L2A_Tables: band SCL needs to be resampled, elapsed time[s]: 1.296, total: 0:17:07.143283
#
# 2023-07-09 22:08:14,890: INFO: Progress[%]: 37.18 : PID-18507, L2A_Tables: band SCL imported, elapsed time[s]: 3.112, total: 0:17:10.254829
#
# 2023-07-09 22:08:16,097: INFO: Progress[%]: 37.22 : PID-18507, L2A_Tables: band AOT needs to be resampled, elapsed time[s]: 1.207, total: 0:17:11.462198
#
# 2023-07-09 22:08:19,252: INFO: Progress[%]: 37.34 : PID-18507, L2A_Tables: band AOT imported, elapsed time[s]: 3.155, total: 0:17:14.616857
#
# 2023-07-09 22:08:20,544: INFO: Progress[%]: 37.38 : PID-18507, L2A_Tables: band WVP needs to be resampled, elapsed time[s]: 1.292, total: 0:17:15.908692
#
# 2023-07-09 22:08:23,707: INFO: Progress[%]: 37.50 : PID-18507, L2A_Tables: band WVP imported, elapsed time[s]: 3.163, total: 0:17:19.071611
#
# 2023-07-09 22:08:24,895: INFO: Progress[%]: 37.54 : PID-18507, L2A_Tables: band VIS needs to be resampled, elapsed time[s]: 1.188, total: 0:17:20.259608
#
# 2023-07-09 22:08:28,060: INFO: Progress[%]: 37.65 : PID-18507, L2A_Tables: band VIS imported, elapsed time[s]: 3.165, total: 0:17:23.424944
#
# 2023-07-09 22:08:30,385: INFO: Progress[%]: 37.74 : PID-18507, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 2.325, total: 0:17:25.749618
#
# 2023-07-09 22:08:35,925: INFO: Progress[%]: 37.94 : PID-18507, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 5.539, total: 0:17:31.288846
#
# 2023-07-09 22:08:35,941: INFO: Progress[%]: 37.94 : PID-18507, L2A_AtmCorr: start of resampling visibility for 10 m resolution, elapsed time[s]: 0.017, total: 0:17:31.305578
#
# 2023-07-09 22:08:37,390: INFO: Progress[%]: 37.99 : PID-18507, L2A_AtmCorr: end of resampling visibility for 10 m resolution, elapsed time[s]: 1.449, total: 0:17:32.754292
#
# 2023-07-09 22:08:39,373: INFO: Progress[%]: 38.07 : PID-18507, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 1.984, total: 0:17:34.737973
#
# 2023-07-09 22:08:39,387: INFO: Progress[%]: 38.07 : PID-18507, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.014, total: 0:17:34.752191
#
# 2023-07-09 22:08:43,800: INFO: Progress[%]: 38.23 : PID-18507, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 4.413, total: 0:17:39.164746
#
# 2023-07-09 22:08:43,812: INFO: Progress[%]: 38.23 : PID-18507, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.012, total: 0:17:39.176770
#
# 2023-07-09 22:12:17,261: INFO: Progress[%]: 45.97 : PID-18507, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 213.447, total: 0:21:12.623766
#
# 2023-07-09 22:12:17,285: INFO: Progress[%]: 45.97 : PID-18507, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.026, total: 0:21:12.649872
#
# 2023-07-09 22:15:35,751: INFO: Progress[%]: 53.17 : PID-18507, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 198.463, total: 0:24:31.112868
#
# 2023-07-09 22:15:35,802: INFO: Progress[%]: 53.17 : PID-18507, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.054, total: 0:24:31.166570
#
# 2023-07-09 22:15:35,815: INFO: Progress[%]: 53.17 : PID-18507, L2A_Tables: start export for 10 m resolution, elapsed time[s]: 0.014, total: 0:24:31.180420
#
# 2023-07-09 22:16:13,815: INFO: Progress[%]: 54.55 : PID-18507, L2A_Tables: band B02 exported, elapsed time[s]: 38.000, total: 0:25:09.180279
#
# 2023-07-09 22:16:52,469: INFO: Progress[%]: 55.95 : PID-18507, L2A_Tables: band B03 exported, elapsed time[s]: 38.652, total: 0:25:47.832232
#
# 2023-07-09 22:17:31,725: INFO: Progress[%]: 57.37 : PID-18507, L2A_Tables: band B04 exported, elapsed time[s]: 39.258, total: 0:26:27.090160
#
# 2023-07-09 22:18:11,531: INFO: Progress[%]: 58.82 : PID-18507, L2A_Tables: band B08 exported, elapsed time[s]: 39.803, total: 0:27:06.892898
#
# 2023-07-09 22:18:18,105: INFO: Progress[%]: 59.06 : PID-18507, L2A_Tables: band AOT exported, elapsed time[s]: 6.576, total: 0:27:13.469357
#
# 2023-07-09 22:18:45,969: INFO: Progress[%]: 60.07 : PID-18507, L2A_Tables: band WVP exported, elapsed time[s]: 27.864, total: 0:27:41.333530
#
# 2023-07-09 22:19:56,561: INFO: Progress[%]: 62.63 : PID-18507, L2A_Tables: band TCI exported, elapsed time[s]: 70.590, total: 0:28:51.923458
#
# 2023-07-09 22:19:56,784: INFO: Progress[%]: 62.64 : PID-18507, L2A_Tables: stop export, elapsed time[s]: 0.225, total: 0:28:52.148919
#
# 2023-07-09 22:20:02,125: INFO: Progress[%]: 100.00 : Application terminated successfully.
#
# 2023-07-09 22:20:02,126: INFO:
#
# 2023-07-09 22:20:02,310: INFO: sen2cor processing finished for /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2A_MSIL1C_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 22:20:02,311: INFO: Checking for presence of band raster files in /home/sepal-user/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 22:20:02,344: INFO: Changing L2A path: /home/sepal-user/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 22:20:02,345: INFO:   to new L2A path: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE
# 2023-07-09 22:20:02,359: INFO:    image path = /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:20:02,360: INFO:    out_directory = /home/sepal-user/pyeo_dir/36NXG/images/L2A
# 2023-07-09 22:20:04,765: INFO:    out name = /home/sepal-user/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:20:04,766: INFO:    out path = /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:20:04,767: INFO:    out glob = /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG*
# 2023-07-09 22:20:04,771: INFO: Atmospheric correction of S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:20:07,090: INFO: Calling sen2cor:
# 2023-07-09 22:20:07,091: INFO: /home/sepal-user/Sen2Cor-02.10.01-Linux64/bin/L2A_Process --GIP_L2A /home/sepal-user/sen2cor/2.10/cfg/L2A_GIPP.xml /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE --output_dir /home/sepal-user/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:20:09,581: INFO: Product versions > 14.9 are not implemented yet.
#
# 2023-07-09 22:20:09,583: INFO: Version 14.9 will be used by default, but warnings during validation might occur.
#
# 2023-07-09 22:20:09,584: INFO:
#
# 2023-07-09 22:20:11,160: INFO: Sen2Cor. Version: 02.10.01, created: 2021.12.13, supporting Level-1C product version 14.2 - 14.9 started ...
#
# 2023-07-09 22:20:11,162: INFO: Product version: 14.9
#
# 2023-07-09 22:20:11,162: INFO: Operation mode: TOOLBOX
#
# 2023-07-09 22:20:11,172: INFO: Processing baseline: 99.99
#
# 2023-07-09 22:20:11,196: INFO: Progress[%]:  0.00 : Generating datastrip metadata
#
# 2023-07-09 22:20:14,209: INFO: L2A datastrip successfully generated
#
# 2023-07-09 22:20:14,547: INFO: No resolution specified, will process 20 and 10 m resolution
#
# 2023-07-09 22:20:14,548: INFO: 20 m resolution will be downsampled to 60 m
#
# 2023-07-09 22:20:16,967: INFO: Progress[%]: 0.09 : PID-19145, L2A_ProcessTile: processing with resolution 20 m, elapsed time[s]: 2.424, total: 0:00:07.657375
#
# 2023-07-09 22:20:16,978: INFO: Progress[%]: 0.09 : PID-19145, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.012, total: 0:00:07.668997
#
# 2023-07-09 22:20:17,069: INFO: Progress[%]: 0.09 : PID-19145, L2A_Tables: start import, elapsed time[s]: 0.091, total: 0:00:07.759860
#
# 2023-07-09 22:20:18,187: INFO: Progress[%]: 0.13 : PID-19145, L2A_Tables: band B01 imported, elapsed time[s]: 1.118, total: 0:00:08.877976
#
# 2023-07-09 22:20:24,217: INFO: Progress[%]: 0.34 : PID-19145, L2A_Tables: band B02 imported, elapsed time[s]: 6.030, total: 0:00:14.907562
#
# 2023-07-09 22:20:31,741: INFO: Progress[%]: 0.61 : PID-19145, L2A_Tables: band B03 imported, elapsed time[s]: 7.524, total: 0:00:22.431099
#
# 2023-07-09 22:20:39,015: INFO: Progress[%]: 0.87 : PID-19145, L2A_Tables: band B04 imported, elapsed time[s]: 7.275, total: 0:00:29.705771
#
# 2023-07-09 22:20:43,201: INFO: Progress[%]: 1.01 : PID-19145, L2A_Tables: band B05 imported, elapsed time[s]: 4.186, total: 0:00:33.891409
#
# 2023-07-09 22:20:46,431: INFO: Progress[%]: 1.13 : PID-19145, L2A_Tables: band B06 imported, elapsed time[s]: 3.230, total: 0:00:37.120936
#
# 2023-07-09 22:20:49,458: INFO: Progress[%]: 1.24 : PID-19145, L2A_Tables: band B07 imported, elapsed time[s]: 3.028, total: 0:00:40.148910
#
# 2023-07-09 22:20:53,813: INFO: Progress[%]: 1.39 : PID-19145, L2A_Tables: band B8A imported, elapsed time[s]: 4.355, total: 0:00:44.503680
#
# 2023-07-09 22:20:55,052: INFO: Progress[%]: 1.43 : PID-19145, L2A_Tables: band B09 imported, elapsed time[s]: 1.239, total: 0:00:45.742925
#
# 2023-07-09 22:20:56,825: INFO: Progress[%]: 1.50 : PID-19145, L2A_Tables: band B10 imported, elapsed time[s]: 1.772, total: 0:00:47.514531
#
# 2023-07-09 22:20:59,986: INFO: Progress[%]: 1.61 : PID-19145, L2A_Tables: band B11 imported, elapsed time[s]: 3.162, total: 0:00:50.676604
#
# 2023-07-09 22:21:03,079: INFO: Progress[%]: 1.72 : PID-19145, L2A_Tables: band B12 imported, elapsed time[s]: 3.093, total: 0:00:53.769509
#
# 2023-07-09 22:21:03,314: INFO: Progress[%]: 1.73 : PID-19145, L2A_Tables: AUX_CAMS* file found., elapsed time[s]: 0.235, total: 0:00:54.004331
#
# 2023-07-09 22:21:16,295: INFO: Progress[%]: 2.18 : PID-19145, L2A_Tables: Visibility map from file AUX_CAMSFO prepared, elapsed time[s]: 12.981, total: 0:01:06.985360
#
# 2023-07-09 22:21:16,320: INFO: Progress[%]: 2.19 : PID-19145, L2A_ProcessTile: start of Scene Classification, elapsed time[s]: 0.026, total: 0:01:07.011115
#
# 2023-07-09 22:21:17,252: INFO: Progress[%]: 2.22 : PID-19145, L2A_Tables: band B02 must be resampled, elapsed time[s]: 0.931, total: 0:01:07.942599
#
# 2023-07-09 22:21:19,346: INFO: Progress[%]: 2.29 : PID-19145, Pre process   , elapsed time[s]: 2.094, total: 0:01:10.036253
#
# 2023-07-09 22:21:19,408: INFO: Progress[%]: 2.29 : PID-19145, L2A_Tables: band B01 must be resampled, elapsed time[s]: 0.063, total: 0:01:10.099181
#
# 2023-07-09 22:21:24,484: INFO: Progress[%]: 2.47 : PID-19145, L2A_Tables: band B03 must be resampled, elapsed time[s]: 5.075, total: 0:01:15.174256
#
# 2023-07-09 22:21:27,331: INFO: Progress[%]: 2.57 : PID-19145, L2A_Tables: band B04 must be resampled, elapsed time[s]: 2.848, total: 0:01:18.021954
#
# 2023-07-09 22:21:30,581: INFO: Progress[%]: 2.69 : PID-19145, L2A_Tables: band B09 must be resampled, elapsed time[s]: 3.250, total: 0:01:21.271590
#
# 2023-07-09 22:21:32,835: INFO: Progress[%]: 2.77 : PID-19145, L2A_Tables: band B10 must be resampled, elapsed time[s]: 2.254, total: 0:01:23.525743
#
# 2023-07-09 22:21:35,606: INFO: Progress[%]: 2.87 : PID-19145, L2A_SC init   , elapsed time[s]: 2.771, total: 0:01:26.296333
#
# 2023-07-09 22:21:36,803: INFO: Progress[%]: 2.91 : PID-19145, L2A_CSND_1_1  , elapsed time[s]: 1.197, total: 0:01:27.493650
#
# 2023-07-09 22:21:38,005: INFO: Progress[%]: 2.95 : PID-19145, L2A_CSND_1_2  , elapsed time[s]: 1.202, total: 0:01:28.695629
#
# 2023-07-09 22:21:38,192: INFO: Progress[%]: 2.96 : PID-19145, L2A_CSND_2_0  , elapsed time[s]: 0.187, total: 0:01:28.882615
#
# 2023-07-09 22:21:39,168: INFO: Progress[%]: 2.99 : PID-19145, L2A_CSND_2_1  , elapsed time[s]: 0.976, total: 0:01:29.858602
#
# 2023-07-09 22:21:39,677: INFO: Progress[%]: 3.01 : PID-19145, L2A_CSND_2_1_2, elapsed time[s]: 0.509, total: 0:01:30.367389
#
# 2023-07-09 22:21:40,089: INFO: Progress[%]: 3.03 : PID-19145, L2A_CSND_2_2  , elapsed time[s]: 0.412, total: 0:01:30.779041
#
# 2023-07-09 22:21:40,833: INFO: Progress[%]: 3.05 : PID-19145, L2A_CSND_2_3  , elapsed time[s]: 0.745, total: 0:01:31.523731
#
# 2023-07-09 22:21:41,794: INFO: Progress[%]: 3.09 : PID-19145, L2A_CSND_2_4  , elapsed time[s]: 0.960, total: 0:01:32.484030
#
# 2023-07-09 22:21:43,918: INFO: Progress[%]: 3.16 : PID-19145, L2A_CSND_2_5  , elapsed time[s]: 2.124, total: 0:01:34.608115
#
# 2023-07-09 22:21:43,931: INFO: Progress[%]: 3.16 : PID-19145, L2A_SnowPostProcessingCCI  , elapsed time[s]: 0.014, total: 0:01:34.622190
#
# 2023-07-09 22:21:45,910: INFO: Progress[%]: 3.23 : PID-19145, L2A_CSND_3    , elapsed time[s]: 1.978, total: 0:01:36.600447
#
# 2023-07-09 22:21:47,392: INFO: Progress[%]: 3.28 : PID-19145, L2A_CSND_5_1  , elapsed time[s]: 1.482, total: 0:01:38.082819
#
# 2023-07-09 22:21:49,345: INFO: Progress[%]: 3.35 : PID-19145, L2A_CSND_5_2  , elapsed time[s]: 1.952, total: 0:01:40.035054
#
# 2023-07-09 22:21:50,901: INFO: Progress[%]: 3.41 : PID-19145, L2A_CSND_6    , elapsed time[s]: 1.556, total: 0:01:41.591327
#
# 2023-07-09 22:21:51,880: INFO: Progress[%]: 3.44 : PID-19145, L2A_CSND_6_2  , elapsed time[s]: 0.980, total: 0:01:42.570845
#
# 2023-07-09 22:21:53,478: INFO: Progress[%]: 3.50 : PID-19145, L2A_CSND_7    , elapsed time[s]: 1.597, total: 0:01:44.167985
#
# 2023-07-09 22:21:54,758: INFO: Progress[%]: 3.54 : PID-19145, DV recovery   , elapsed time[s]: 1.280, total: 0:01:45.448099
#
# 2023-07-09 22:21:56,118: INFO: Progress[%]: 3.59 : PID-19145, WP recovery   , elapsed time[s]: 1.360, total: 0:01:46.808519
#
# 2023-07-09 22:21:56,133: INFO: Progress[%]: 3.59 : PID-19145, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.015, total: 0:01:46.823932
#
# 2023-07-09 22:21:58,353: INFO: Progress[%]: 3.67 : PID-19145, Snow recovery , elapsed time[s]: 2.218, total: 0:01:49.041996
#
# 2023-07-09 22:22:04,442: INFO: Progress[%]: 3.89 : PID-19145, SnowSoilBorders, elapsed time[s]: 6.090, total: 0:01:55.131768
#
# 2023-07-09 22:22:05,172: INFO: Progress[%]: 3.91 : PID-19145, Soil recovery , elapsed time[s]: 0.731, total: 0:01:55.862825
#
# 2023-07-09 22:22:05,187: INFO: Progress[%]: 3.91 : PID-19145, Cirrus recovery with B10 , elapsed time[s]: 0.015, total: 0:01:55.877509
#
# 2023-07-09 22:22:05,201: INFO: Progress[%]: 3.91 : PID-19145, Urban and Bare pixel recovery with CCI Land Cover Map at 300 m , elapsed time[s]: 0.014, total: 0:01:55.891293
#
# 2023-07-09 22:22:19,039: INFO: Progress[%]: 4.40 : PID-19145, Bright pixels Hollstein Fmask, elapsed time[s]: 13.836, total: 0:02:09.727744
#
# 2023-07-09 22:23:53,421: INFO: Cloud heights processed in 0:00:28.663060 seconds
#
# 2023-07-09 22:23:53,440: INFO: Progress[%]: 7.74 : PID-19145, L2A_SHD       , elapsed time[s]: 94.381, total: 0:03:44.109034
#
# 2023-07-09 22:23:53,444: INFO: Progress[%]: 7.74 : PID-19145, WP recovery with CCI Water Bodies at 150m  , elapsed time[s]: 0.017, total: 0:03:44.125727
#
# 2023-07-09 22:23:55,726: INFO: Progress[%]: 7.82 : PID-19145, Topographic casted shadow Pixels post processing, elapsed time[s]: 2.290, total: 0:03:46.416221
#
# 2023-07-09 22:23:56,621: INFO: Progress[%]: 7.86 : PID-19145, Post process  , elapsed time[s]: 0.895, total: 0:03:47.311648
#
# 2023-07-09 22:23:56,803: INFO: Progress[%]: 7.86 : PID-19145, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 0.181, total: 0:03:47.493133
#
# 2023-07-09 22:23:58,171: INFO: Progress[%]: 7.91 : PID-19145, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 1.368, total: 0:03:48.861363
#
# 2023-07-09 22:23:58,183: INFO: Progress[%]: 7.91 : PID-19145, L2A_AtmCorr: start of AOT retrieval at 550nm, elapsed time[s]: 0.012, total: 0:03:48.873728
#
# 2023-07-09 22:24:04,451: INFO: Progress[%]: 8.13 : PID-19145, L2A_AtmCorr: end of internal classification, elapsed time[s]: 6.268, total: 0:03:55.141613
#
# 2023-07-09 22:24:05,335: INFO: Progress[%]: 8.16 : PID-19145, L2A_AtmCorr: end of interpolation LUTs, elapsed time[s]: 0.884, total: 0:03:56.025398
#
# 2023-07-09 22:24:24,653: INFO: Progress[%]: 8.85 : PID-19145, L2A_AtmCorr: end retrieving reference pixels for dark areas, elapsed time[s]: 19.318, total: 0:04:15.342916
#
# 2023-07-09 22:26:13,525: INFO: Progress[%]: 12.70 : PID-19145, L2A_AtmCorr: end of check for negative reflectance pixels, elapsed time[s]: 108.870, total: 0:06:04.213263
#
# 2023-07-09 22:26:16,769: INFO: Progress[%]: 12.81 : PID-19145, L2A_AtmCorr: the rescaling of path radiance in blue band has been disabled by configuration, elapsed time[s]: 3.246, total: 0:06:07.459454
#
# 2023-07-09 22:27:16,194: INFO: Progress[%]: 14.91 : PID-19145, L2A_AtmCorr: end of visibility index calculation, elapsed time[s]: 59.423, total: 0:07:06.882489
#
# 2023-07-09 22:27:16,206: INFO: Progress[%]: 14.91 : PID-19145, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 0.014, total: 0:07:06.896452
#
# 2023-07-09 22:27:16,222: INFO: Progress[%]: 14.92 : PID-19145, L2A_AtmCorr: start of water vapour retrieval, elapsed time[s]: 0.017, total: 0:07:06.913183
#
# 2023-07-09 22:27:17,568: INFO: Progress[%]: 14.96 : PID-19145, L2A_AtmCorr: end of water vapour retrieval preparation, elapsed time[s]: 1.345, total: 0:07:08.258410
#
# 2023-07-09 22:30:32,006: INFO: Progress[%]: 21.84 : PID-19145, L2A_AtmCorr: end of water vapour retrieval, elapsed time[s]: 194.436, total: 0:10:22.694354
#
# 2023-07-09 22:30:32,021: INFO: Progress[%]: 21.84 : PID-19145, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.017, total: 0:10:22.711753
#
# 2023-07-09 22:30:39,094: INFO: Progress[%]: 22.09 : PID-19145, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 7.073, total: 0:10:29.784335
#
# 2023-07-09 22:30:39,107: INFO: Progress[%]: 22.09 : PID-19145, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.013, total: 0:10:29.797790
#
# 2023-07-09 22:32:57,553: INFO: Progress[%]: 26.99 : PID-19145, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 138.444, total: 0:12:48.241623
#
# 2023-07-09 22:32:57,569: INFO: Progress[%]: 26.99 : PID-19145, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.018, total: 0:12:48.259449
#
# 2023-07-09 22:34:00,848: INFO: Progress[%]: 29.23 : PID-19145, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 63.277, total: 0:13:51.536394
#
# 2023-07-09 22:34:00,895: INFO: Progress[%]: 29.23 : PID-19145, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.049, total: 0:13:51.585331
#
# 2023-07-09 22:34:02,627: INFO: Progress[%]: 29.29 : PID-19145, L2A_Tables: start export for 20 m resolution, elapsed time[s]: 1.732, total: 0:13:53.317740
#
# 2023-07-09 22:34:09,955: INFO: Progress[%]: 29.55 : PID-19145, L2A_Tables: band B01 exported, elapsed time[s]: 7.328, total: 0:14:00.645770
#
# 2023-07-09 22:34:21,144: INFO: Progress[%]: 29.95 : PID-19145, L2A_Tables: band B02 exported, elapsed time[s]: 11.189, total: 0:14:11.835073
#
# 2023-07-09 22:34:32,768: INFO: Progress[%]: 30.36 : PID-19145, L2A_Tables: band B03 exported, elapsed time[s]: 11.623, total: 0:14:23.458272
#
# 2023-07-09 22:34:44,362: INFO: Progress[%]: 30.77 : PID-19145, L2A_Tables: band B04 exported, elapsed time[s]: 11.595, total: 0:14:35.052873
#
# 2023-07-09 22:34:55,485: INFO: Progress[%]: 31.16 : PID-19145, L2A_Tables: band B05 exported, elapsed time[s]: 11.123, total: 0:14:46.175986
#
# 2023-07-09 22:35:06,816: INFO: Progress[%]: 31.56 : PID-19145, L2A_Tables: band B06 exported, elapsed time[s]: 11.328, total: 0:14:57.504140
#
# 2023-07-09 22:35:18,631: INFO: Progress[%]: 31.98 : PID-19145, L2A_Tables: band B07 exported, elapsed time[s]: 11.818, total: 0:15:09.322084
#
# 2023-07-09 22:35:30,001: INFO: Progress[%]: 32.38 : PID-19145, L2A_Tables: band B8A exported, elapsed time[s]: 11.369, total: 0:15:20.691468
#
# 2023-07-09 22:35:41,062: INFO: Progress[%]: 32.77 : PID-19145, L2A_Tables: band B11 exported, elapsed time[s]: 11.061, total: 0:15:31.752210
#
# 2023-07-09 22:35:52,002: INFO: Progress[%]: 33.16 : PID-19145, L2A_Tables: band B12 exported, elapsed time[s]: 10.941, total: 0:15:42.692887
#
# 2023-07-09 22:35:53,830: INFO: Progress[%]: 33.22 : PID-19145, L2A_Tables: band SCL exported, elapsed time[s]: 1.828, total: 0:15:44.520393
#
# 2023-07-09 22:35:54,531: INFO: Progress[%]: 33.25 : PID-19145, L2A_Tables: band SNW exported, elapsed time[s]: 0.701, total: 0:15:45.221479
#
# 2023-07-09 22:35:56,913: INFO: Progress[%]: 33.33 : PID-19145, L2A_Tables: band CLD exported, elapsed time[s]: 2.382, total: 0:15:47.603288
#
# 2023-07-09 22:35:58,138: INFO: Progress[%]: 33.38 : PID-19145, L2A_Tables: band AOT exported, elapsed time[s]: 1.226, total: 0:15:48.829092
#
# 2023-07-09 22:36:06,111: INFO: Progress[%]: 33.66 : PID-19145, L2A_Tables: band WVP exported, elapsed time[s]: 7.973, total: 0:15:56.801859
#
# 2023-07-09 22:36:06,858: INFO: Progress[%]: 33.68 : PID-19145, L2A_Tables: band VIS exported, elapsed time[s]: 0.745, total: 0:15:57.547158
#
# 2023-07-09 22:36:09,450: INFO: Progress[%]: 33.78 : PID-19145, L2A_Tables: band PVI exported, elapsed time[s]: 2.593, total: 0:16:00.140531
#
# 2023-07-09 22:36:27,248: INFO: Progress[%]: 34.41 : PID-19145, L2A_Tables: band TCI exported, elapsed time[s]: 17.798, total: 0:16:17.938963
#
# 2023-07-09 22:36:27,269: INFO: Progress[%]: 34.41 : PID-19145, L2A_Tables: stop export, elapsed time[s]: 0.020, total: 0:16:17.959370
#
# 2023-07-09 22:36:27,284: INFO: Progress[%]: 34.41 : PID-19145, L2A_Tables: preparing downsampled export for 60 m resolution, elapsed time[s]: 0.015, total: 0:16:17.974534
#
# 2023-07-09 22:36:27,300: INFO: Progress[%]: 34.41 : PID-19145, L2A_Tables: start export for 60 m resolution, elapsed time[s]: 0.016, total: 0:16:17.990317
#
# 2023-07-09 22:36:29,608: INFO: Progress[%]: 34.49 : PID-19145, L2A_Tables: band B01 exported, elapsed time[s]: 2.309, total: 0:16:20.298926
#
# 2023-07-09 22:36:31,542: INFO: Progress[%]: 34.56 : PID-19145, L2A_Tables: band B02 exported, elapsed time[s]: 1.934, total: 0:16:22.232565
#
# 2023-07-09 22:36:34,393: INFO: Progress[%]: 34.66 : PID-19145, L2A_Tables: band B03 exported, elapsed time[s]: 2.851, total: 0:16:25.084042
#
# 2023-07-09 22:36:36,931: INFO: Progress[%]: 34.75 : PID-19145, L2A_Tables: band B04 exported, elapsed time[s]: 2.538, total: 0:16:27.621746
#
# 2023-07-09 22:36:39,380: INFO: Progress[%]: 34.84 : PID-19145, L2A_Tables: band B05 exported, elapsed time[s]: 2.449, total: 0:16:30.070725
#
# 2023-07-09 22:36:41,808: INFO: Progress[%]: 34.92 : PID-19145, L2A_Tables: band B06 exported, elapsed time[s]: 2.428, total: 0:16:32.498425
#
# 2023-07-09 22:36:44,449: INFO: Progress[%]: 35.01 : PID-19145, L2A_Tables: band B07 exported, elapsed time[s]: 2.641, total: 0:16:35.139510
#
# 2023-07-09 22:36:46,776: INFO: Progress[%]: 35.10 : PID-19145, L2A_Tables: band B8A exported, elapsed time[s]: 2.327, total: 0:16:37.466765
#
# 2023-07-09 22:36:49,225: INFO: Progress[%]: 35.18 : PID-19145, L2A_Tables: band B09 exported, elapsed time[s]: 2.449, total: 0:16:39.915878
#
# 2023-07-09 22:36:51,584: INFO: Progress[%]: 35.27 : PID-19145, L2A_Tables: band B11 exported, elapsed time[s]: 2.359, total: 0:16:42.274473
#
# 2023-07-09 22:36:54,016: INFO: Progress[%]: 35.35 : PID-19145, L2A_Tables: band B12 exported, elapsed time[s]: 2.432, total: 0:16:44.706616
#
# 2023-07-09 22:36:56,947: INFO: Progress[%]: 35.46 : PID-19145, L2A_Tables: band SCL exported, elapsed time[s]: 2.931, total: 0:16:47.637815
#
# 2023-07-09 22:36:57,458: INFO: Progress[%]: 35.47 : PID-19145, L2A_Tables: band SNW exported, elapsed time[s]: 0.510, total: 0:16:48.148277
#
# 2023-07-09 22:36:58,376: INFO: Progress[%]: 35.51 : PID-19145, L2A_Tables: band CLD exported, elapsed time[s]: 0.918, total: 0:16:49.066437
#
# 2023-07-09 22:36:59,426: INFO: Progress[%]: 35.54 : PID-19145, L2A_Tables: band AOT exported, elapsed time[s]: 1.050, total: 0:16:50.116426
#
# 2023-07-09 22:37:01,330: INFO: Progress[%]: 35.61 : PID-19145, L2A_Tables: band WVP exported, elapsed time[s]: 1.904, total: 0:16:52.020623
#
# 2023-07-09 22:37:01,344: INFO: Progress[%]: 35.61 : PID-19145, L2A_Tables: band TCI must be resampled, elapsed time[s]: 0.014, total: 0:16:52.034673
#
# 2023-07-09 22:37:04,885: INFO: Progress[%]: 35.74 : PID-19145, L2A_Tables: band TCI exported, elapsed time[s]: 3.541, total: 0:16:55.575732
#
# 2023-07-09 22:37:09,617: INFO: Progress[%]: 35.90 : PID-19145, L2A_ProcessTile: processing with resolution 10 m, elapsed time[s]: 4.731, total: 0:17:00.306849
#
# 2023-07-09 22:37:09,629: INFO: Progress[%]: 35.91 : PID-19145, L2A_ProcessTile: start of pre processing, elapsed time[s]: 0.013, total: 0:17:00.319829
#
# 2023-07-09 22:37:09,717: INFO: Progress[%]: 35.91 : PID-19145, L2A_Tables: remove unused bands for 10m resolution, elapsed time[s]: 0.088, total: 0:17:00.407917
#
# 2023-07-09 22:37:10,495: INFO: Progress[%]: 35.94 : PID-19145, L2A_Tables: start import, elapsed time[s]: 0.778, total: 0:17:01.186052
#
# 2023-07-09 22:37:16,473: INFO: Progress[%]: 36.15 : PID-19145, L2A_Tables: band B08 imported, elapsed time[s]: 5.977, total: 0:17:07.163530
#
# 2023-07-09 22:37:17,694: INFO: Progress[%]: 36.19 : PID-19145, L2A_Tables: band SCL needs to be resampled, elapsed time[s]: 1.221, total: 0:17:08.384839
#
# 2023-07-09 22:37:20,779: INFO: Progress[%]: 36.30 : PID-19145, L2A_Tables: band SCL imported, elapsed time[s]: 3.085, total: 0:17:11.469732
#
# 2023-07-09 22:37:21,973: INFO: Progress[%]: 36.34 : PID-19145, L2A_Tables: band AOT needs to be resampled, elapsed time[s]: 1.193, total: 0:17:12.663208
#
# 2023-07-09 22:37:25,107: INFO: Progress[%]: 36.45 : PID-19145, L2A_Tables: band AOT imported, elapsed time[s]: 3.134, total: 0:17:15.797078
#
# 2023-07-09 22:37:26,323: INFO: Progress[%]: 36.50 : PID-19145, L2A_Tables: band WVP needs to be resampled, elapsed time[s]: 1.217, total: 0:17:17.013827
#
# 2023-07-09 22:37:29,477: INFO: Progress[%]: 36.61 : PID-19145, L2A_Tables: band WVP imported, elapsed time[s]: 3.153, total: 0:17:20.167310
#
# 2023-07-09 22:37:30,774: INFO: Progress[%]: 36.65 : PID-19145, L2A_Tables: band VIS needs to be resampled, elapsed time[s]: 1.298, total: 0:17:21.465035
#
# 2023-07-09 22:37:33,927: INFO: Progress[%]: 36.76 : PID-19145, L2A_Tables: band VIS imported, elapsed time[s]: 3.152, total: 0:17:24.617372
#
# 2023-07-09 22:37:36,123: INFO: Progress[%]: 36.84 : PID-19145, L2A_ProcessTile: start of Atmospheric Correction, elapsed time[s]: 2.196, total: 0:17:26.812924
#
# 2023-07-09 22:37:41,648: INFO: Progress[%]: 37.04 : PID-19145, L2A_AtmCorr: end of calculation terrain maps, elapsed time[s]: 5.525, total: 0:17:32.338136
#
# 2023-07-09 22:37:41,660: INFO: Progress[%]: 37.04 : PID-19145, L2A_AtmCorr: start of resampling visibility for 10 m resolution, elapsed time[s]: 0.013, total: 0:17:32.351089
#
# 2023-07-09 22:37:43,231: INFO: Progress[%]: 37.09 : PID-19145, L2A_AtmCorr: end of resampling visibility for 10 m resolution, elapsed time[s]: 1.570, total: 0:17:33.921292
#
# 2023-07-09 22:37:45,210: INFO: Progress[%]: 37.16 : PID-19145, L2A_AtmCorr: end of AOT retrieval at 550nm, elapsed time[s]: 1.980, total: 0:17:35.900825
#
# 2023-07-09 22:37:45,221: INFO: Progress[%]: 37.16 : PID-19145, L2A_AtmCorr: preparation of surface reflectance retrieval, elapsed time[s]: 0.011, total: 0:17:35.912101
#
# 2023-07-09 22:37:49,727: INFO: Progress[%]: 37.32 : PID-19145, L2A_AtmCorr: end of surface reflectance retrieval preparation, elapsed time[s]: 4.505, total: 0:17:40.417522
#
# 2023-07-09 22:37:49,738: INFO: Progress[%]: 37.32 : PID-19145, L2A_AtmCorr: start of surface reflectance retrieval, elapsed time[s]: 0.012, total: 0:17:40.429097
#
# 2023-07-09 22:41:19,194: INFO: Progress[%]: 44.73 : PID-19145, L2A_AtmCorr: end of surface reflectance retrieval, elapsed time[s]: 209.454, total: 0:21:09.882960
#
# 2023-07-09 22:41:19,217: INFO: Progress[%]: 44.73 : PID-19145, L2A_AtmCorr: start of rho retrieval step 2, elapsed time[s]: 0.024, total: 0:21:09.907386
#
# 2023-07-09 22:44:36,669: INFO: Progress[%]: 51.72 : PID-19145, L2A_AtmCorr: end of rho retrieval step 2, elapsed time[s]: 197.451, total: 0:24:27.357909
#
# 2023-07-09 22:44:36,719: INFO: Progress[%]: 51.72 : PID-19145, L2A_ProcessTile: start of post processing, elapsed time[s]: 0.051, total: 0:24:27.409217
#
# 2023-07-09 22:44:36,731: INFO: Progress[%]: 51.72 : PID-19145, L2A_Tables: start export for 10 m resolution, elapsed time[s]: 0.013, total: 0:24:27.421745
#
# 2023-07-09 22:45:14,512: INFO: Progress[%]: 53.06 : PID-19145, L2A_Tables: band B02 exported, elapsed time[s]: 37.780, total: 0:25:05.202165
#
# 2023-07-09 22:45:53,213: INFO: Progress[%]: 54.43 : PID-19145, L2A_Tables: band B03 exported, elapsed time[s]: 38.699, total: 0:25:43.901340
#
# 2023-07-09 22:46:32,536: INFO: Progress[%]: 55.82 : PID-19145, L2A_Tables: band B04 exported, elapsed time[s]: 39.325, total: 0:26:23.226202
#
# 2023-07-09 22:47:11,778: INFO: Progress[%]: 57.20 : PID-19145, L2A_Tables: band B08 exported, elapsed time[s]: 39.240, total: 0:27:02.466147
#
# 2023-07-09 22:47:17,796: INFO: Progress[%]: 57.42 : PID-19145, L2A_Tables: band AOT exported, elapsed time[s]: 6.020, total: 0:27:08.486495
#
# 2023-07-09 22:47:43,568: INFO: Progress[%]: 58.33 : PID-19145, L2A_Tables: band WVP exported, elapsed time[s]: 25.773, total: 0:27:34.259094
#
# 2023-07-09 22:48:53,011: INFO: Progress[%]: 60.78 : PID-19145, L2A_Tables: band TCI exported, elapsed time[s]: 69.441, total: 0:28:43.699966
#
# 2023-07-09 22:48:53,230: INFO: Progress[%]: 60.79 : PID-19145, L2A_Tables: stop export, elapsed time[s]: 0.220, total: 0:28:43.920158
#
# 2023-07-09 22:48:58,187: INFO: Progress[%]: 100.00 : Application terminated successfully.
#
# 2023-07-09 22:48:58,188: INFO:
#
# 2023-07-09 22:48:58,371: INFO: sen2cor processing finished for /home/sepal-user/pyeo_dir/36NXG/images/L1C/S2B_MSIL1C_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:48:58,372: INFO: Checking for presence of band raster files in /home/sepal-user/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:48:58,406: INFO: Changing L2A path: /home/sepal-user/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:48:58,407: INFO:   to new L2A path: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE
# 2023-07-09 22:48:58,418: INFO: Successfully downloaded the Sentinel-2 L1C products

# %% [markdown]
# ## <a id='toc4_5_'></a>[Download L2A Change Imagery](#toc0_)

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if l2a_products.shape[0] > 0:
        tile_log.info(f"Downloading Sentinel-2 L2A products from {download_source}")

        if download_source == "scihub":
            queries_and_downloads.download_s2_data(
                l2a_products.to_dict("index"),
                l1_image_dir,
                l2_image_dir,
                download_source,
                user=sen_user,
                passwd=sen_pass,
                try_scihub_on_fail=True,
            )
        if download_source == "dataspace":
            queries_and_downloads.download_s2_data_from_dataspace(
                product_df=l2a_products,
                l1c_directory=l1_image_dir,
                l2a_directory=l2_image_dir,
                dataspace_username=sen_user,
                dataspace_password=sen_pass,
                log=tile_log
            )

    # check for incomplete L2A downloads and remove them
    incomplete_downloads, sizes = raster_manipulation.find_small_safe_dirs(
        l2_image_dir, threshold=faulty_granule_threshold * 1024 * 1024
    )
    if len(incomplete_downloads) > 0:
        for index, safe_dir in enumerate(incomplete_downloads):
            if sizes[
                index
            ] / 1024 / 1024 < faulty_granule_threshold and os.path.exists(safe_dir):
                tile_log.warning(
                    "Found likely incomplete download of size {} MB: {}".format(
                        str(round(sizes[index] / 1024 / 1024)), safe_dir
                    )
                )

    tile_log.info("Successfully downloaded the Sentinel-2 L2A products")

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Image download and atmospheric correction for change detection images is complete.")
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 22:48:58,441: INFO: Downloading Sentinel-2 L2A products from dataspace
# 2023-07-09 22:48:58,467: INFO:     Checking 1 of 6 : S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE
# 2023-07-09 22:48:58,553: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:58,553: INFO:     Checking 2 of 6 : S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE
# 2023-07-09 22:48:58,634: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:58,635: INFO:     Checking 3 of 6 : S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE
# 2023-07-09 22:48:58,707: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:58,707: INFO:     Checking 4 of 6 : S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE
# 2023-07-09 22:48:58,781: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:58,781: INFO:     Checking 5 of 6 : S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE
# 2023-07-09 22:48:58,854: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:58,855: INFO:     Checking 6 of 6 : S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE
# 2023-07-09 22:48:58,927: INFO:         /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE imagery already exists, skipping download
# 2023-07-09 22:48:59,155: INFO: Successfully downloaded the Sentinel-2 L2A products
# 2023-07-09 22:48:59,157: INFO: ---------------------------------------------------------------
# 2023-07-09 22:48:59,158: INFO: Image download and atmospheric correction for change detection images is complete.
# 2023-07-09 22:48:59,159: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### <a id='toc4_5_1_'></a>[Housekeeping - Compress L1Cs](#toc0_)

# %% [markdown]
# If you have set your `do_zip` argument to `True`, then this cell will compress the L1Cs now that they have been atmospherically corrected and relabelled as L2As.

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if config_dict["do_delete"]:
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Deleting L1C images downloaded for change detection.")
        tile_log.info("Keeping only the derived L2A images after atmospheric correction.")
        tile_log.info("---------------------------------------------------------------")
        directory = l1_image_dir
        tile_log.info("Deleting {}".format(directory))
        shutil.rmtree(directory)
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Deletion complete")
        tile_log.info("---------------------------------------------------------------")
    else:
        if config_dict["do_zip"]:
            tile_log.info("---------------------------------------------------------------")
            tile_log.info("Zipping L1C images downloaded for change detection")
            tile_log.info("---------------------------------------------------------------")
            filesystem_utilities.zip_contents(l1_image_dir)
            tile_log.info("---------------------------------------------------------------")
            tile_log.info("Zipping complete")
            tile_log.info("---------------------------------------------------------------")

    tile_log.info("Cell successfully finished")
# Out:
# 2023-07-09 22:48:59,170: INFO: Cell successfully finished

# %% [markdown]
# ## <a id='toc4_6_'></a>[Cloud Masking, Offsetting and Quicklooks](#toc0_)

# %% [markdown]
# Here, like before in the previous session, we cloud mask, apply the baseline offset correction and produce quicklooks (if selected).
#
# Additionally, if you have set the `do_zip` flag to True, then `pyeo_1` will compress the cloud masked L2A images, as we no longer need these once classified.

# %% [markdown]
# ### Cloud Masking

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Applying simple cloud, cloud shadow and haze mask based on SCL files and stacking the masked band raster files."
    )
    tile_log.info("---------------------------------------------------------------")

    raster_manipulation.apply_scl_cloud_mask(
        l2_image_dir,
        l2_masked_image_dir,
        scl_classes=[0, 1, 2, 3, 8, 9, 10, 11],
        buffer_size=buffer_size,
        bands=bands,
        out_resolution=out_resolution,
        haze=None,
        epsg=epsg,
        skip_existing=skip_existing,
    )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Cloud masking and band stacking of new L2A images are complete.")
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 22:48:59,230: INFO: ---------------------------------------------------------------
# 2023-07-09 22:48:59,231: INFO: Applying simple cloud, cloud shadow and haze mask based on SCL files and stacking the masked band raster files.
# 2023-07-09 22:48:59,232: INFO: ---------------------------------------------------------------
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE/GRANULE/L2A_T36NXG_A030763_20230126T080451/IMG_DATA/R10m/T36NXG_20230126T075109_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE/GRANULE/L2A_T36NXG_A030763_20230126T080451/IMG_DATA/R10m/T36NXG_20230126T075109_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE/GRANULE/L2A_T36NXG_A030763_20230126T080451/IMG_DATA/R10m/T36NXG_20230126T075109_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230126T075109_N0509_R135_T36NXG_20230126T101405.SAFE/GRANULE/L2A_T36NXG_A030763_20230126T080451/IMG_DATA/R10m/T36NXG_20230126T075109_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE/GRANULE/L2A_T36NXG_A039600_20230121T080456/IMG_DATA/R10m/T36NXG_20230121T075231_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE/GRANULE/L2A_T36NXG_A039600_20230121T080456/IMG_DATA/R10m/T36NXG_20230121T075231_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE/GRANULE/L2A_T36NXG_A039600_20230121T080456/IMG_DATA/R10m/T36NXG_20230121T075231_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230121T075231_N0509_R135_T36NXG_20230121T110651.SAFE/GRANULE/L2A_T36NXG_A039600_20230121T080456/IMG_DATA/R10m/T36NXG_20230121T075231_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE/GRANULE/L2A_T36NXG_A030477_20230106T080450/IMG_DATA/R10m/T36NXG_20230106T075219_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE/GRANULE/L2A_T36NXG_A030477_20230106T080450/IMG_DATA/R10m/T36NXG_20230106T075219_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE/GRANULE/L2A_T36NXG_A030477_20230106T080450/IMG_DATA/R10m/T36NXG_20230106T075219_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230106T075219_N0509_R135_T36NXG_20230106T101809.SAFE/GRANULE/L2A_T36NXG_A030477_20230106T080450/IMG_DATA/R10m/T36NXG_20230106T075219_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE/GRANULE/L2A_T36NXG_A030906_20230205T080451/IMG_DATA/R10m/T36NXG_20230205T075019_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE/GRANULE/L2A_T36NXG_A030906_20230205T080451/IMG_DATA/R10m/T36NXG_20230205T075019_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE/GRANULE/L2A_T36NXG_A030906_20230205T080451/IMG_DATA/R10m/T36NXG_20230205T075019_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230205T075019_N0509_R135_T36NXG_20230205T101407.SAFE/GRANULE/L2A_T36NXG_A030906_20230205T080451/IMG_DATA/R10m/T36NXG_20230205T075019_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE/GRANULE/L2A_T36NXG_A039743_20230131T080449/IMG_DATA/R10m/T36NXG_20230131T075141_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE/GRANULE/L2A_T36NXG_A039743_20230131T080449/IMG_DATA/R10m/T36NXG_20230131T075141_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE/GRANULE/L2A_T36NXG_A039743_20230131T080449/IMG_DATA/R10m/T36NXG_20230131T075141_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230131T075141_N0509_R135_T36NXG_20230131T131152.SAFE/GRANULE/L2A_T36NXG_A039743_20230131T080449/IMG_DATA/R10m/T36NXG_20230131T075141_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE/GRANULE/L2A_T36NXG_A039314_20230101T080556/IMG_DATA/R10m/T36NXG_20230101T075331_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE/GRANULE/L2A_T36NXG_A039314_20230101T080556/IMG_DATA/R10m/T36NXG_20230101T075331_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE/GRANULE/L2A_T36NXG_A039314_20230101T080556/IMG_DATA/R10m/T36NXG_20230101T075331_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230101T075331_N0509_R135_T36NXG_20230101T110554.SAFE/GRANULE/L2A_T36NXG_A039314_20230101T080556/IMG_DATA/R10m/T36NXG_20230101T075331_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE/S2B_MSIL2A_20230116T075149_N9999_R135_T36NXG_20230709T222010.SAFE/GRANULE/L2A_T36NXG_A030620_20230116T080450/IMG_DATA/R10m/T36NXG_20230116T075149_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE/S2B_MSIL2A_20230116T075149_N9999_R135_T36NXG_20230709T222010.SAFE/GRANULE/L2A_T36NXG_A030620_20230116T080450/IMG_DATA/R10m/T36NXG_20230116T075149_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE/S2B_MSIL2A_20230116T075149_N9999_R135_T36NXG_20230709T222010.SAFE/GRANULE/L2A_T36NXG_A030620_20230116T080450/IMG_DATA/R10m/T36NXG_20230116T075149_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2B_MSIL2A_20230116T075149_N0509_R135_T36NXG_20230116T093503.SAFE/S2B_MSIL2A_20230116T075149_N9999_R135_T36NXG_20230709T222010.SAFE/GRANULE/L2A_T36NXG_A030620_20230116T080450/IMG_DATA/R10m/T36NXG_20230116T075149_B08_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE/S2A_MSIL2A_20230111T075301_N9999_R135_T36NXG_20230709T215105.SAFE/GRANULE/L2A_T36NXG_A039457_20230111T080534/IMG_DATA/R10m/T36NXG_20230111T075301_B02_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE/S2A_MSIL2A_20230111T075301_N9999_R135_T36NXG_20230709T215105.SAFE/GRANULE/L2A_T36NXG_A039457_20230111T080534/IMG_DATA/R10m/T36NXG_20230111T075301_B03_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE/S2A_MSIL2A_20230111T075301_N9999_R135_T36NXG_20230709T215105.SAFE/GRANULE/L2A_T36NXG_A039457_20230111T080534/IMG_DATA/R10m/T36NXG_20230111T075301_B04_10m.jp2
# Image Resolution: /home/sepal-user/pyeo_dir/36NXG/images/L2A/S2A_MSIL2A_20230111T075301_N0509_R135_T36NXG_20230111T093441.SAFE/S2A_MSIL2A_20230111T075301_N9999_R135_T36NXG_20230709T215105.SAFE/GRANULE/L2A_T36NXG_A039457_20230111T080534/IMG_DATA/R10m/T36NXG_20230111T075301_B08_10m.jp2
# 2023-07-09 23:15:02,137: INFO: ---------------------------------------------------------------
# 2023-07-09 23:15:02,139: INFO: Cloud masking and band stacking of new L2A images are complete.
# 2023-07-09 23:15:02,140: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### Offsetting

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Offsetting cloud masked L2A images.")
    tile_log.info("---------------------------------------------------------------")

    raster_manipulation.apply_processing_baseline_offset_correction_to_tiff_file_directory(
        l2_masked_image_dir, l2_masked_image_dir)

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Offsetting of cloud masked L2A images complete.")
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 23:15:02,155: INFO: ---------------------------------------------------------------
# 2023-07-09 23:15:02,157: INFO: Offsetting cloud masked L2A images.
# 2023-07-09 23:15:02,158: INFO: ---------------------------------------------------------------
# apply_processing_baseline_offset_correction_to_tiff_file_directory() running on: /home/sepal-user/pyeo_dir/36NXG/images/cloud_masked
# 2023-07-09 23:18:50,779: INFO: ---------------------------------------------------------------
# 2023-07-09 23:18:50,781: INFO: Offsetting of cloud masked L2A images complete.
# 2023-07-09 23:18:50,782: INFO: ---------------------------------------------------------------
# Offsetting Finished

# %% [markdown]
# ### Quicklooks

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if config_dict["do_quicklooks"] or config_dict["do_all"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Producing quicklooks.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
        dirs_for_quicklooks = [l2_masked_image_dir]
        for main_dir in dirs_for_quicklooks:
            files = [
                f.path
                for f in os.scandir(main_dir)
                if f.is_file() and os.path.basename(f).endswith(".tif")
            ]
            if len(files) == 0:
                tile_log.warning("No images found in {}.".format(main_dir))
            else:
                for f in files:
                    quicklook_path = os.path.join(
                        quicklook_dir,
                        os.path.basename(f).split(".")[0] + ".png",
                    )
                    tile_log.info("Creating quicklook: {}".format(quicklook_path))
                    raster_manipulation.create_quicklook(
                        f,
                        quicklook_path,
                        width=512,
                        height=512,
                        format="PNG",
                        bands=[3, 2, 1],
                        scale_factors=[[0, 2000, 0, 255]],
                    )
        tile_log.info("Quicklooks complete.")
    else:
        tile_log.info("Quicklooks disabled in ini file.")
# Out:
# 2023-07-09 23:18:50,794: INFO: ---------------------------------------------------------------
# 2023-07-09 23:18:50,795: INFO: Producing quicklooks.
# 2023-07-09 23:18:50,795: INFO: ---------------------------------------------------------------
# 2023-07-09 23:18:50,805: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230116T075149_NA509_R135_T36NXG_20230116T093503.png
# 2023-07-09 23:19:04,119: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230101T075331_NA509_R135_T36NXG_20230101T110554.png
# 2023-07-09 23:19:17,450: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230111T075301_NA509_R135_T36NXG_20230111T093441.png
# 2023-07-09 23:19:30,755: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230131T075141_NA509_R135_T36NXG_20230131T131152.png
# 2023-07-09 23:19:44,591: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230121T075231_NA509_R135_T36NXG_20230121T110651.png
# 2023-07-09 23:19:57,948: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230126T075109_NA509_R135_T36NXG_20230126T101405.png
# 2023-07-09 23:20:11,312: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230205T075019_NA509_R135_T36NXG_20230205T101407.png
# 2023-07-09 23:20:24,693: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230106T075219_NA509_R135_T36NXG_20230106T101809.png
# 2023-07-09 23:20:38,167: INFO: Quicklooks complete.

# %% [markdown]
# ### Housekeeping

# %%
if config_dict["do_all"] or config_dict["do_download"]:
    if config_dict["do_zip"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Zipping L2A images downloaded for change detection")
        tile_log.info(
            "---------------------------------------------------------------"
        )
        filesystem_utilities.zip_contents(l2_image_dir)
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Zipping complete")
        tile_log.info(
            "---------------------------------------------------------------"
        )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Compressing tiff files in directory {} and all subdirectories".format(
            l2_masked_image_dir
        )
    )
    tile_log.info("---------------------------------------------------------------")
    for root, dirs, files in os.walk(l2_masked_image_dir):
        all_tiffs = [
            image_name for image_name in files if image_name.endswith(".tif")
        ]
        for this_tiff in all_tiffs:
            raster_manipulation.compress_tiff(
                os.path.join(root, this_tiff), os.path.join(root, this_tiff)
            )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Pre-processing of change detection images, file compression, zipping"
    )
    tile_log.info(
        "and deletion of intermediate file products (if selected) are complete."
    )
    tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 23:20:38,177: INFO: ---------------------------------------------------------------
# 2023-07-09 23:20:38,179: INFO: Compressing tiff files in directory /home/sepal-user/pyeo_dir/36NXG/images/cloud_masked and all subdirectories
# 2023-07-09 23:20:38,179: INFO: ---------------------------------------------------------------
# 2023-07-09 23:24:51,135: INFO: ---------------------------------------------------------------
# 2023-07-09 23:24:51,137: INFO: Pre-processing of change detection images, file compression, zipping
# 2023-07-09 23:24:51,138: INFO: and deletion of intermediate file products (if selected) are complete.
# 2023-07-09 23:24:51,138: INFO: ---------------------------------------------------------------

# %% [markdown]
# ## <a id='toc4_7_'></a>[Classification of the Baseline Composite and Change Images](#toc0_)

# %% [markdown]
# Here, we classify the Baseline Composite and the Change images using the model we created in the model training session.

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    if config_dict["do_all"] or config_dict["do_classify"]:
        tile_log.info("---------------------------------------------------------------")
        tile_log.info(
            "Classify a land cover map for each L2A image and composite image using a saved model"
        )
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Model used: {}".format(model_path))
        if skip_existing:
            tile_log.info("Skipping existing classification images if found.")
        classification.classify_directory(
            composite_dir,
            model_path,
            categorised_image_dir,
            prob_out_dir=None,
            apply_mask=False,
            out_type="GTiff",
            chunks=config_dict["chunks"],
            skip_existing=skip_existing,
        )
        classification.classify_directory(
            l2_masked_image_dir,
            model_path,
            categorised_image_dir,
            prob_out_dir=None,
            apply_mask=False,
            out_type="GTiff",
            chunks=config_dict["chunks"],
            skip_existing=skip_existing,
        )

        tile_log.info("---------------------------------------------------------------")
        tile_log.info(
            "Compressing tiff files in directory {} and all subdirectories".format(
                categorised_image_dir
            )
        )
        tile_log.info("---------------------------------------------------------------")
        for root, dirs, files in os.walk(categorised_image_dir):
            all_tiffs = [
                image_name for image_name in files if image_name.endswith(".tif")
            ]
            for this_tiff in all_tiffs:
                raster_manipulation.compress_tiff(
                    os.path.join(root, this_tiff), os.path.join(root, this_tiff)
                )

        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Classification of all images is complete.")
        tile_log.info("---------------------------------------------------------------")
# Out:
# 2023-07-09 23:24:51,151: INFO: ---------------------------------------------------------------
# 2023-07-09 23:24:51,152: INFO: Classify a land cover map for each L2A image and composite image using a saved model
# 2023-07-09 23:24:51,153: INFO: ---------------------------------------------------------------
# 2023-07-09 23:24:51,154: INFO: Model used: ./models/model_36MYE_Unoptimised_20230505_no_haze.pkl
# 2023-07-09 23:24:51,155: INFO: Skipping existing classification images if found.
# 2023-07-09 23:58:34,530: INFO: ---------------------------------------------------------------
# 2023-07-09 23:58:34,549: INFO: Compressing tiff files in directory /home/sepal-user/pyeo_dir/36NXG/output/classified and all subdirectories
# 2023-07-09 23:58:34,553: INFO: ---------------------------------------------------------------
# 2023-07-09 23:58:50,587: INFO: ---------------------------------------------------------------
# 2023-07-09 23:58:50,588: INFO: Classification of all images is complete.
# 2023-07-09 23:58:50,589: INFO: ---------------------------------------------------------------

# %% [markdown]
# ### Housekeeping

# %%
if config_dict["do_all"] or config_dict["do_classify"]:
    if config_dict["do_quicklooks"] or config_dict["do_all"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Producing quicklooks.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
        dirs_for_quicklooks = [categorised_image_dir]
        for main_dir in dirs_for_quicklooks:
            # files = [ f.path for f in os.scandir(main_dir) if f.is_file() and os.path.basename(f).endswith(".tif") ]
            files = [
                f.path
                for f in os.scandir(main_dir)
                if f.is_file()
                and os.path.basename(f).endswith(".tif")
                and "class" in os.path.basename(f)
            ]  # do classification images only
            if len(files) == 0:
                tile_log.warning("No images found in {}.".format(main_dir))
            else:
                for f in files:
                    quicklook_path = os.path.join(
                        quicklook_dir,
                        os.path.basename(f).split(".")[0] + ".png",
                    )
                    tile_log.info("Creating quicklook: {}".format(quicklook_path))
                    raster_manipulation.create_quicklook(
                        f, quicklook_path, width=512, height=512, format="PNG"
                    )
        tile_log.info("Quicklooks complete.")
    else:
        tile_log.info("Quicklooks disabled in ini file.")
# Out:
# 2023-07-09 23:58:50,609: INFO: ---------------------------------------------------------------
# 2023-07-09 23:58:50,610: INFO: Producing quicklooks.
# 2023-07-09 23:58:50,611: INFO: ---------------------------------------------------------------
# 2023-07-09 23:58:50,619: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230106T075219_NA509_R135_T36NXG_20230106T101809_class.png
# 2023-07-09 23:58:52,953: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230205T075019_NA509_R135_T36NXG_20230205T101407_class.png
# 2023-07-09 23:58:55,157: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/composite_T36NXG_20220918T074619_class.png
# 2023-07-09 23:58:57,729: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/composite_T36NXG_20220511T074609_class.png
# 2023-07-09 23:58:59,920: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230126T075109_NA509_R135_T36NXG_20230126T101405_class.png
# 2023-07-09 23:59:02,076: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230121T075231_NA509_R135_T36NXG_20230121T110651_class.png
# 2023-07-09 23:59:04,065: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230111T075301_NA509_R135_T36NXG_20230111T093441_class.png
# 2023-07-09 23:59:05,894: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2B_MSIL2A_20230116T075149_NA509_R135_T36NXG_20230116T093503_class.png
# 2023-07-09 23:59:07,811: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230101T075331_NA509_R135_T36NXG_20230101T110554_class.png
# 2023-07-09 23:59:09,762: INFO: Creating quicklook: /home/sepal-user/pyeo_dir/36NXG/output/quicklooks/S2A_MSIL2A_20230131T075141_NA509_R135_T36NXG_20230131T131152_class.png
# 2023-07-09 23:59:11,835: INFO: Quicklooks complete.

# %% [markdown]
# ## <a id='toc4_8_'></a>[Change Detection](#toc0_)

# %% [markdown]
# To perform Change Detection, we take the Classified Change Imagery and compare it with the Classified Baseline Composite.
#
# Because we are concerned with monitoring deforestation for our Change Detection, `pyeo_1` examines whether any forest classes (*classes 1, 11 and 12*) change to non-forest classes (*classes 3, 4, 5 and 13*).
#
# As new change imagery becomes available (*as deforestation monitoring is an iterative process through time*), these change images are classified and compared to the baseline, again.

# %% [markdown]
# ---

# %% [markdown]
# The overall Change Detection can be summarised as this:
# - PyEO first looks for the composite and change imagery classifications and orders them by most recent.
# - Then, it searches for existing report files created from previous PyEO runs and archive them, moving them to an archived folder.
# - Then it creates the change report by sequentially comparing the classified change imagery against the classified baseline composite.
# - Once finished, PyEO does some housekeeping, compressing unneeded files.

# %%
from pyeo_1 import vectorisation
if config_dict["do_all"] or config_dict["do_change"]:
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Creating change layers from stacked class images.")
    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Changes of interest:")
    tile_log.info(
        "  from any of the classes {}".format(config_dict["from_classes"])
    )
    tile_log.info("  to   any of the classes {}".format(config_dict["to_classes"]))

    # optionally sieve the class images
    if sieve > 0:
        tile_log.info("Applying sieve to classification outputs.")
        sieved_paths = raster_manipulation.sieve_directory(
            in_dir=categorised_image_dir,
            out_dir=sieved_image_dir,
            neighbours=8,
            sieve=sieve,
            out_type="GTiff",
            skip_existing=skip_existing,
        )
        # if sieve was chosen, work with the sieved class images
        class_image_dir = sieved_image_dir
    else:
        # if sieve was not chosen, work with the original class images
        class_image_dir = categorised_image_dir

    # get all image paths in the classification maps directory except the class composites
    class_image_paths = [
        f.path
        for f in os.scandir(class_image_dir)
        if f.is_file() and f.name.endswith(".tif") and not "composite_" in f.name
    ]
    if len(class_image_paths) == 0:
        raise FileNotFoundError(
            "No class images found in {}.".format(class_image_dir)
        )

    # sort class images by image acquisition date
    class_image_paths = list(
        filter(filesystem_utilities.get_image_acquisition_time, class_image_paths)
    )
    class_image_paths.sort(
        key=lambda x: filesystem_utilities.get_image_acquisition_time(x)
    )
    for index, image in enumerate(class_image_paths):
        tile_log.info("{}: {}".format(index, image))

    # find the latest available composite
    try:
        latest_composite_name = filesystem_utilities.sort_by_timestamp(
            [
                image_name
                for image_name in os.listdir(composite_dir)
                if image_name.endswith(".tif")
            ],
            recent_first=True,
        )[0]
        latest_composite_path = os.path.join(composite_dir, latest_composite_name)
        tile_log.info("Most recent composite at {}".format(latest_composite_path))
    except IndexError:
        tile_log.critical(
            "Latest composite not found. The first time you run this script, you need to include the "
            "--build-composite flag to create a base composite to work off. If you have already done this,"
            "check that the earliest dated image in your images/merged folder is later than the earliest"
            " dated image in your composite/ folder."
        )
        sys.exit(1)

    latest_class_composite_path = os.path.join(
        class_image_dir,
        [
            f.path
            for f in os.scandir(class_image_dir)
            if f.is_file()
            and os.path.basename(latest_composite_path)[:-4] in f.name
            and f.name.endswith(".tif")
        ][0],
    )

    tile_log.info(
        "Most recent class composite at {}".format(latest_class_composite_path)
    )
    if not os.path.exists(latest_class_composite_path):
        tile_log.critical(
            "Latest class composite not found. The first time you run this script, you need to include the "
            "--build-composite flag to create a base composite to work off. If you have already done this,"
            "check that the earliest dated image in your images/merged folder is later than the earliest"
            " dated image in your composite/ folder. Then, you need to run the --classify option."
        )
        sys.exit(1)

    if config_dict[
        "do_dev"
    ]:  # set the name of the report file in the development version run
        before_timestamp = filesystem_utilities.get_change_detection_dates(
            os.path.basename(latest_class_composite_path)
        )[0]
        # I.R. 20220611 START
        ## Timestamp report with the date of most recent classified image that contributes to it
        after_timestamp = filesystem_utilities.get_image_acquisition_time(
            os.path.basename(class_image_paths[-1])
        )
        ## ORIGINAL
        # gets timestamp of the earliest change image of those available in class_image_path
        # after_timestamp  = pyeo_1.filesystem_utilities.get_image_acquisition_time(os.path.basename(class_image_paths[0]))
        # I.R. 20220611 END
        output_product = os.path.join(
            probability_image_dir,
            "report_{}_{}_{}.tif".format(
                before_timestamp.strftime("%Y%m%dT%H%M%S"),
                tile_to_process,
                after_timestamp.strftime("%Y%m%dT%H%M%S"),
            ),
        )
        tile_log.info("I.R. Report file name will be {}".format(output_product))

        # if a report file exists, archive it  ( I.R. Changed from 'rename it to show it has been updated')
        n_report_files = len(
            [
                f
                for f in os.scandir(probability_image_dir)
                if f.is_file()
                and f.name.startswith("report_")
                and f.name.endswith(".tif")
            ]
        )

        if n_report_files > 0:
            # I.R. ToDo: Should iterate over output_product_existing in case more than one report file is present (though unlikely)
            output_product_existing = [
                f.path
                for f in os.scandir(probability_image_dir)
                if f.is_file()
                and f.name.startswith("report_")
                and f.name.endswith(".tif")
            ][0]
            tile_log.info(
                "Found existing report image product: {}".format(
                    output_product_existing
                )
            )

            output_product_existing_archived = os.path.join(
                os.path.dirname(output_product_existing),
                "archived_" + os.path.basename(output_product_existing),
            )
            tile_log.info(
                "Renaming existing report image product to: {}".format(
                    output_product_existing_archived
                )
            )
            os.rename(output_product_existing, output_product_existing_archived)

    # find change patterns in the stack of classification images
    for index, image in enumerate(class_image_paths):
        tile_log.info("")
        tile_log.info("")
        tile_log.info(f"  printing index, image   : {index}, {image}")
        tile_log.info("")
        tile_log.info("")
        before_timestamp = filesystem_utilities.get_change_detection_dates(
            os.path.basename(latest_class_composite_path)
        )[0]
        after_timestamp = filesystem_utilities.get_image_acquisition_time(
            os.path.basename(image)
        )
        tile_log.info(
            "*** PROCESSING CLASSIFIED IMAGE: {} of {} filename: {} ***".format(
                index, len(class_image_paths), image
            )
        )
        tile_log.info("  early time stamp: {}".format(before_timestamp))
        tile_log.info("  late  time stamp: {}".format(after_timestamp))
        change_raster = os.path.join(
            probability_image_dir,
            "change_{}_{}_{}.tif".format(
                before_timestamp.strftime("%Y%m%dT%H%M%S"),
                tile_to_process,
                after_timestamp.strftime("%Y%m%dT%H%M%S"),
            ),
        )
        tile_log.info(
            "  Change raster file to be created: {}".format(change_raster)
        )

        dNDVI_raster = os.path.join(
            probability_image_dir,
            "dNDVI_{}_{}_{}.tif".format(
                before_timestamp.strftime("%Y%m%dT%H%M%S"),
                tile_to_process,
                after_timestamp.strftime("%Y%m%dT%H%M%S"),
            ),
        )
        tile_log.info(
            "  I.R. dNDVI raster file to be created: {}".format(dNDVI_raster)
        )

        NDVI_raster = os.path.join(
            probability_image_dir,
            "NDVI_{}_{}_{}.tif".format(
                before_timestamp.strftime("%Y%m%dT%H%M%S"),
                tile_to_process,
                after_timestamp.strftime("%Y%m%dT%H%M%S"),
            ),
        )
        tile_log.info(
            "  I.R. NDVI raster file of change image to be created: {}".format(
                NDVI_raster
            )
        )

        if config_dict["do_dev"]:
            # This function looks for changes from class 'change_from' in the composite to any of the 'change_to_classes'
            # in the change images. Pixel values are the acquisition date of the detected change of interest or zero.
            # TODO: In change_from_class_maps(), add a flag (e.g. -1) whether a pixel was a cloud in the later image.
            # Applying check whether dNDVI < -0.2, i.e. greenness has decreased over changed areas

            tile_log.info("Update of the report image product based on change detection image.")
            raster_manipulation.__change_from_class_maps(
                old_class_path=latest_class_composite_path,
                new_class_path=image,
                change_raster=change_raster,
                dNDVI_raster=dNDVI_raster,
                NDVI_raster=NDVI_raster,
                change_from=from_classes,
                change_to=to_classes,
                report_path=output_product,
                skip_existing=skip_existing,
                old_image_dir=composite_dir,
                new_image_dir=l2_masked_image_dir,
                viband1=4,
                viband2=3,
                dNDVI_threshold=-0.2,
                log=tile_log,
            )
        else:
            raster_manipulation.change_from_class_maps(
                latest_class_composite_path,
                image,
                change_raster,
                change_from=from_classes,
                change_to=to_classes,
                skip_existing=skip_existing,
            )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Post-classification change detection complete.")
    tile_log.info("---------------------------------------------------------------")

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Compressing tiff files in directory {} and all subdirectories".format(
            probability_image_dir
        )
    )
    tile_log.info("---------------------------------------------------------------")
    for root, dirs, files in os.walk(probability_image_dir):
        all_tiffs = [
            image_name for image_name in files if image_name.endswith(".tif")
        ]
        for this_tiff in all_tiffs:
            raster_manipulation.compress_tiff(
                os.path.join(root, this_tiff), os.path.join(root, this_tiff)
            )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Compressing tiff files in directory {} and all subdirectories".format(
            sieved_image_dir
        )
    )
    tile_log.info("---------------------------------------------------------------")
    for root, dirs, files in os.walk(sieved_image_dir):
        all_tiffs = [
            image_name for image_name in files if image_name.endswith(".tif")
        ]
        for this_tiff in all_tiffs:
            raster_manipulation.compress_tiff(
                os.path.join(root, this_tiff), os.path.join(root, this_tiff)
            )

    if not config_dict["do_dev"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info(
            "Creating aggregated report file. Deprecated in the development version."
        )
        tile_log.info(
            "---------------------------------------------------------------"
        )
        # combine all change layers into one output raster with two layers:
        #   (1) pixels show the earliest change detection date (expressed as the number of days since 1/1/2000)
        #   (2) pixels show the number of change detection dates (summed up over all change images in the folder)
        date_image_paths = [
            f.path
            for f in os.scandir(probability_image_dir)
            if f.is_file() and f.name.endswith(".tif") and "change_" in f.name
        ]
        if len(date_image_paths) == 0:
            raise FileNotFoundError(
                "No class images found in {}.".format(categorised_image_dir)
            )

        before_timestamp = filesystem_utilities.get_change_detection_dates(
            os.path.basename(latest_class_composite_path)
        )[0]
        after_timestamp = filesystem_utilities.get_image_acquisition_time(
            os.path.basename(class_image_paths[-1])
        )
        output_product = os.path.join(
            probability_image_dir,
            "report_{}_{}_{}.tif".format(
                before_timestamp.strftime("%Y%m%dT%H%M%S"),
                tile_to_process,
                # tile_id,
                after_timestamp.strftime("%Y%m%dT%H%M%S"),
            ),
        )
        tile_log.info("Combining date maps: {}".format(date_image_paths))
        raster_manipulation.combine_date_maps(date_image_paths, output_product)

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Report image product completed / updated: {}".format(output_product)
    )
        
if config_dict["do_all"] or config_dict["do_vectorise"]:
    from pyeo_1.apps.acd_national.acd_by_tile_vectorisation import vector_report_generation
    output_vector_products = vector_report_generation(config_path, tile_to_process)

    tile_log.info("---------------------------------------------------------------")
    tile_log.info("Report image vectorised. Output file(s) created:")
    for i in range(len(output_vector_products)):
        tile_log.info("  {}".format(output_vector_products[i]))
# Out:
# 2023-07-10 08:25:37,820: INFO: ---------------------------------------------------------------
# 2023-07-10 08:25:37,825: INFO: Creating change layers from stacked class images.
# 2023-07-10 08:25:37,825: INFO: ---------------------------------------------------------------
# 2023-07-10 08:25:37,827: INFO: Changes of interest:
# 2023-07-10 08:25:37,829: INFO:   from any of the classes [1, 2]
# 2023-07-10 08:25:37,829: INFO:   to   any of the classes [3]
# 2023-07-10 08:25:37,834: INFO: 0: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230101T075331_NA509_R135_T36NXG_20230101T110554_class.tif
# 2023-07-10 08:25:37,834: INFO: 1: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230106T075219_NA509_R135_T36NXG_20230106T101809_class.tif
# 2023-07-10 08:25:37,835: INFO: 2: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230111T075301_NA509_R135_T36NXG_20230111T093441_class.tif
# 2023-07-10 08:25:37,836: INFO: 3: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230116T075149_NA509_R135_T36NXG_20230116T093503_class.tif
# 2023-07-10 08:25:37,837: INFO: 4: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230121T075231_NA509_R135_T36NXG_20230121T110651_class.tif
# 2023-07-10 08:25:37,838: INFO: 5: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230126T075109_NA509_R135_T36NXG_20230126T101405_class.tif
# 2023-07-10 08:25:37,839: INFO: 6: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230131T075141_NA509_R135_T36NXG_20230131T131152_class.tif
# 2023-07-10 08:25:37,842: INFO: 7: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230205T075019_NA509_R135_T36NXG_20230205T101407_class.tif
# 2023-07-10 08:25:37,844: INFO: Most recent composite at /home/sepal-user/pyeo_dir/36NXG/composite/composite_T36NXG_20220918T074619.tif
# 2023-07-10 08:25:37,846: INFO: Most recent class composite at /home/sepal-user/pyeo_dir/36NXG/output/classified/composite_T36NXG_20220918T074619_class.tif
# 2023-07-10 08:25:37,849: INFO: I.R. Report file name will be /home/sepal-user/pyeo_dir/36NXG/output/probabilities/report_20220918T074619_36NXG_20230205T075019.tif
# 2023-07-10 08:25:37,853: INFO: Found existing report image product: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/report_20220918T074619_36NXG_20230205T075019.tif
# 2023-07-10 08:25:37,854: INFO: Renaming existing report image product to: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/archived_report_20220918T074619_36NXG_20230205T075019.tif
# 2023-07-10 08:25:37,889: INFO:
# 2023-07-10 08:25:37,890: INFO:
# 2023-07-10 08:25:37,891: INFO:   printing index, image   : 0, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230101T075331_NA509_R135_T36NXG_20230101T110554_class.tif
# 2023-07-10 08:25:37,891: INFO:
# 2023-07-10 08:25:37,892: INFO:
# 2023-07-10 08:25:37,893: INFO: *** PROCESSING CLASSIFIED IMAGE: 0 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230101T075331_NA509_R135_T36NXG_20230101T110554_class.tif ***
# 2023-07-10 08:25:37,893: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 08:25:37,894: INFO:   late  time stamp: 2023-01-01 07:53:31
# 2023-07-10 08:25:37,897: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230101T075331.tif
# 2023-07-10 08:25:37,897: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230101T075331.tif
# 2023-07-10 08:25:37,898: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230101T075331.tif
# 2023-07-10 08:25:37,899: INFO: Update of the report image product based on change detection image.
# 2023-07-10 08:25:37,900: INFO: Report file being created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/report_20220918T074619_36NXG_20230205T075019.tif
# 2023-07-10 08:25:38,000: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230101T075331.tif. Skipping change raster creation.
# 2023-07-10 08:25:38,001: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 08:25:38,039: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 08:25:38,041: INFO: percentage_probability_threshold:   50
# 2023-07-10 08:25:38,041: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 08:25:38,042: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 08:25:38,043: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 08:25:38,044: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 08:25:38,044: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 08:25:38,045: INFO: Build Report Layers
# 2023-07-10 08:25:38,046: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 08:25:58,487: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 08:26:56,155: INFO: Layer 3: First-Change Trigger for Combined Classifier+dNDVI Validated Change Detection: Records earliest date of a classification change detection where values are greater than zero (not missing data and not cloud)
# 2023-07-10 08:27:44,700: INFO: Layer 4: Combined Classifier+dNDVI Validated Change Detection Count: Count if a change was detected after a first change has already been detected
# 2023-07-10 08:28:03,834: INFO: Layer 5: Combined Classifier+dNDVI Validated No Change Detection Count: Count if a no change was detected after a first change has already been detected
# 2023-07-10 08:28:10,016: INFO: Layer 6: Cloud Occlusion Count: Count if a cloud occlusion (or out-of-orbit) occured after a first change has already been detected
# 2023-07-10 08:28:18,441: INFO: Layer 7: Valid Image Count: Total number of valid (no cloud) images for this pixel since first change was detected
# 2023-07-10 08:28:36,900: INFO: Layer 8: Change Detection Repeatability: Repeatability of change detection after first change is detected - as a percentage of available valid images
# 2023-07-10 08:28:44,209: INFO: Layer 9: Binary time-series decision: Based on percentage_probability_threshold and minimum_required_validated_detections_threshold
# 2023-07-10 08:29:15,599: INFO: Layer 10: Binary time-series decision by first-change date: First change date masked by Binary Decision - Layer 9
# 2023-07-10 08:29:23,055: INFO: Layer 11: dNDVI Only Change Detection Count: Count if a change was detected by the dNDVI test and that not cloud occluded (or out-of-orbit)
# 2023-07-10 08:29:48,032: INFO: Layer 12: Binary time-series decision: Based on dNDVI Only and minimum_required_dNDVI_detections_threshold
# 2023-07-10 08:30:35,919: INFO: Layer 13: Binary time-series decision: Based on Classifier Only
# 2023-07-10 08:30:50,243: INFO: Layer 14: Combined Classifier+dNDVI Binary time-series decision: Based on Classifier AND dNDVI opinion
# 2023-07-10 08:31:31,718: INFO: Layer 15: FROM Classification Count
# 2023-07-10 08:31:42,858: INFO: Layer 16: TO Classification Count
# 2023-07-10 08:32:11,805: INFO: Layer 17: Binary Decision Thresholds on FROM and TO Classification Counts
# 2023-07-10 08:33:07,438: INFO:
# 2023-07-10 08:33:07,440: INFO:
# 2023-07-10 08:33:07,441: INFO:   printing index, image   : 1, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230106T075219_NA509_R135_T36NXG_20230106T101809_class.tif
# 2023-07-10 08:33:07,442: INFO:
# 2023-07-10 08:33:07,442: INFO:
# 2023-07-10 08:33:07,443: INFO: *** PROCESSING CLASSIFIED IMAGE: 1 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230106T075219_NA509_R135_T36NXG_20230106T101809_class.tif ***
# 2023-07-10 08:33:07,444: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 08:33:07,444: INFO:   late  time stamp: 2023-01-06 07:52:19
# 2023-07-10 08:33:07,445: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230106T075219.tif
# 2023-07-10 08:33:07,446: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230106T075219.tif
# 2023-07-10 08:33:07,446: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230106T075219.tif
# 2023-07-10 08:33:07,447: INFO: Update of the report image product based on change detection image.
# 2023-07-10 08:33:07,456: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230106T075219.tif. Skipping change raster creation.
# 2023-07-10 08:33:07,457: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 08:33:07,495: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 08:33:07,496: INFO: percentage_probability_threshold:   50
# 2023-07-10 08:33:07,497: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 08:33:07,497: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 08:33:07,499: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 08:33:07,500: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 08:33:07,500: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 08:33:07,501: INFO: Build Report Layers
# 2023-07-10 08:33:07,502: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 08:33:21,806: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 08:33:52,677: INFO: Layer 2: Classifier Change Detection Count: Count if a from/to change of classification was detected
# 2023-07-10 08:34:24,458: INFO: Layer 3: First-Change Trigger for Combined Classifier+dNDVI Validated Change Detection: Records earliest date of a classification change detection where values are greater than zero (not missing data and not cloud)
# 2023-07-10 08:35:08,353: INFO: Layer 4: Combined Classifier+dNDVI Validated Change Detection Count: Count if a change was detected after a first change has already been detected
# 2023-07-10 08:35:35,080: INFO: Layer 5: Combined Classifier+dNDVI Validated No Change Detection Count: Count if a no change was detected after a first change has already been detected
# 2023-07-10 08:35:42,665: INFO: Layer 6: Cloud Occlusion Count: Count if a cloud occlusion (or out-of-orbit) occured after a first change has already been detected
# 2023-07-10 08:36:05,728: INFO: Layer 7: Valid Image Count: Total number of valid (no cloud) images for this pixel since first change was detected
# 2023-07-10 08:36:12,904: INFO: Layer 8: Change Detection Repeatability: Repeatability of change detection after first change is detected - as a percentage of available valid images
# 2023-07-10 08:36:27,659: INFO: Layer 9: Binary time-series decision: Based on percentage_probability_threshold and minimum_required_validated_detections_threshold
# 2023-07-10 08:37:12,702: INFO: Layer 10: Binary time-series decision by first-change date: First change date masked by Binary Decision - Layer 9
# 2023-07-10 08:37:20,163: INFO: Layer 11: dNDVI Only Change Detection Count: Count if a change was detected by the dNDVI test and that not cloud occluded (or out-of-orbit)
# 2023-07-10 08:37:45,191: INFO: Layer 12: Binary time-series decision: Based on dNDVI Only and minimum_required_dNDVI_detections_threshold
# 2023-07-10 08:38:31,234: INFO: Layer 13: Binary time-series decision: Based on Classifier Only
# 2023-07-10 08:38:49,772: INFO: Layer 14: Combined Classifier+dNDVI Binary time-series decision: Based on Classifier AND dNDVI opinion
# 2023-07-10 08:39:31,167: INFO: Layer 15: FROM Classification Count
# 2023-07-10 08:39:42,084: INFO: Layer 16: TO Classification Count
# 2023-07-10 08:40:13,201: INFO: Layer 17: Binary Decision Thresholds on FROM and TO Classification Counts
# 2023-07-10 08:41:12,413: INFO:
# 2023-07-10 08:41:12,415: INFO:
# 2023-07-10 08:41:12,416: INFO:   printing index, image   : 2, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230111T075301_NA509_R135_T36NXG_20230111T093441_class.tif
# 2023-07-10 08:41:12,416: INFO:
# 2023-07-10 08:41:12,418: INFO:
# 2023-07-10 08:41:12,419: INFO: *** PROCESSING CLASSIFIED IMAGE: 2 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230111T075301_NA509_R135_T36NXG_20230111T093441_class.tif ***
# 2023-07-10 08:41:12,419: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 08:41:12,420: INFO:   late  time stamp: 2023-01-11 07:53:01
# 2023-07-10 08:41:12,421: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230111T075301.tif
# 2023-07-10 08:41:12,422: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230111T075301.tif
# 2023-07-10 08:41:12,423: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230111T075301.tif
# 2023-07-10 08:41:12,424: INFO: Update of the report image product based on change detection image.
# 2023-07-10 08:41:12,431: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230111T075301.tif. Skipping change raster creation.
# 2023-07-10 08:41:12,432: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 08:41:12,466: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 08:41:12,467: INFO: percentage_probability_threshold:   50
# 2023-07-10 08:41:12,467: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 08:41:12,468: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 08:41:12,469: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 08:41:12,469: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 08:41:12,470: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 08:41:12,471: INFO: Build Report Layers
# 2023-07-10 08:41:12,471: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 08:41:26,602: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 08:42:15,881: INFO: Layer 2: Classifier Change Detection Count: Count if a from/to change of classification was detected
# 2023-07-10 08:42:32,942: INFO: Layer 3: First-Change Trigger for Combined Classifier+dNDVI Validated Change Detection: Records earliest date of a classification change detection where values are greater than zero (not missing data and not cloud)
# 2023-07-10 08:43:02,814: INFO: Layer 4: Combined Classifier+dNDVI Validated Change Detection Count: Count if a change was detected after a first change has already been detected
# 2023-07-10 08:43:21,951: INFO: Layer 5: Combined Classifier+dNDVI Validated No Change Detection Count: Count if a no change was detected after a first change has already been detected
# 2023-07-10 08:43:28,980: INFO: Layer 6: Cloud Occlusion Count: Count if a cloud occlusion (or out-of-orbit) occured after a first change has already been detected
# 2023-07-10 08:43:42,404: INFO: Layer 7: Valid Image Count: Total number of valid (no cloud) images for this pixel since first change was detected
# 2023-07-10 08:44:00,234: INFO: Layer 8: Change Detection Repeatability: Repeatability of change detection after first change is detected - as a percentage of available valid images
# 2023-07-10 08:44:17,931: INFO: Layer 9: Binary time-series decision: Based on percentage_probability_threshold and minimum_required_validated_detections_threshold
# 2023-07-10 08:45:03,535: INFO: Layer 10: Binary time-series decision by first-change date: First change date masked by Binary Decision - Layer 9
# 2023-07-10 08:45:11,030: INFO: Layer 11: dNDVI Only Change Detection Count: Count if a change was detected by the dNDVI test and that not cloud occluded (or out-of-orbit)
# 2023-07-10 08:45:36,848: INFO: Layer 12: Binary time-series decision: Based on dNDVI Only and minimum_required_dNDVI_detections_threshold
# 2023-07-10 08:46:23,243: INFO: Layer 13: Binary time-series decision: Based on Classifier Only
# 2023-07-10 08:46:53,216: INFO: Layer 14: Combined Classifier+dNDVI Binary time-series decision: Based on Classifier AND dNDVI opinion
# 2023-07-10 08:47:36,278: INFO: Layer 15: FROM Classification Count
# 2023-07-10 08:48:03,139: INFO: Layer 16: TO Classification Count
# 2023-07-10 08:48:41,244: INFO: Layer 17: Binary Decision Thresholds on FROM and TO Classification Counts
# 2023-07-10 08:49:19,425: INFO:
# 2023-07-10 08:49:19,427: INFO:
# 2023-07-10 08:49:19,427: INFO:   printing index, image   : 3, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230116T075149_NA509_R135_T36NXG_20230116T093503_class.tif
# 2023-07-10 08:49:19,428: INFO:
# 2023-07-10 08:49:19,429: INFO:
# 2023-07-10 08:49:19,430: INFO: *** PROCESSING CLASSIFIED IMAGE: 3 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230116T075149_NA509_R135_T36NXG_20230116T093503_class.tif ***
# 2023-07-10 08:49:19,431: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 08:49:19,431: INFO:   late  time stamp: 2023-01-16 07:51:49
# 2023-07-10 08:49:19,433: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230116T075149.tif
# 2023-07-10 08:49:19,434: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230116T075149.tif
# 2023-07-10 08:49:19,434: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230116T075149.tif
# 2023-07-10 08:49:19,435: INFO: Update of the report image product based on change detection image.
# 2023-07-10 08:49:19,442: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230116T075149.tif. Skipping change raster creation.
# 2023-07-10 08:49:19,442: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 08:49:19,481: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 08:49:19,482: INFO: percentage_probability_threshold:   50
# 2023-07-10 08:49:19,483: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 08:49:19,484: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 08:49:19,485: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 08:49:19,485: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 08:49:19,486: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 08:49:19,487: INFO: Build Report Layers
# 2023-07-10 08:49:19,488: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 08:49:33,711: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 08:50:06,062: INFO: Layer 2: Classifier Change Detection Count: Count if a from/to change of classification was detected
# 2023-07-10 08:50:31,201: INFO: Layer 3: First-Change Trigger for Combined Classifier+dNDVI Validated Change Detection: Records earliest date of a classification change detection where values are greater than zero (not missing data and not cloud)
# 2023-07-10 08:51:03,200: INFO: Layer 4: Combined Classifier+dNDVI Validated Change Detection Count: Count if a change was detected after a first change has already been detected
# 2023-07-10 08:51:15,662: INFO: Layer 5: Combined Classifier+dNDVI Validated No Change Detection Count: Count if a no change was detected after a first change has already been detected
# 2023-07-10 08:51:22,921: INFO: Layer 6: Cloud Occlusion Count: Count if a cloud occlusion (or out-of-orbit) occured after a first change has already been detected
# 2023-07-10 08:51:44,184: INFO: Layer 7: Valid Image Count: Total number of valid (no cloud) images for this pixel since first change was detected
# 2023-07-10 08:51:52,459: INFO: Layer 8: Change Detection Repeatability: Repeatability of change detection after first change is detected - as a percentage of available valid images
# 2023-07-10 08:52:11,816: INFO: Layer 9: Binary time-series decision: Based on percentage_probability_threshold and minimum_required_validated_detections_threshold
# 2023-07-10 08:52:59,458: INFO: Layer 10: Binary time-series decision by first-change date: First change date masked by Binary Decision - Layer 9
# 2023-07-10 08:53:07,136: INFO: Layer 11: dNDVI Only Change Detection Count: Count if a change was detected by the dNDVI test and that not cloud occluded (or out-of-orbit)
# 2023-07-10 08:53:32,172: INFO: Layer 12: Binary time-series decision: Based on dNDVI Only and minimum_required_dNDVI_detections_threshold
# 2023-07-10 08:54:29,356: INFO: Layer 13: Binary time-series decision: Based on Classifier Only
# 2023-07-10 08:54:59,745: INFO: Layer 14: Combined Classifier+dNDVI Binary time-series decision: Based on Classifier AND dNDVI opinion
# 2023-07-10 08:55:31,574: INFO: Layer 15: FROM Classification Count
# 2023-07-10 08:55:41,751: INFO: Layer 16: TO Classification Count
# 2023-07-10 08:56:09,638: INFO: Layer 17: Binary Decision Thresholds on FROM and TO Classification Counts
# 2023-07-10 08:57:27,341: INFO:
# 2023-07-10 08:57:27,343: INFO:
# 2023-07-10 08:57:27,343: INFO:   printing index, image   : 4, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230121T075231_NA509_R135_T36NXG_20230121T110651_class.tif
# 2023-07-10 08:57:27,344: INFO:
# 2023-07-10 08:57:27,345: INFO:
# 2023-07-10 08:57:27,346: INFO: *** PROCESSING CLASSIFIED IMAGE: 4 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2A_MSIL2A_20230121T075231_NA509_R135_T36NXG_20230121T110651_class.tif ***
# 2023-07-10 08:57:27,347: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 08:57:27,348: INFO:   late  time stamp: 2023-01-21 07:52:31
# 2023-07-10 08:57:27,351: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230121T075231.tif
# 2023-07-10 08:57:27,352: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230121T075231.tif
# 2023-07-10 08:57:27,353: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230121T075231.tif
# 2023-07-10 08:57:27,354: INFO: Update of the report image product based on change detection image.
# 2023-07-10 08:57:27,361: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230121T075231.tif. Skipping change raster creation.
# 2023-07-10 08:57:27,362: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 08:57:27,396: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 08:57:27,397: INFO: percentage_probability_threshold:   50
# 2023-07-10 08:57:27,398: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 08:57:27,399: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 08:57:27,400: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 08:57:27,402: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 08:57:27,403: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 08:57:27,404: INFO: Build Report Layers
# 2023-07-10 08:57:27,406: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 08:57:41,751: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 08:58:21,752: INFO: Layer 2: Classifier Change Detection Count: Count if a from/to change of classification was detected
# 2023-07-10 08:58:35,564: INFO: Layer 3: First-Change Trigger for Combined Classifier+dNDVI Validated Change Detection: Records earliest date of a classification change detection where values are greater than zero (not missing data and not cloud)
# 2023-07-10 08:59:45,370: INFO: Layer 4: Combined Classifier+dNDVI Validated Change Detection Count: Count if a change was detected after a first change has already been detected
# 2023-07-10 09:00:17,057: INFO: Layer 5: Combined Classifier+dNDVI Validated No Change Detection Count: Count if a no change was detected after a first change has already been detected
# 2023-07-10 09:00:27,671: INFO: Layer 6: Cloud Occlusion Count: Count if a cloud occlusion (or out-of-orbit) occured after a first change has already been detected
# 2023-07-10 09:00:48,030: INFO: Layer 7: Valid Image Count: Total number of valid (no cloud) images for this pixel since first change was detected
# 2023-07-10 09:00:57,719: INFO: Layer 8: Change Detection Repeatability: Repeatability of change detection after first change is detected - as a percentage of available valid images
# 2023-07-10 09:01:22,973: INFO: Layer 9: Binary time-series decision: Based on percentage_probability_threshold and minimum_required_validated_detections_threshold
# 2023-07-10 09:01:58,026: INFO: Layer 10: Binary time-series decision by first-change date: First change date masked by Binary Decision - Layer 9
# 2023-07-10 09:02:16,494: INFO: Layer 11: dNDVI Only Change Detection Count: Count if a change was detected by the dNDVI test and that not cloud occluded (or out-of-orbit)
# 2023-07-10 09:02:41,286: INFO: Layer 12: Binary time-series decision: Based on dNDVI Only and minimum_required_dNDVI_detections_threshold
# 2023-07-10 09:03:37,377: INFO: Layer 13: Binary time-series decision: Based on Classifier Only
# 2023-07-10 09:04:31,645: INFO: Layer 14: Combined Classifier+dNDVI Binary time-series decision: Based on Classifier AND dNDVI opinion
# 2023-07-10 09:05:10,606: INFO: Layer 15: FROM Classification Count
# 2023-07-10 09:05:21,710: INFO: Layer 16: TO Classification Count
# 2023-07-10 09:06:06,846: INFO: Layer 17: Binary Decision Thresholds on FROM and TO Classification Counts
# 2023-07-10 09:07:19,278: INFO:
# 2023-07-10 09:07:19,280: INFO:
# 2023-07-10 09:07:19,280: INFO:   printing index, image   : 5, /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230126T075109_NA509_R135_T36NXG_20230126T101405_class.tif
# 2023-07-10 09:07:19,281: INFO:
# 2023-07-10 09:07:19,282: INFO:
# 2023-07-10 09:07:19,283: INFO: *** PROCESSING CLASSIFIED IMAGE: 5 of 8 filename: /home/sepal-user/pyeo_dir/36NXG/output/classified/S2B_MSIL2A_20230126T075109_NA509_R135_T36NXG_20230126T101405_class.tif ***
# 2023-07-10 09:07:19,283: INFO:   early time stamp: 2022-09-18 07:46:19
# 2023-07-10 09:07:19,285: INFO:   late  time stamp: 2023-01-26 07:51:09
# 2023-07-10 09:07:19,286: INFO:   Change raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230126T075109.tif
# 2023-07-10 09:07:19,287: INFO:   I.R. dNDVI raster file to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/dNDVI_20220918T074619_36NXG_20230126T075109.tif
# 2023-07-10 09:07:19,287: INFO:   I.R. NDVI raster file of change image to be created: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/NDVI_20220918T074619_36NXG_20230126T075109.tif
# 2023-07-10 09:07:19,289: INFO: Update of the report image product based on change detection image.
# 2023-07-10 09:07:19,295: INFO: Change raster file already exists: /home/sepal-user/pyeo_dir/36NXG/output/probabilities/change_20220918T074619_36NXG_20230126T075109.tif. Skipping change raster creation.
# 2023-07-10 09:07:19,296: INFO: ***   Loading data arrays required to build report layers   ***
# 2023-07-10 09:07:19,334: INFO: ***   Starting build of report layers:   ***
# 2023-07-10 09:07:19,335: INFO: percentage_probability_threshold:   50
# 2023-07-10 09:07:19,335: INFO: minimum_required_validated_detections_threshold: 5
# 2023-07-10 09:07:19,336: INFO: minimum_required_dNDVI_detections_threshold: 5
# 2023-07-10 09:07:19,337: INFO: minimum_required_classifier_detections_threshold: 5
# 2023-07-10 09:07:19,339: INFO: minimum_required_FROM_detections_threshold: 2
# 2023-07-10 09:07:19,339: INFO: minimum_required_TO_detections_threshold: 2
# 2023-07-10 09:07:19,340: INFO: Build Report Layers
# 2023-07-10 09:07:19,340: INFO: Layer 0: Total Image Count: Counts the number of images processed per pixel - number of available images within overall cloud percentage cover limit set in pyeo_1.ini file
# 2023-07-10 09:07:33,537: INFO: Layer 1: Occluded Image Count: Counts number of cloud occluded (or out-of-orbit) images that are thus unavailable for classification and analysis
# 2023-07-10 09:08:01,576: INFO: Layer 2: Classifier Change Detection Count: Count if a from/to change of classification was detected

# %% [markdown]
# ### <a id='toc4_8_2_'></a>[Final Housekeeping](#toc0_)

# %% [markdown]
# Finally, we run some more housekeeping, deleting or compressing unnecessary files, depending on the argument supplied at the beginning of this session.

# %%
if config_dict["do_all"] or config_dict["do_change"]:
    tile_log.info("Compressing the report image.")
    tile_log.info("---------------------------------------------------------------")
    raster_manipulation.compress_tiff(output_product, output_product)

    if config_dict["do_delete"]:
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info(
            "Deleting intermediate class images used in change detection."
        )
        tile_log.info(
            "They can be recreated from the cloud-masked, band-stacked L2A images and the saved model."
        )
        tile_log.info(
            "---------------------------------------------------------------"
        )
        directories = [
            categorised_image_dir,
            sieved_image_dir,
            probability_image_dir,
        ]
        for directory in directories:
            paths = [f for f in os.listdir(directory)]
            for f in paths:
                # keep the classified composite layers and the report image product for the next change detection
                if not f.startswith("composite_") and not f.startswith("report_"):
                    tile_log.info("Deleting {}".format(os.path.join(directory, f)))
                    if os.path.isdir(os.path.join(directory, f)):
                        shutil.rmtree(os.path.join(directory, f))
                    else:
                        os.remove(os.path.join(directory, f))
        tile_log.info(
            "---------------------------------------------------------------"
        )
        tile_log.info("Deletion of intermediate file products complete.")
        tile_log.info(
            "---------------------------------------------------------------"
        )
    else:
        if config_dict["do_zip"]:
            tile_log.info(
                "---------------------------------------------------------------"
            )
            tile_log.info(
                "Zipping intermediate class images used in change detection"
            )
            tile_log.info(
                "---------------------------------------------------------------"
            )
            directories = [categorised_image_dir, sieved_image_dir]
            for directory in directories:
                filesystem_utilities.zip_contents(
                    directory, notstartswith=["composite_", "report_"]
                )
            tile_log.info(
                "---------------------------------------------------------------"
            )
            tile_log.info("Zipping complete")
            tile_log.info(
                "---------------------------------------------------------------"
            )

    tile_log.info("---------------------------------------------------------------")
    tile_log.info(
        "Change detection and report image product updating, file compression, zipping"
    )
    tile_log.info(
        "and deletion of intermediate file products (if selected) are complete."
    )
    tile_log.info("---------------------------------------------------------------")

    if config_dict["do_delete"]:
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Deleting temporary directories starting with 'tmp*'")
        tile_log.info("These can be left over from interrupted processing runs.")
        tile_log.info("---------------------------------------------------------------")
        directory = tile_root_dir
        for root, dirs, files in os.walk(directory):
            temp_dirs = [d for d in dirs if d.startswith("tmp")]
            for temp_dir in temp_dirs:
                tile_log.info("Deleting {}".format(os.path.join(root, temp_dir)))
                if os.path.isdir(os.path.join(directory, f)):
                    shutil.rmtree(os.path.join(directory, f))
                else:
                    tile_log.warning(
                        "This should not have happened. {} is not a directory. Skipping deletion.".format(
                            os.path.join(root, temp_dir)
                        )
                    )
        tile_log.info("---------------------------------------------------------------")
        tile_log.info("Deletion of temporary directories complete.")
        tile_log.info("---------------------------------------------------------------")


tile_log.info("---------------------------------------------------------------")
tile_log.info("---                  PROCESSING END                         ---")
tile_log.info("---------------------------------------------------------------")
