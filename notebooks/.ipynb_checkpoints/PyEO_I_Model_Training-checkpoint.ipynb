# %% [markdown]
# In the previous notebook, we queried and downloaded Sentinel-2 imagery. Now, we need to create a model to classify the land cover (and thus detect changes in forest cover between two date periods).
#
# To build a model, we will need training data. For pyeo_1, we define training data as pixel surface reflectance values and their corresponding land cover classes.
#
# The section below details how to delineate training polygons in QGIS, but if you already have training data, then you can skip and proceed to [importing the pyeo_1 library](#Import-the-Required-Libraries).

# %% [markdown]
# # How to Delineate Sample Areas (in QGIS)

# %% [markdown]
# ## Heiko's Instructional Video

# %% [markdown]
# The below recording is from Prof. Heiko Balzter. Here Heiko takes users through the process of creating shapefiles over Sentinel-2 imagery.
#
# You may need to close the file manager tab to the left of this notebook, to see the embedded video clearer.

# %%
# for now, we are displaying Heiko's training sample delineation over Rutland, UK.

# time permitting, Matt will record a video delineating samples over Kenya.

from IPython.display import HTML

# in hpc, the below output is black (probably a firewall restriction)
# on sepal, the video plays.
HTML('<iframe width="1080" height="490" src="https://leicester.cloud.panopto.eu/Panopto/Pages/Viewer.aspx?id=a4568baf-c85d-4fab-b6c4-ac9300ed6ab2" frameborder="0" allowfullscreen></iframe>')
# Out:
# /home/m/mp730/miniconda3/envs/pyeo_prod_0_8_0_env/lib/python3.10/site-packages/IPython/core/display.py:419: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="1080" height="490" src="https://leicester.cloud.panopto.eu/Panopto/Pages/Viewer.aspx?id=a4568baf-c85d-4fab-b6c4-ac9300ed6ab2" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Matt's Instructional Video

# %% [markdown]
# *Note to myself - for me to cover in the video*
# - How to create a shapefile for sampling
# - The advised structure of the shapefile e.g. id, class
# - Digitising toolbars
# - How to delineate
# - Sample away from class edges
# - Reshape often
# - Send2GE plugin to inspect high-res imagery for uncertain land cover classes
# - Save often
# - Sample underrepresented classes more

# %% [markdown]
# ### Written QGIS Tips

# %% [markdown]
# 1. Whilst in QGIS, make sure you have the **Digitizing** and **Advanced Digitizing** toolbars enabled. To do so, click:
#     - View > Toolbars > Tick Digitizing and Advanced Digitizing
#
# 2. To delineate features, use the **Add Polygon Feature** tool. It looks like this: ![image](/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/Create_polygon.PNG)
#
# 3. Avoid delineating near the edges of land cover, e.g. at the forest edge adjacent to a road. These edge pixels will capture the variation in land-cover at the sub-pixel level, confusing your classifier.
#
# 3. The **Reshape Features** tool, is extremely useful for extending already delineated polygons. Click inside the polygon you want to extend, then click any points outside of the polygon (covering your land cover class of interest), once ready - click inside the polygon to complete the loop, and right click to finish delineation. The tool icon looks like this: ![image](/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/Reshape_features.PNG)
#
# 4. Install Google Earth Pro on your PC, https://www.google.com/earth/about/versions/ , which offers very-high resolution satellite imagery, and Google StreetView, to help you understand the land covers you are delineating.
#
# 5. Install the QGIS plugin, **Send2GE**. This plugin sends your location directly to your installed Google Earth Pro. To do so, click on the Send2GE icon, ![image](/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/Send2GE.PNG), and then click on the location you want to view in Google Earth Pro.
#
# 6. Consider your Land Cover Classes and tailor them to what you want your product to achieve.
# Below are a list of classes that we have used for our `pyeo_1` classifier, but alternative classes may be more appropriate for your needs.
#
#     1. Primary Forest
#     2. Plantation Forest
#     3. Bare Soil
#     4. Crops
#     5. Grassland
#     6. Open Water
#     7. Burn Scar
#     8. Cloud
#     9. Cloud Shadow
#     10. Haze
#     11. Sparse Woodland
#     12. Dense Woodland
#     13. Artificial

# %% [markdown]
# # Import the Required Libraries

# %% [markdown]
# Before proceeding, let's check that the import statements from pyeo_1 execute correctly.

# %%
from pyeo_1 import classification as cls
from pyeo_1 import filesystem_utilities as file_utils
import logging
import os
from pathlib import Path

print("library imports complete")
# Out:
# library imports complete

# %% [markdown]
# ## Specify the root directory

# %% [markdown]
# This is the directory where you want to work from.

# %%
root_dir = "ir_test_pyeo_1_production"

# %% [markdown]
# This script below shows you the root_home path, you should **not** amend this unless you know what you're doing.

# %%
home = f"{str(Path.home())}{os.sep}"
root_home = f"{home}{root_dir}{os.sep}"
root_home
# Out:
# '/home/sepal-user/ir_test_pyeo_1_production/'

# %% [markdown]
# ## Initialise the Logger

# %% [markdown]
# When running `pyeo_1`, we record our processing efforts, parameters etc. in a log file (a .txt file). If we are ever curious about what `pyeo_1` has done and when, we can look at the log file.
# So below, we initialise our log file. Replace `log_path` with your own path.
#  **Note: the log.txt does not need to exist before running the function**

# %%
log_path = f"{root_home}/models/model_1/log.txt"
folder_path = Path(log_path[:-8])
if folder_path.exists() == False:
    os.makedirs(folder_path)
    
log = file_utils.init_log(log_path)
# Out:
# 2023-03-24 18:22:30,938: INFO: ****PROCESSING START****

# %% [markdown]
# Whenever a function writes to the log, the output will be displayed in the Python cell output, but the log file can also be viewed in a text editor.
# **Note, sometimes not all of the log file output in the cell outputs is displayed, so it is best to view the log.txt file in an external text editor.**

# %% [markdown]
# # Single Tile Approach

# %% [markdown]
# In this section, we will follow the individual steps to extract spectral information from the Sentinel-2 imagery using our training shapefiles, train a Random Forest model on the spectral values of the land cover classes, and classify a Sentinel-2 image tile.

# %% [markdown]
# ## Extract Spectral Information from Sentinel-2 Imagery

# %% [markdown]
# Since we have delineated our training polygons, we can now extract the spectral information from the imagery, by running `cls.extract_features_to_csv()` in the cell below.
# First, specify the paths to the training shapefile, training raster and the out directory.

# %%
# specify the path of the training shapefile

training_shape_path = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/models/model_4/composite_T36MYE_20191128T075251.shp"

# specify the path of the training raster
training_raster_path = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/data/36MYE/composite/composite_T36MYE_20191128T075251.tif"

# specify the output folder
out_folder = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/models/model_4/"

# %% [markdown]
# Now, we can run the `cls.extract_features_to_csv` function.
# If the column heading of your training shapefile is not `CODE`, substitute the correct column name with the `attribute` argument.

# %%
# run the function to extract the spectral values and assigned classes from the training raster and training shapefile
cls.extract_features_to_csv(in_ras_path=training_raster_path,
                            training_shape_path=training_shape_path,
                            out_path=f"{out_folder}composite_T36MYE_20191128T075251_features.csv",
                            attribute="class")
# Out:
# 2023-03-13 16:01:24,750: INFO: Get training data from /data/clcr/shared/IMPRESS/Ivan/kenya_training/36MYE/composite/composite_T36MYE_20191128T075251.tif
# 2023-03-13 16:01:24,829: INFO:                    and /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_4/composite_T36MYE_20191128T075251.shp
# 2023-03-13 16:01:24,962: INFO: Shape raster path /lustre/alice3/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/tmpqevzl6e3/composite_T36MYE_20191128T075251_rasterised
# 2023-03-13 16:01:27,098: INFO: 4 bands in image file
# 2023-03-13 16:01:27,099: INFO: 1000958 training pixels in shapefile

# %% [markdown]
# Let's see what `features.csv` looks like, by reading in the csv and printing the first 5 rows.
#
# Each row represents a pixel of a certain class. The first column in each row is the class of that pixel, with the columns after that being the Sentinel 2 blue, green, red and NIR value of that pixel.

# %%
import pandas as pd

# read in our spectral signatures
features = pd.read_csv(f"{out_folder}composite_T36MYE_20191128T075251_features.csv")

# prints the first 5 rows of features
features.head(5)
# Out:
#    6.0  615.0  893.0  863.0  513.0
# 0  6.0  623.0  896.0  861.0  511.0
# 1  6.0  616.0  907.0  855.0  508.0
# 2  6.0  621.0  906.0  845.0  502.0
# 3  6.0  614.0  890.0  847.0  502.0
# 4  6.0  610.0  895.0  854.0  512.0

# %% [markdown]
# ## Model Creation and Training

# %% [markdown]
# You can create a scikit-learn Extra Trees Classifier using pyeo_1 with the code in the cell below:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import ensemble as ens
import numpy as np
import joblib

# initialise an Extra Trees Classifier
model = ens.ExtraTreesClassifier(bootstrap=False, criterion="gini", max_features=0.55, min_samples_leaf=2,
                                    min_samples_split=16, n_estimators=100, n_jobs=-1, class_weight='balanced')

# load signatures from csv file
features, labels = cls.load_signatures(f"{out_folder}composite_T36MYE_20191128T075251_features.csv",
                                       sig_datatype=np.int32)

# split into test and train samples
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.25, random_state=101)

# train the model
model.fit(X_train, y_train)

# save the model
joblib.dump(model, filename=f"{out_folder}model_36MYE_20220313.pkl")
# Out:
# ['/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_4/model_36MYE_20220313.pkl']

# %% [markdown]
# ## Accuracy Statistics

# %% [markdown]
# Now that we have a model trained from shapefiles overlaid a Sentinel-2 image tile, we need to assess the model accuracy.
#
# To do that, we will use the model to predict the classes of `y_test` from the values of `X_test`.

# %%
# make a prediction
y_pred = model.predict(X_test)

# write classification labels
target_names = ["Primary Forest",
          "Plantation Forest",
          "Bare Soil",
          "Crops",
          "Grassland",
          "Open Water",
          "Artificial"]

# create classification metrics report
report = classification_report(y_true=y_test, y_pred=y_pred, target_names=target_names)

# write classification report to file
with open(f"{out_folder}class_scores.txt", "w") as txt:
    print(report, file=txt)

# view the report
print(report)
# Out:
#                    precision    recall  f1-score   support
#
#    Primary Forest       1.00      0.99      1.00    174880
# Plantation Forest       0.59      0.90      0.72      1679
#         Bare Soil       0.29      0.88      0.44         8
#             Crops       0.83      0.92      0.87      1261
#         Grassland       0.95      0.99      0.97      4789
#        Open Water       1.00      1.00      1.00     67225
#        Artificial       0.88      0.95      0.92       398
#
#          accuracy                           0.99    250240
#         macro avg       0.79      0.95      0.84    250240
#      weighted avg       0.99      0.99      0.99    250240

# %% [markdown]
# ## Imagery Classification

# %% [markdown]
# If we are happy with the performance of the model, we can now classify a Sentinel-2 image tile, if we believe the values the model was trained on represent the spectral values of the land cover of the imagery of interest.

# %%
cls.classify_image(image_path=training_raster_path,
                   model_path=f"{out_folder}model_36MYE_20220313.pkl",
                   class_out_path=f"{out_folder}composite_T36MYE_20211212T075229_class.tif",
                   prob_out_path=None,
                   apply_mask=False,
                   out_format="GTiff",
                   chunks=10,
                   nodata=0,
                   skip_existing = False)
# Out:
# 2023-03-14 13:34:39,506: INFO: Classifying file: /data/clcr/shared/IMPRESS/Ivan/kenya_training/36MYE/composite/composite_T36MYE_20191128T075251.tif
# 2023-03-14 13:34:39,507: INFO: Saved model     : /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_4/model_36MYE_20220313.pkl
# 2023-03-14 13:34:57,979: INFO: Proportion of non-missing values: 99.76%
# 2023-03-14 13:35:03,190: INFO:    Number of chunks 10 Chunk size 12079353 Chunk residual 6
# 2023-03-14 13:35:03,191: INFO:    Classifying chunk 1 of size 12079353
# 2023-03-14 13:35:36,983: INFO:    Classifying chunk 2 of size 12079353
# 2023-03-14 13:36:08,415: INFO:    Classifying chunk 3 of size 12079353
# 2023-03-14 13:36:40,981: INFO:    Classifying chunk 4 of size 12079353
# 2023-03-14 13:37:14,674: INFO:    Classifying chunk 5 of size 12079353
# 2023-03-14 13:37:49,207: INFO:    Classifying chunk 6 of size 12079353
# 2023-03-14 13:38:25,480: INFO:    Classifying chunk 7 of size 12079353
# 2023-03-14 13:39:02,034: INFO:    Classifying chunk 8 of size 12079353
# 2023-03-14 13:39:37,815: INFO:    Classifying chunk 9 of size 12079353
# 2023-03-14 13:40:13,698: INFO:    Classifying chunk 10 of size 12079359
# 2023-03-14 13:41:17,361: INFO: Created classification image file: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_4/composite_T36MYE_20211212T075229_class.tif
# '/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_4/composite_T36MYE_20211212T075229_class.tif'

# %% [markdown]
# ## Visualise the Classified Imagery

# %%
def visualise_classification(classified_path: str, labels: list):

    from osgeo import gdal
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.colors as mcolors

    ds = gdal.Open(classified_path)
    array = np.array(ds.GetRasterBand(1).ReadAsArray())

    counts, _ = np.histogram(array, bins = len(labels))
    percent = counts / counts.sum()
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 6))


    def discrete_cmap(N, base_cmap=None):
        """Create an N-bin discrete colormap from the specified input map"""

        # this function was taken on 10/03/2023 from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
        # author: Jake Vanderplas

        base = plt.cm.get_cmap(base_cmap)
        color_list = base(np.linspace(0, 1, N))
        cmap_name = base.name + str(N)
        return base.from_list(cmap_name, color_list, N)

    cmap = discrete_cmap(len(labels), base_cmap="cubehelix")
    cmap.set_bad("red")
    colour_list = [mcolors.rgb2hex(cmap(i)) for i in range(cmap.N)]

    x = np.arange(1, (len(labels) + 1))
    ax1.bar(x, percent, color=colour_list)
    ax1.set_xticks(x, labels=labels, rotation=35, ha="right")
    ax1.set_title("Classes distribution")
    ax2.set_title("Classification raster displayed")

    ax2.imshow(array, cmap=cmap, aspect="auto")
    plt.show()

    return

# %%
# specify the path of the classified image
classified_path = f"{out_folder}composite_T36MYE_20211212T075229_class.tif"

# create a list of class labels
labels = [
    "Primary Forest",
    "Plantation Forest",
    "Bare Soil",
    "Crops",
    "Grassland",
    "Open Water",
    "Artificial"
    ]

visualise_classification(classified_path=classified_path, labels=labels)

# %% [markdown]
# # Multiple Tile and Training Shapefiles Approach

# %% [markdown]
# We can also train a Random Forest classifier on multiple Sentinel-2 tiles with multiple training shapefiles. This approach can create a superior classifier because the training shapefiles can cover more tiles, providing the model with a variety of spectral values per class.

# %% [markdown]
# The `create_rf_model_for_region` function assumes the training rasters and training shapefiles are structured like the cell diagram below.
# **Note, the filenames do not need to be a specific format**

# %%
# model_folder
    # training_raster_tile_1
    # training_shapefile_tile_1
    # training_raster_tile_2
    # training_shapefile_tile_2

# %%
# specify the path to the directory structure
out_folder = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/models/model_2/"

# name the model that will be created
model_file = "model_simple.pkl"

cls.create_rf_model_for_region(path_to_region=out_folder,
                               model_out=f"{out_folder}{model_file}",
                               attribute="class"
                               #,attribute="CODE" # replace this line with the one above, if training shapefile has CODE as class heading
                               )
# Out:
# 2023-03-14 12:54:32,653: INFO: Create a random forest classification model for region based on tif/shp file pairs: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/
# 2023-03-14 12:54:32,660: INFO: Collecting training data from all tif/shp file pairs.
# 2023-03-14 12:54:32,661: INFO: Analysing shapefile: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/composite_T36MYE_20191128T075251.shp
# 2023-03-14 12:54:33,016: INFO: EPSG codes of the image and shapefile: 21097, 21097
# 2023-03-14 12:54:34,374: INFO: This training data shapefile includes 7 classes: [1, 2, 3, 4, 5, 6, 13]
# 2023-03-14 12:54:34,375: INFO: 4 bands in image file
# 2023-03-14 12:54:34,376: INFO: (4, 11004, 11004)
# 2023-03-14 12:54:34,376: INFO: (11004, 11004)
# 2023-03-14 12:54:34,377: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:34,378: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:34,379: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:39,570: INFO: (4, 1000958)
# 2023-03-14 12:54:39,572: INFO: (1000958,)
# 2023-03-14 12:54:39,573: INFO: 1000958 training pixels in shapefile
# 2023-03-14 12:54:39,700: INFO: Analysing shapefile: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/composite_T37NCC_20191120T074119.shp
# 2023-03-14 12:54:39,945: INFO: EPSG codes of the image and shapefile: 21097, 21097
# 2023-03-14 12:54:41,648: INFO: This training data shapefile includes 2 classes: [1, 3]
# 2023-03-14 12:54:41,649: INFO: 4 bands in image file
# 2023-03-14 12:54:41,650: INFO: (4, 10980, 10980)
# 2023-03-14 12:54:41,651: INFO: (10980, 10980)
# 2023-03-14 12:54:41,652: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:41,652: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:41,653: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:51,241: INFO: (4, 19983778)
# 2023-03-14 12:54:51,243: INFO: (19983778,)
# 2023-03-14 12:54:51,244: INFO: 19983778 training pixels in shapefile
# 2023-03-14 12:54:51,576: INFO: Analysing shapefile: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/composite_T37MER_20191207T073209.shp
# 2023-03-14 12:54:51,794: INFO: EPSG codes of the image and shapefile: 21097, 21097
# 2023-03-14 12:54:52,958: INFO: This training data shapefile includes 5 classes: [1, 3, 6, 11, 13]
# 2023-03-14 12:54:52,959: INFO: 4 bands in image file
# 2023-03-14 12:54:52,959: INFO: (4, 10980, 10980)
# 2023-03-14 12:54:52,960: INFO: (10980, 10980)
# 2023-03-14 12:54:52,961: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54:52,962: INFO:
# [0 0 0 ... 0 0 0]
# 2023-03-14 12:54
# 2023-03-14 12:56:09,256: INFO:                 |
# 2023-03-14 12:56:09,257: INFO: Predicted class v
# 2023-03-14 12:56:09,258: INFO:
# [[11785    85     0    23   582    28    16     0]
#  [  131  1548     0     0     1     0     0     0]
#  [    0     0 12522     0     0     3   101     0]
#  [   45     0     0  1183    65     1     9     0]
#  [  525     0     0     6  4189     6     4     0]
#  [   24     0     1     5     9 12478    38     0]
#  [   22     0   189    15    12    60 10552   170]
#  [    0     0     0     0     0     0    72  6106]]
# 2023-03-14 12:56:09,258: INFO: ----------------------------------------
# 2023-03-14 12:56:09,355: INFO: Classification Report
# 2023-03-14 12:56:09,356: INFO:
#               precision    recall  f1-score   support
#
#            1       0.94      0.94      0.94     12519
#            2       0.95      0.92      0.93      1680
#            3       0.99      0.99      0.99     12626
#            4       0.96      0.91      0.93      1303
#            5       0.86      0.89      0.87      4730
#            6       0.99      0.99      0.99     12555
#           11       0.97      0.99      0.98      6178
#           13       0.98      0.96      0.97     11020
#
#     accuracy                           0.96     62611
#    macro avg       0.95      0.95      0.95     62611
# weighted avg       0.96      0.96      0.96     62611
#
# 2023-03-14 12:56:09,356: INFO: Saving classification report to /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/class_scores.txt
# 2023-03-14 12:56:09,747: INFO: Feature ranking:
# 2023-03-14 12:56:09,748: INFO: 1. feature 3 (0.312228)
# 2023-03-14 12:56:09,748: INFO: 2. feature 2 (0.275234)
# 2023-03-14 12:56:09,749: INFO: 3. feature 0 (0.249296)
# 2023-03-14 12:56:09,749: INFO: 4. feature 1 (0.163242)

# %%
# view classification report metrics
with open(f"{out_folder}class_scores.txt", "r") as report:
    print(report.read())
# Out:
#               precision    recall  f1-score   support
#
#            1       0.94      0.94      0.94     12519
#            2       0.95      0.92      0.93      1680
#            3       0.99      0.99      0.99     12626
#            4       0.96      0.91      0.93      1303
#            5       0.86      0.89      0.87      4730
#            6       0.99      0.99      0.99     12555
#           11       0.97      0.99      0.98      6178
#           13       0.98      0.96      0.97     11020
#
#     accuracy                           0.96     62611
#    macro avg       0.95      0.95      0.95     62611
# weighted avg       0.96      0.96      0.96     62611

# %% [markdown]
# As of yet, we have not written a function for `pyeo_1` to take user-supplied class names, which would enable class names to be displayed in the classification metrics report above.
#
# Therefore, currently users should substitute their own class names to pass to the classification report function.

# %% [markdown]
# ## Classify Directory

# %% [markdown]
# `cls.classify_directory` requires the `class_out_dir` to already exist, so make sure that this directory is present before running the function.

# %%
# provide the path of the directory of images to classify
image_directory = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/data/to_classify"

# specify the path of the model created in the cell above
model_path = f"{out_folder}{model_file}"

# provide the path of the classified output folder
class_out_dir = "/data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_1_notebooks/resources/data/classified"

# run the function to classify the directory of images you provided
cls.classify_directory(in_dir=image_directory,
                       model_path=model_path,
                       class_out_dir=class_out_dir,
                       chunks=10)
# Out:
# 2023-03-14 11:14:49,534: INFO: Classifying files in /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/data/to_classify
# 2023-03-14 11:14:49,535: INFO: Class files saved in /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/data/classified
# 2023-03-14 11:14:49,536: INFO: Classifying file: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/data/to_classify/composite_T36MYE_20191128T075251.tif
# 2023-03-14 11:14:49,536: INFO: Saved model     : /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/model_simple.pkl
# 2023-03-14 11:15:06,779: INFO: Proportion of non-missing values: 99.76%
# 2023-03-14 11:15:14,687: INFO:    Number of chunks 10 Chunk size 12079353 Chunk residual 6
# 2023-03-14 11:15:14,704: INFO:    Classifying chunk 1 of size 12079353
# 2023-03-14 11:19:38,941: INFO:    Classifying chunk 2 of size 12079353
# 2023-03-14 11:24:10,143: INFO:    Classifying chunk 3 of size 12079353
# 2023-03-14 11:28:37,642: INFO:    Classifying chunk 4 of size 12079353
# 2023-03-14 11:33:16,341: INFO:    Classifying chunk 5 of size 12079353
# 2023-03-14 11:37:50,370: INFO:    Classifying chunk 6 of size 12079353
# 2023-03-14 11:42:39,513: INFO:    Classifying chunk 7 of size 12079353
# 2023-03-14 11:47:25,795: INFO:    Classifying chunk 8 of size 12079353
# 2023-03-14 11:52:18,954: INFO:    Classifying chunk 9 of size 12079353
# 2023-03-14 11:57:12,874: INFO:    Classifying chunk 10 of size 12079359
# 2023-03-14 12:02:18,715: INFO: Created classification image file: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/data/classified/composite_T36MYE_20191128T075251_class.tif
# 2023-03-14 12:02:19,093: INFO: Classifying file: /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/data/to_classify/composite_T37NCC_20191120T074119.tif
# 2023-03-14 12:02:19,094: INFO: Saved model     : /data/clcr/shared/IMPRESS/matt/pyeo_1/pyeo_notebooks/resources/models/model_2/model_simple.pkl
# 2023-03-14 12:02:36,514: INFO: Proportion of non-missing values: 99.99%
# 2023-03-14 12:02:42,474: INFO:    Number of chunks 10 Chunk size 12054646 Chunk residual 8
# 2023-03-14 12:02:42,486: INFO:    Classifying chunk 1 of size 12054646
# 2023-03-14 12:06:27,718: INFO:    Classifying chunk 2 of size 12054646
# 2023-03-14 12:10:17,017: INFO:    Classifying chunk 3 of size 12054646
# 2023-03-14 12:14:08,465: INFO:    Classifying chunk 4 of size 12054646
# 2023-03-14 12:18:04,881: INFO:    Classifying chunk 5 of size 12054646
# 2023-03-14 12:22:02,834: INFO:    Classifying chunk 6 of size 12054646
# 2023-03-14 12:26:01,222: INFO:    Classifying chunk 7 of size 12054646
# 2023-03-14 12:29:51,770: INFO:    Classifying chunk 8 of size 12054646
# 2023-03-14 12:33:44,930: INFO:    Classifying chunk 9 of size 12054646
# 2023-03-14 12:37:26,034: INFO:    Classifying chunk 10 of size 12054654

# %% [markdown]
# ## Visualise the Classifications

# %% [markdown]
# Here, we can visualise the images we have just classified. Just pass the filename of the classified image.

# %%
# specify the directory of a classified image
classified_path = f"{class_out_dir}/composite_T36MYE_20191128T075251_class.tif"

# create a list of class labels. In this example we have more classes because the additional classes were delineated to train this region rf model.
labels = [
    "Primary Forest",
    "Plantation Forest",
    "Bare Soil",
    "Crops",
    "Grassland",
    "Open Water",
    "Sparse Woodland",
    "Artificial"
]

visualise_classification(classified_path=classified_path, labels=labels)

# %%
# specify the directory of a classified image
classified_path = f"{class_out_dir}/composite_T37NCC_20191120T074119_class.tif"

visualise_classification(classified_path=classified_path, labels=labels)

# note - this isn't a great rf model, I trained it quickly with few samples over this tile. This is intended as a toy model.
